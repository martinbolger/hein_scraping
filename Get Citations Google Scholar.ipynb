# %%
from selenium import webdriver
import pandas as pd
import bs4 as bs
import os
import numpy as np
import re
import time
from selenium.webdriver.common.keys import Keys
import requests
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome()
driver.get('https://scholar.google.com/')

# %%
def create_path(*args):
    cur_path = os.getcwd()
    for value in args:
        cur_path  = os.path.join(cur_path, value)
    return cur_path

# %%
def search_google_scholar(article_name):
    driver.get('https://scholar.google.com/')
    search = driver.find_element_by_xpath('//*[@id="gs_hdr_tsi"]')
    search.send_keys('allintitle: ' + article_name)
    driver.find_element_by_xpath('//*[@id="gs_hdr_tsb"]/span/span[1]').click()
#     citations = driver.find_element_by_xpath('//*[@id="gs_res_ccl_mid"]/div[1]/div[2]/div[3]/a[3]').text
    try:
        citations = driver.find_element_by_xpath('//*[@id="gs_res_ccl_mid"]/div/div/div[3]/a[3]').text
        try:
            citations = citations.split('by ')[1]
        except IndexError as exception:
            citations = '0'
    except NoSuchElementException as exception:
        print('No article found')
        citations = 'na'
    return citations

# %%
os.getcwd()
path = os.path.join(os.getcwd(), 'author_papers', 'Arizona')
files = os.listdir(path)
main_df = pd.DataFrame(columns = ['Name', 'Article', 'Hein Citations', 'Google Citations'])
for file in files[0:1]:
    data = pd.read_csv(os.path.join(path, file))
    name = file.split('_')[0]
    for i in range(0, len(data)):
        article_name = data['Title'][i].split('[')[0]
        print(article_name)
        hein_citations = data['Cited (articles)'][i]
        print(hein_citations)
        citation_number = search_google_scholar(article_name)
        print(citation_number)
        main_df = main_df.append(pd.DataFrame({'Name': [name], 'Article': [article_name], 'Hein Citations': [hein_citations], 'Google Citations': [citation_number]}))
        driver.get('http://amazon.com')
        time.sleep(3)
        driver.get('http://facebook.com')
        time.sleep(3)
# Out:
# Reinventing the Double Helix: A Novel and Nonobvious Reconceptualization of the Biotechnology Patent
# 115
# 229
# Civil and Criminal Sanctions in the Constitution and Courts
# 58
# 88
# Don't Judge a Sale by Its License: Software Transfers under the First Sale Doctrine in the United States and the European Community
# 32
# 57
# Copyright Misuse and the Limits of the Intellectual Property Monopoly
# 28
# 63
# State Regulation of Sexuality in International Human Rights Law and Theory
# 26
# 69
# Secrecy, Monopoly, and Access to Pharmaceuticals in International Trade Law: Protection of Marketing Approval Data under the TRIPs Agreement
# 20
# 83
# U.S. State Legislation to Limit Use of International and Foreign Law
# 14
# 22
# Questioning Civilian Immunity
# 13
# 30
# Challenges and Implications of a Systemic Social Effect Theory
# 10
# 16
# Introductory Note to the Anti-Counterfeiting Trade Agreement
# 10
# No article found
# na
# A Divorce Waiting to Happen: Franklin Roosevelt and the Law of Neutrality, 1935-1941
# 10
# 31
# Feminism and International Law: Theory, Methodology, and Substantive Reform
# 9
# 62
# Control without Interest: State Law of Assignment, Federal Preemption, and the Intellectual Property License
# 7
# 30
# Wiwa v. Royal Dutch Petroleum Co.: A New Standard for the Enforcement of International Law in U.S. Courts
# 6
# 35
# Cure without a Disease: The Emerging Doctrine of Successor Liability in International Trade Regulation
# 4
# 9
# Nondiscrimination as a Universal Human Rights
# 4
# 6
# The Proportionality Principle in Operation: Methodological Limitations of Empirical Research and the Need for Transparency
# 3
# 7
# Introductory Note to the Beijing Treaty of Audiovisual Performances
# 3
# No article found
# na
# Below-Market in Interest in International Claims against States
# 2
# 3
# Leading from (a Bit) behind: The United States and International Human Rights Law
# 1
# 5
# Conception and Misconception in Joint Inventorship
# 1
# 9
# Control without Interest: State Law of Assignment, Federal Preemption, and the Intellectual Property License
# na
# 30
# Targeting Decisions and Consequences for Civilians in the Colombian Civil Strife
# na
# 1
# Overloading International Human Rights Law: Introductory Remarks
# na
# No article found
# na
# Cyber Trespass Comes of Age - Ebay, Inc. v. Bidder's Edge, Inc.
# na
# 0

# %%
main_df.to_csv(create_path('google_scholar_citations', 'arizona.csv'))

# %%
data
# Out:
#     Unnamed: 0                                              Title  \
# 0            0  Reinventing the Double Helix: A Novel and Nono...
# 1            0  Civil and Criminal Sanctions in the Constituti...
# 2            0  Don't Judge a Sale by Its License: Software Tr...
# 3            0  Copyright Misuse and the Limits of the Intelle...
# 4            0  State Regulation of Sexuality in International...
# 5            0  Secrecy, Monopoly, and Access to Pharmaceutica...
# 6            0  U.S. State Legislation to Limit Use of Interna...
# 7            0            Questioning Civilian Immunity [article]
# 8            0  Challenges and Implications of a Systemic Soci...
# 9            0  Introductory Note to the Anti-Counterfeiting T...
# 10           0  A Divorce Waiting to Happen: Franklin Roosevel...
# 11           0  Feminism and International Law: Theory, Method...
# 12           0  Control without Interest: State Law of Assignm...
# 13           0  Wiwa v. Royal Dutch Petroleum Co.: A New Stand...
# 14           0  Cure without a Disease: The Emerging Doctrine ...
# 15           0  Nondiscrimination as a Universal Human Rights ...
# 16           0  The Proportionality Principle in Operation: Me...
# 17           0  Introductory Note to the Beijing Treaty of Aud...
# 18           0  Below-Market in Interest in International Clai...
# 19           0  Leading from (a Bit) behind: The United States...
# 20           0  Conception and Misconception in Joint Inventor...
# 21           0  Control without Interest: State Law of Assignm...
# 22           0  Targeting Decisions and Consequences for Civil...
# 23           0  Overloading International Human Rights Law: In...
# 24           0  Cyber Trespass Comes of Age - Ebay, Inc. v. Bi...
#
#                                             Author(s)  \
# 0   Demaine, Linda J. (Cited 262 times); Fellmeth,...
# 1                              Fellmeth, Aaron Xavier
# 2   Determann, Lothar (Cited 104 times); Fellmeth,...
# 3                              Fellmeth, Aaron Xavier
# 4                              Fellmeth, Aaron Xavier
# 5                              Fellmeth, Aaron Xavier
# 6                   Fellmeth, Aaron (Cited 376 times)
# 7                              Fellmeth, Aaron Xavier
# 8                              Fellmeth, Aaron Xavier
# 9                                  Fellmeth, Aaron X.
# 10                             Fellmeth, Aaron Xavier
# 11                             Fellmeth, Aaron Xavier
# 12                             Fellmeth, Aaron Xavier
# 13                             Fellmeth, Aaron Xavier
# 14                             Fellmeth, Aaron Xavier
# 15                                 Fellmeth, Aaron X.
# 16                  Fellmeth, Aaron (Cited 376 times)
# 17                                 Fellmeth, Aaron X.
# 18                             Fellmeth, Aaron Xavier
# 19                                 Fellmeth, Aaron X.
# 20                                 Fellmeth, Aaron X.
# 21                             Fellmeth, Aaron Xavier
# 22  Fellmeth, Aaron X.; Sylvester, Douglas J. (Cit...
# 23                  Fellmeth, Aaron (Cited 376 times)
# 24                             Fellmeth, Aaron Xavier
#
#                                               Journal Cited (articles)  \
# 0   Stanford Law Review, Vol. 55, Issue 2 (Novembe...              115
# 1   Georgetown Law Journal, Vol. 94, Issue 1 (Nove...               58
# 2   University of San Francisco Law Review, Vol. 3...               32
# 3   Journal of Intellectual Property Law, Vol. 6, ...               28
# 4   William and Mary Law Review, Vol. 50, Issue 3 ...               26
# 5   Harvard International Law Journal, Vol. 45, Is...               20
# 6   American Journal of International Law, Vol. 10...               14
# 7   Texas International Law Journal, Vol. 43, Issu...               13
# 8   University of Illinois Law Review, Vol. 2006, ...               10
# 9   International Legal Materials, Vol. 50, Issue ...               10
# 10  Buffalo Journal of International Law, Vol. 3, ...               10
# 11  Human Rights Quarterly, Vol. 22, Issue 3 (2000...                9
# 12  Virginia Journal of Law & Technology, Vol. 6, ...                7
# 13  Yale Human Rights & Development Law Journal, V...                6
# 14  Yale Journal of International Law, Vol. 31, Is...                4
# 15  Yale Journal of International Law, Vol. 34, Is...                4
# 16  Israel Law Review, Vol. 45, Issue 1 (2012), pp...                3
# 17  International Legal Materials, Vol. 51, Issue ...                3
# 18  Journal of International Economic Law, Vol. 13...                2
# 19  North Carolina Journal of International Law an...                1
# 20  New York University Journal of Intellectual Pr...                1
# 21                                                 na               na
# 22  Minnesota Journal of International Law, Vol. 2...               na
# 23  Proceedings of the Annual Meeting, published b...               na
# 24  IPL Newsletter, Vol. 19, Issue 2 (Winter 2001)...               na
#
#    Cited (cases) Accessed                                             Topics
# 0             na        8   Intellectual Property Law, Science and Techno...
# 1              3       22   Jurisprudence, Practice and Procedure, Crimin...
# 2             na       13   Science and Technology, Computer Law, Intelle...
# 3             na       15   Torts, Intellectual Property Law, Trade Regul...
# 4             na       85   Education, Fair Credit, Fair Employment, Fair...
# 5             na       39   Food and Drug, Intellectual Property Law, Int...
# 6             na       11            Legislation, Comparative Law, Terrorism
# 7             na        9   Crimes Against Humanity, Military, War and Pe...
# 8              1        1   Jurisprudence, Practice and Procedure, Crimin...
# 9             na        5   Intellectual Property Law, International Trad...
# 10            na       20   Legal History, Politics, Legal Profession, Pr...
# 11            na       61                 Feminism, International Law, Women
# 12            na        4   Intellectual Property Law, Arbitration, Indus...
# 13            na        7   International Law, Jurisdiction, Torts, Human...
# 14            na        4   International Trade, Bankruptcy Law, Corporat...
# 15            na       10   Adoption, Homosexuality, Comparative Law, Ind...
# 16            na       10   Data Protection, Military Law, Human Rights, ...
# 17            na       12   International Law, First Amendment, Internati...
# 18            na       na   Dispute Resolution, Remedies, International T...
# 19            na       14   Human Rights Law, Military, War and Peace, Hu...
# 20            na        8   Intellectual Property Law, International Trad...
# 21            na       na   Comparative Law, Legal History, Terrorism, Cr...
# 22            na       19   Comparative Law, Legal History, Corporations,...
# 23            na        1   Communications Law, Conflict of Laws, Intelle...
# 24            na        6                                                 na

# %%
def split_name(full_name):
    space_count = full_name.count(' ')
    if space_count == 1:
        f_name = full_name.split(' ')[0] 
        last_name = full_name.split(' ')[1]
    elif space_count == 2:
        f_name = full_name.split(' ')[0] 
#                         m_name = full_name.split(' ')[1]
#         fm_name = f_name + ' ' + m_name
        last_name = full_name.split(' ')[2]
    elif space_count > 2:
        f_name = full_name.split(' ')[0] 
#                         m_name = full_name.split(' ')[1]
#         fm_name = f_name + ' ' + m_name
        last_name = ' '.join(full_name.split(' ')[2:])
    return f_name, last_name

# %%
def get_links(first_name, last_name, school_url, school_name):
    driver.get("https://scholar.google.com/citations?view_op=search_authors&mauthors=" +  first_name + '+' + last_name + "&hl=en&oi=ao")
    i = 1
    try:
        print(i)
        element = driver.find_element_by_xpath('//*[@id="gsc_sa_ccl"]/div[' + str(i) + ']/div/div/h3')
    except:
        element = []
    while element:
        full_name = element.text
        print(full_name)
        f_name, last_name = split_name(full_name)
        if last_name in full_name and f_name in full_name:
            affiliation = driver.find_element_by_xpath('//*[@id="gsc_sa_ccl"]/div[' + str(i) + ']/div/div/div[1]')
            print(affiliation.text.lower())
            if (school_name in affiliation.text.lower() or school_url in affiliation.text.lower()) and full_name not in correct_names:
                link_elm = driver.find_element_by_xpath('//*[@id="gsc_sa_ccl"]/div[' + str(i) + ']/div/div/h3/a')
                correct_name = (full_name, link_elm.get_attribute('href'))
                return correct_name
#             else:
#                 faculty = check_google(f_name, last_name, [school_url])
#                 if faculty and full_name not in correct_names:
#                     link_elm = driver.find_element_by_xpath('//*[@id="gsc_sa_ccl"]/div[' + str(i) + ']/div/div/h3/a')
#                     correct_name = (full_name, link_elm.get_attribute('href'))
#                     return correct_name
        i += 1
        try:
            element = driver.find_element_by_xpath('//*[@id="gsc_sa_ccl"]/div[' + str(i) + ']/div/div/h3')
        except:
            element = []

# %%
# element = driver.find_element_by_xpath('//*[@id="gsc_sa_ccl"]/div[' + str(i) + ']/div/div/h3')
element = driver.find_element_by_xpath('//*[@id="gsc_sa_ccl"]/div[1]/div/div/h3')
element.text
# Out:
# 'Kenneth W Abbott'

# %%
def create_path(*args):
    cur_path = os.getcwd()
    for value in args:
        cur_path  = os.path.join(cur_path, value)
    return cur_path

# %%
os.getcwd()
path = os.path.join(os.getcwd(), 'school_data')
files = os.listdir(path)
school_name = 'arizona'
school_url = 'asu'
for file in files[0:1]:
    main_df = pd.DataFrame(columns = ['Name', 'School', 'Link'])
    data = pd.read_csv(os.path.join(os.getcwd(), 'school_data', file))
    for i in range(len(data)):
        got_page = False
        mid_first_name = data['First Name'][i]
        last_name = data['Last Name'][i]
        full_name = mid_first_name + ' ' +  last_name
        school = data['School'][i]
        link = get_links(mid_first_name, last_name, school_url, school_name)
        print(link)
        driver.get('http://amazon.com')
        time.sleep(3)
        driver.get('http://facebook.com')
        time.sleep(3)
        if link:
            main_df = main_df.append(pd.DataFrame({'Name': [full_name], 'School': [school],'Link': [link[1]]}))
        else:
            main_df = main_df.append(pd.DataFrame({'Name': [full_name], 'School': [school],'Link': ['NA']}))
# Out:
# 1
# Kenneth W Abbott
# jack e brown chair in law emeritus, professor of global studies, arizona state university
# ('Kenneth W Abbott', 'https://scholar.google.com/citations?hl=en&user=hva7aGkAAAAJ')
# 1
# Angela D Banks
# university of san francisco
# Angela Abbate
# economist, swiss national bank
# None
# 1
# None
# 1
# Daniel Bodansky
# arizona state university
# ('Daniel Bodansky', 'https://scholar.google.com/citations?hl=en&user=bqmEUsQAAAAJ')
# 1
# Diana M Bowman
# arizona state university
# ('Diana M Bowman', 'https://scholar.google.com/citations?hl=en&user=wSvWb9MAAAAJ')
# 1
# Karen Lee Bradshaw
# associate professor, rhodes university
# Karen Bradshaw
# arizona state university, sandra day o'connor school of law
# ('Karen Bradshaw', 'https://scholar.google.com/citations?hl=en&user=WzTErjUAAAAJ')
# 1
# None
# 1
# Andrew Carter
# professor of earth sciences, birkbeck, university of london
# Elizabeth J. Carter
# carnegie mellon university
# Dorinda Carter Andrews
# associate dean for equity and inclusion and associate professor of teacher education …
# Andrew V Carter
# associate professor of statistics, uc santa barbara
# Andrew Carter
# teledyne scientific and imaging
# Andrew Carter
#
# Matt ID Carter
# sea mammal research unit, university of st andrews
# Andrew W. Nute
# data manager, the carter center
# Andy Carter
# digital projects archivist
# None
# 1
# None
# 1
# Adam Chodorow
# professor of law, arizona state university
# ('Adam Chodorow', 'https://scholar.google.com/citations?hl=en&user=X00PAi4AAAAJ')
# 1
# Jason Cohen
# associate professor of information systems, wits university
# Andrew Jason Cohen
# georgia state university
# Jason Cohen
# security researcher, hewlett packard enterprise labs
# Jason Cohn
# doctoral candidate in computer science, northwestern university
# None
# 1
# Maria Eveline de Castro Pereira
# comissão interna de biossegurança, instituto oswaldo cruz, fundação oswaldo cruz
# MONICA EVELYN JUAREZ DE LA CRUZ
# universidad nacional de san martín - tarapoto
# None
# 1
# None
# 1
# None
# 1
# None
# 1
# None
# 1
# None
# 1
# David K Gardner
# distinguished professor, school of biosciences, university of melbourne
# David S. Gardner
# professor of physiology
# David Gardner
# hong kong university
# David Gardner
# loughborough university
# David W Gardner
# university of california, berkeley
# David J. Gardner
# lawrence livermore national laboratory
# None
# 1
# None
# 1
# None
# 1
# None
# 1
# None
# 1
# None
# 1
# James W. Hodge
# national cancer institute, nih
# James JL Hodge
# lecturer in pharmacology, bristol university
# James M. Hodges
# northwestern university
# James Hodge
# openlab, newcastle university
# James A. Hodges
# school of communication & information, rutgers university
# None
# 1
# Kimberly Holst
# mayo clinic
# None
# 1
# None
# 1
# None
# 1
# None
# 1
# None
# 1
# None
# 1
# Eric Oliver Luna González
# uam
# Sekitoleko Eric
# mountains of the moon university
# None
# 1
# None
# 1
# Gary Marchant
# arizona state university
# ('Gary Marchant', 'https://scholar.google.com/citations?hl=en&user=zte3RKUAAAAJ')
# 1
# None
# 1
# robert miller
# adjunct prof. material science 7 engineering, stanford university
# Robert C. Miller
# professor, computer science, mit
# Robert P Millar
# university of pretoria, university of cape town, university of edinburgh, university of st …
# Robert F Stambaugh
# miller anderson & sherrerd professor of finance, the wharton school, university of …
# Robert M. Starke MD, MSc
# department of neurosurgery & radiology, miami miller school of medicine, miami university …
# Robert Miller
# mayo
# Robert W. Keane
# professor of physiology and biophysics, university of miami miller school of medicine
# Robert A. Miller
# professor of economics and strategy, carnegie mellon university
# Robert D. Miller
# professor of biology, university of new mexico
# Robert Miller
# university of california santa barbara, marine science institute
# None
# 1
# Jeffrey N. Murphy
# eindhoven university of technology
# Jeffrey C Murphy
# university at buffalo
# None
# 1
# None
# 1
# None
# 1
# Troy Rule
# professor of law, asu sandra day o'connor college of law
# ('Troy Rule', 'https://scholar.google.com/citations?hl=en&user=4VfZj7IAAAAJ')
# 1
# Michael Sacks
# professor of biomedical engineering, unversity of texas at austin
# Michael J. Saks
# arizona state university
# ('Michael J. Saks', 'https://scholar.google.com/citations?hl=en&user=Nw_8OD4AAAAJ')
# 1
# None
# 1
# None
# 1
# None
# 1
# None

# %%
main_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a7bf8065ec73> in <module>
# ----> 1 main_df
#
# NameError: name 'main_df' is not defined
