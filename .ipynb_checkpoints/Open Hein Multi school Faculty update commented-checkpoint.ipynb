# %%
from selenium import webdriver
import pandas as pd
import bs4 as bs
import os
import numpy as np
import re
import time
from selenium.webdriver.common.keys import Keys
import nltk
import requests
import random
import math

# %% [markdown]
# webdriver.Chrome() opens the automated Chrome window that the code manipulates
# driver.get(url) directs the webdriver to a page. The driver 'driver' is used for the Hein pages.
# The driver 'g_driver' will be used for searching names on Bing

# %%
driver = webdriver.Chrome()
driver.get("http://proxy.its.virginia.edu/login?url=http://heinonline.org/HOL/Welcome")
g_driver = webdriver.Chrome()

# %% [markdown]
# Hein requres you to log into your UVa account. This cell send the user name and password so that you can automatically login. DUO two step authentication is still required. You will have to enter that manually.

# %%
username = 'uva_username'
password = 'uva_password'
driver.find_element_by_id("user").send_keys(username);
driver.find_element_by_id("pass").send_keys(password);
driver.find_element_by_xpath("/html/body/main/div[2]/fieldset/form/input").click()

# %% [markdown]
# After you have logged in, Selenium is able to navigate to any webpage. We will navigate to the pages on the list:

# %% [markdown]
# If there is no middle name, a more famous person with the same first and last name will
#     be at the top of the search results, so we need to add the school name
#     In this case it will be ambiguous is another professor with the same first and last name
#     is in Hein anyway, so there is really no good way to tell if we are getting the wrong one.
#     If they have a middle initial, I assume there is not another professor using the same exact name
#     at a different school. Therefore, to avoid conflict with more famous people, I use the school name
#     in the search

# %%
def create_path(*args):
    cur_path = os.getcwd()
    for value in args:
        cur_path  = os.path.join(cur_path, value)
    return cur_path

# %% [markdown]
# This cell modifies the input dataframe. The input dataframe is data (the Excel file is 'Professor names.xlsx').

# %%
data = pd.read_excel(create_path('Professor Names.xlsx'))

# %% [markdown]
# If this dataframe doesn't have a column with ID values, one is created and appended to the end. The dataframe is saved with the new ID values

# %%
if not 'id' in data.columns:
    data.insert(len(data.columns), 'id', random.sample(range(10000), len(data)), True)   
    data.to_excel(create_path('Professor Names.xlsx'))

# %% [markdown]
# This section creates the data for each section of the dataframe.
#
# fm_name is the combined first and middle name
#
# last_name is the last name
#
# title would be the professor's position (e.g., associate professor)
#
# This is all combined into a new dataframe called new_data

# %%
name_tuple = list(zip(data.First, data.Middle, data.Last))
fm_name = [x[0] + ' ' +  x[1]  if isinstance(x[1], str)  else x[0] for x in name_tuple ]
last_name = [x[2] for x in name_tuple ]
title = ['NA']*len(last_name)
new_data = pd.DataFrame({'First Name': fm_name, 'Last Name': last_name, 'Title': title, 'School': data.Former, 'New School': data.Current, 'ID': data.id})

# %%
new_data
# Out:
#           First Name    Last Name Title  \
# 0            Richard       Albert    NA
# 1             Hilary        Allen    NA
# 2       Olufunmilayo        Arewa    NA
# 3          Khaled A.      Beydoun    NA
# 4             Joshua        Blank    NA
# 5            William         Boyd    NA
# 6             Samuel         Bray    NA
# 7           Jennifer       Chacon    NA
# 8             Anupam      Chander    NA
# 9            Stewart        Chang    NA
# 10           Jessica       Clarke    NA
# 11        Frank Rudy       Cooper    NA
# 12              Seth        Davis    NA
# 13        Melissa J.       Durkee    NA
# 14             Atiba        Ellis    NA
# 15            Victor    Fleischer    NA
# 16             David     Franklyn    NA
# 17              Nuno      Garoupa    NA
# 18           Brandon      Garrett    NA
# 19            Andrew         Gold    NA
# 20            Philip      Hackney    NA
# 21       Christopher       Holman    NA
# 22            Robert      Jackson    NA
# 23             Dalie      Jimenez    NA
# 24           Kristin      Johnson    NA
# 25           Michael         Kang    NA
# 26              Orin         Kerr    NA
# 27            Eugene  Kontorovich    NA
# 28           Rebecca        Kysar    NA
# 29       Jill Wieber         Lens    NA
# ..               ...          ...   ...
# 290             Jill      Horwitz    NA
# 291         Shi-Ling          Hsu    NA
# 292             Jody        Kraus    NA
# 293         Francine       Lipman    NA
# 294         Jonathan       Lipson    NA
# 295       Jacqueline       Lipton    NA
# 296           Thomas         Main    NA
# 297           Calvin       Massey    NA
# 298            Jason      Mazzone    NA
# 299           Robert       Miller    NA
# 300        Edward R.     Morrison    NA
# 301         Victoria       Nourse    NA
# 302           Rafael        Pardo    NA
# 303           Edward       Parson    NA
# 304     H. Jefferson       Powell    NA
# 305          Dana A.        Remus    NA
# 306          L. Song   Richardson    NA
# 307          Dorothy      Roberts    NA
# 308              Jim        Rossi    NA
# 309             Adam       Samaha    NA
# 310             Lynn        Stout    NA
# 311             Alan        Sykes    NA
# 312           Andrew      Taslitz    NA
# 313           Amanda        Tyler    NA
# 314        Katharine   Van Tassel    NA
# 315           Gideon        Yaffe    NA
# 316           Sandra      Zellmer    NA
# 317          Stephen      Vladeck    NA
# 182  Steven Davidoff      Solomon    NA
# 240          Miranda        Perry    NA
#
#                                                 School  \
# 0                                       Boston College
# 1                                   Suffolk University
# 2                     University of California, Irvine
# 3            University of Detroit Mercy School of Law
# 4                                  New York University
# 5                      University of Colorado, Boulder
# 6                University of California, Los Angeles
# 7                     University of California, Irvine
# 8                      University of California, Davis
# 9                                  Whittier Law School
# 10                             University of Minnesota
# 11                                  Suffolk University
# 12                    University of California, Irvine
# 13                   University of Washington, Seattle
# 14                            West Virginia University
# 15                             University of San Diego
# 16                         University of San Francisco
# 17                                Texas A&M University
# 18                              University of Virginia
# 19                                   DePaul University
# 20                          Louisiana State University
# 21                 University of Missouri, Kansas City
# 22                                 Columbia University
# 23                           University of Connecticut
# 24                               Seton Hall University
# 25                                    Emory University
# 26                        George Washington University
# 27                             Northwestern University
# 28                                 Brooklyn Law School
# 29                                   Baylor University
# ..                                                 ...
# 290                             University of Michigan
# 291                     University of British Columbia
# 292                         University of Pennsylvania
# 293                                 Chapman University
# 294                   University of Wisconsin, Madison
# 295                    Case Western Reserve University
# 296  McGeorge School of Law, University of the Pacific
# 297                 University of California, Hastings
# 298                                Brooklyn Law School
# 299                               Villanova University
# 300                                Columbia University
# 301                   University of Wisconsin, Madison
# 302                University of Washington at Seattle
# 303                             University of Michigan
# 304                       George Washington University
# 305                        University of New Hampshire
# 306                                American University
# 307                            Northwestern University
# 308                           Florida State University
# 309                              University of Chicago
# 310            University of California at Los Angeles
# 311                                Stanford University
# 312                                  Howard University
# 313                       George Washington University
# 314                   St. Thomas University (Florida)
# 315                  University of Southern California
# 316                    University of Nebraska, Lincoln
# 317                                American University
# 182                              Ohio State University
# 240                    University of Colorado, Boulder
#
#                                 New School    ID
# 0              University of Texas, Austin    46
# 1                      American University   832
# 2                        Temple University  2248
# 3     University of Arkansas, Fayetteville   656
# 4         University of California, Irvine  7894
# 5    University of California, Los Angeles   301
# 6                 University of Notre Dame  2493
# 7    University of California, Los Angeles  2814
# 8                    Georgetown University  8807
# 9          University of Nevada, Las Vegas  1723
# 10                   Vanderbilt University  9893
# 11         University of Nevada, Las Vegas  1824
# 12      University of California, Berkeley  6296
# 13                   University of Georgia  6667
# 14                    Marquette University    74
# 15        University of California, Irvine  6793
# 16                  Golden Gate University  3743
# 17                 George Mason University  2171
# 18                         Duke University  5069
# 19                     Brooklyn Law School  7402
# 20                University of Pittsburgh  7046
# 21                        Drake University  8826
# 22                     New York University  5470
# 23        University of California, Irvine   217
# 24                       Tulane University  3590
# 25                 Northwestern University  4133
# 26       University of Southern California  6675
# 27                 George Mason University  1180
# 28                      Fordham University  1104
# 29    University of Arkansas, Fayetteville  5384
# ..                                     ...   ...
# 290  University of California, Los Angeles  7499
# 291               Florida State University  5670
# 292                    Columbia University  1100
# 293        University of Nevada, Las Vegas  8223
# 294                      Temple University  8230
# 295                  University of Houston  2118
# 296        University of Nevada, Las Vegas  5728
# 297            University of New Hampshire  4588
# 298                 University of Illinois  3833
# 299                     University of Iowa  1459
# 300                  University of Chicago  1863
# 301                  Georgetown University  9064
# 302                       Emory University  9014
# 303  University of California, Los Angeles  3957
# 304                        Duke University  1038
# 305                      Drexel University  9387
# 306                     University of Iowa  2780
# 307             University of Pennsylvania  2123
# 308                  Vanderbilt University    13
# 309                    New York University  7437
# 310                     Cornell University  8860
# 311                    New York University   956
# 312                    American University  6176
# 313     University of California, Berkeley  6066
# 314                    University of Akron  4704
# 315                        Yale University   555
# 316                  University of Montana  7177
# 317            University of Texas, Austin  4898
# 182     University of California, Berkeley  7669
# 240                University of San Diego  4193
#
# [314 rows x 6 columns]

# %%
def get_school_urls(urls_df, school_list):
    url_list = []
    for school_name in school_list:
        #Remove commas from the unversity name (e.g., University of Texas, Austin becomes University of Texas Austin)
        school_name = school_name.replace(',', '')
        #This try section attempts to find the school name in the dataframe of university URLs. If it does not find it, 
        #it goes to the except section. It would be better to write a specific exception to reduce the possibility of 
        #errors
        try: 
            #This line searches for the index of the school name in the dataframe
            index = urls_df[urls_df['School Name'] == school_name].index[0]
            #This line finds the url associated with the school at that index
            url_name = urls_df['URL'][index]
            #This line prints the school name and URL
            print('found school: {} with url {}'.format(school_name, url_name))
            #The url is appended to the list of URLs
            url_list.append(url_name)
        #In the except section, the school name is serached on Google. The Selenium code find the URL on the page and saves it 
        #as the university url
        except:
            #Navigates the g_driver to Google.com
            g_driver.get("http://google.com")
            #This section is webpage manipulation. The first line finds the search box, the second line enters the school name
            #the third line presses enter
            search = g_driver.find_element_by_name('q')
            search.send_keys(school_name)
            search.send_keys(Keys.RETURN)
            #This section finds the first url that comes up on a Google search
            #find_elements_by_xpath finds specific elements on a webpages The three xpaths were found using trial and error
            #Sometimes Google includes a map or some other element before the first search result, so this handles those cases
            element = g_driver.find_elements_by_xpath('//*[@id="rso"]/div[1]/div/div[1]/div/div/div[1]/a/div/cite')
            if not element:
                element = g_driver.find_elements_by_xpath('//*[@id="rso"]/div[1]/div/div/div/div[1]/a/div/cite')
                if not element: 
                    element = g_driver.find_elements_by_xpath('//*[@id="rso"]/div[2]/div/div/div/div/div[1]/a/div/cite')
            #This section extracts the name of the url
            for elm in element:
                print(elm.text)
                url_name = elm.text
            #The url is appended to the list of URLs
            url_list.append(url_name)
            #This line prints the school name and URL
            print('Creating entry for {} with url {}'.format(school_name, url_name))
            #This line updates the URL dataframe to include an entry with the school name and URL. The next time to code
            #runs, it shouldn't have to search for the school name
            urls_df = urls_df.append(pd.DataFrame({'School Name': [school_name], 'URL': [url_name]}), ignore_index=True, sort = False)
            #This section natavigates away from Google. I did this to avoid triggering the Captcha, but it doesn't work consistantly
            #For the main code, I used Bing because Bing doesn't have a Captcha
            g_driver.get("http://amazon.com")
            time.sleep(3)
            g_driver.get("http://facebook.com")  
    #This line saves name updates to 'University and College Websites update.csv'
    urls_df.to_csv(create_path('University and College Websites update.csv'), index=False)
    return url_list

def short_url(data):
    url_list = []
    for url in data:
        if '.edu' in url:
            end = '.edu'
        elif '.ca' in url:
            end = '.ca'
        elif '.ac.uk' in url:
            end = '.ac.uk'
        elif '.hk' in url:
            end = '.hk'
        elif '.ac.il' in url:
            end = '.ac.il'
        elif '.yu' in url:
            end = '.yu'
        if 'https://www.' in url:
            new_url = url.split('https://www.')[1].split(end)[0]
        elif 'http://www.' in url:
            new_url = url.split('http://www.')[1].split(end)[0]
        elif 'https://www1.' in url:
            new_url = url.split('https://www1.')[1].split(end)[0]
        elif 'https://www2.' in url:
            new_url = url.split('https://www2.')[1].split(end)[0]
        elif 'www.' in url:
            new_url = url.split('www.')[1].split(end)[0]
        elif 'https://' in url:
            new_url = url.split('https://')[1].split(end)[0]
        elif 'http://' in url:
            new_url = url.split('http://')[1].split(end)[0]
        url_list.append(new_url+end)
    return url_list

# %% [markdown]
# The code varifies professor identities by searching their name on Bing and checking to see if their university URL shows up in the search results. We need a URL for each university on the list of professors to be able to do this.
#
# The url names are found using the function get_school_urls. This function attempts to find the url in a list of university websites The variable urls from the CSV 'University and College Websites update.csv' is a list of university websites from the internet.
#
# Unfortunately, there are lots of different ways to render the same university name (e.g., UCLA, University of California LA, U Cal. LA), so direct string matching often fails.
#
# In this case, the code searches for the name on Google and finds the first result. See the comments on get_school_urls for a full description
#
# The function get_school_urls returns a list of school URLs, but we don't want the full URL. The protocol identifier is removed using short_urls

# %%
urls = pd.read_csv(create_path('University and College Websites update.csv'))
url_list = get_school_urls(urls, new_data['School'])
#This line inserts the urls into the full dataframe
new_data.insert(4, "School URL", url_list) 
# The function returns the short version of the URLs
url_list = short_url(new_data['School URL'])
# This line inserts the short version of the URLs into the dataframe
new_data.insert(5, "School URL short", url_list)
#This section repeats the same steps for the second set of schools
print('First half complete')
url_list = get_school_urls(urls, new_data['New School'])
new_data.insert(7, "New School URL", url_list) 
url_list = short_url(new_data['New School URL'])
new_data.insert(8, "New School URL short", url_list) 
new_data.head()
# Out:
# found school: Boston College with url http://bc.edu
# found school: Suffolk University with url http://suffolk.edu
# found school: University of California Irvine with url http://uci.edu
# found school: University of Detroit Mercy School of Law with url www.law.udmercy.edu/
# found school: New York University with url http://nyu.edu
# found school: University of Colorado Boulder with url http://colorado.edu
# found school: University of California Los Angeles with url http://ucla.edu
# found school: University of California Irvine with url http://uci.edu
# found school: University of California Davis with url http://ucdavis.edu
# found school: Whittier Law School with url https://www.law.whittier.edu/
# found school: University of Minnesota with url http://umn.edu
# found school: Suffolk University with url http://suffolk.edu
# found school: University of California Irvine with url http://uci.edu
# found school: University of Washington Seattle with url https://www.washington.edu/
# found school: West Virginia University with url http://wvu.edu
# found school: University of San Diego with url http://sandiego.edu
# found school: University of San Francisco with url http://usfca.edu
# found school: Texas A&M University with url http://tamu.edu
# found school: University of Virginia with url http://virginia.edu
# found school: DePaul University with url http://depaul.edu
# found school: Louisiana State University with url http://lsu.edu
# found school: University of Missouri Kansas City with url http://umkc.edu
# found school: Columbia University with url http://columbia.edu
# found school: University of Connecticut with url http://uconn.edu
# found school: Seton Hall University with url http://shu.edu
# found school: Emory University with url http://emory.edu
# found school: George Washington University with url https://www.gwu.edu/
# found school: Northwestern University with url http://northwestern.edu
# found school: Brooklyn Law School with url http://northwestern.edu
# found school: Baylor University with url http://baylor.edu
# found school: Catholic University with url https://www.catholic.edu/index.html
# found school: University of Arizona with url http://arizona.edu
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: Columbia University with url http://columbia.edu
# found school: Barry University with url http://barry.edu
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: University of Miami with url http://miami.edu
# found school: University of San Diego with url http://sandiego.edu
# found school: Duke University with url http://duke.edu
# found school: Florida Coastal Law School with url https://www.fcsl.edu/index.php
# found school: Washington University St. Louis with url https://wustl.edu/
# found school: University of California Davis with url http://ucdavis.edu
# found school: Universities of Helsinki & Eastern Finland with url www.uef.fi/en/etusivu
# found school: University of California Davis with url http://ucdavis.edu
# found school: University of Kentucky with url www.uky.edu/
# found school: Drexel University with url http://drexel.edu
# found school: Case Western Reserve University with url http://case.edu
# found school: University of Nebraska Lincoln with url https://www.unl.edu/
# found school: Texas A&M University with url http://tamu.edu
# found school: Washington University St. Louis with url https://wustl.edu/
# found school: University of Hawaii with url https://www.hawaii.edu/
# found school: College of William & Mary with url https://wm.edu/
# found school: Columbia University with url http://columbia.edu
# found school: University of North Carolina Chapel Hill  with url https://www.unc.edu/
# found school: George Washington University with url https://www.gwu.edu/
# found school: Washington & Lee University with url https://www.wlu.edu/
# found school: Widener University Commonwealth with url https://commonwealthlaw.widener.edu/
# found school: University of California Irvine with url http://uci.edu
# found school: University of North Carolina Chapel Hill with url https://www.unc.edu/
# found school: Fordham University with url http://fordham.edu
# found school: Yeshiva University with url http://yu.edu
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: Seton Hall University with url http://shu.edu
# found school: University of Idaho with url http://uidaho.edu
# found school: University of Tulsa with url http://utulsa.edu
# found school: Cumberland School of Law Samford University with url https://www.samford.edu/cumberlandlaw/
# found school: University of Colorado Boulder with url http://colorado.edu
# found school: University of California Los Angeles with url http://ucla.edu
# found school: Temple University with url http://temple.edu
# found school: Southern Illinois University with url http://siu.edu
# found school: University of Iowa with url https://uiowa.edu/
# found school: Louisiana State University with url http://lsu.edu
# found school: Cleveland-Marshall College of Law with url https://www.law.csuohio.edu/
# found school: George Washington University with url https://www.gwu.edu/
# found school: University of Illinois with url http://illinois.edu
# found school: University of Southern California with url http://usc.edu
# found school: University of Colorado Boulder with url http://colorado.edu
# found school: Tulane University with url http://tulane.edu
# found school: McGill University with url https://www.mcgill.ca/
# found school: Creighton University with url http://creighton.edu
# found school: Harvard University with url http://harvard.edu
# found school: Loyola Law School Los Angeles with url https://www.lls.edu/
# found school: University of California Los Angeles with url http://ucla.edu
# found school: Tulane University with url http://tulane.edu
# found school: University of Minnesota with url http://umn.edu
# found school: Indiana University Indianapolis with url https://www.iupui.edu/
# found school: University of San Diego with url http://sandiego.edu
# found school: Seton Hall University with url http://shu.edu
# found school: Washington & Lee University with url https://www.wlu.edu/
# found school: Seton Hall University with url http://shu.edu
# found school: University of Wisconsin Madison with url https://www.wisc.edu/
# found school: Universities of Helsinki & Eastern Finland with url www.uef.fi/en/etusivu
# found school: Florida State University with url http://fsu.edu
# found school: Georgetown University with url http://georgetown.edu
# found school: University of Akron with url https://www.uakron.edu/
# found school: Emory University with url http://emory.edu
# found school: University of California Davis with url http://ucdavis.edu
# found school: Pennsylvania State University Dickinson School of Law (Carlysle) with url https://dickinsonlaw.psu.edu/
# found school: Valparaiso University with url http://valpo.edu
# found school: Ava Maria School of Law with url https://www.avemarialaw.edu/
# found school: University of Wisconsin Madison with url https://www.wisc.edu/
# found school: Brigham Young University with url http://byu.edu
# found school: University of Virginia with url http://virginia.edu
# found school: University of Minnesota with url http://umn.edu
# found school: Southwestern Law School with url https://www.swlaw.edu/
# found school: Northwestern University with url http://northwestern.edu
# found school: Northwestern University with url http://northwestern.edu
# found school: Washington & Lee University with url https://www.wlu.edu/
# found school: University of Wisconsin Madison with url https://www.wisc.edu/
# found school: University of Maryland with url http://umaryland.edu
# found school: Hofstra University with url http://hofstra.edu
# found school: Hofstra University with url http://hofstra.edu
# found school: University of Utah with url http://utah.edu
# found school: University of Utah with url http://utah.edu
# found school: University of Illinois with url http://illinois.edu
# found school: Marquette University with url http://marquette.edu
# found school: Michigan State University with url http://msu.edu
# found school: University of California Irvine with url http://uci.edu
# found school: Pace University with url http://pace.edu
# found school: University of Nevada Las Vegas with url http://unlv.edu
# found school: University of Wisconsin Madison with url https://www.wisc.edu/
# found school: University of Iowa with url https://uiowa.edu/
# found school: Seton Hall University with url http://shu.edu
# found school: University of North Carolina Chapel Hill with url https://www.unc.edu/
# found school: University of Pennsylvania with url http://upenn.edu
# found school: University of Colorado Boulder with url http://colorado.edu
# found school: Harvard University with url http://harvard.edu
# found school: Cardozo Law School with url https://cardozo.yu.edu/
# found school: Suffolk University with url http://suffolk.edu
# found school: American University with url http://american.edu
# found school: Texas A&M University with url http://tamu.edu
# found school: University of Illinois with url http://illinois.edu
# found school: Cardozo Law School with url https://cardozo.yu.edu/
# found school: University of Oklahoma Norman with url www.ou.edu/
# found school: Pace University with url http://pace.edu
# found school: Northwestern University with url http://northwestern.edu
# found school: University of Houston with url www.uh.edu/
# found school: Chicago-Kent College of Law with url www.uh.edu/
# found school: Marquette University with url http://marquette.edu
# found school: University of California Hastings with url https://www.uchastings.edu/
# found school: Hofstra University with url http://hofstra.edu
# found school: Boston College with url http://bc.edu
# found school: University of Illinois with url http://illinois.edu
# found school: Columbia University with url http://columbia.edu
# found school: University of Florida Gainesville with url www.ufl.edu/
# found school: Fordham University with url http://fordham.edu
# found school: Michigan State University with url http://msu.edu
# found school: University of Illinois with url http://illinois.edu
# found school: Washington & Lee University with url https://www.wlu.edu/
# found school: Tulane University with url http://tulane.edu
# found school: Albany Law School with url https://www.albanylaw.edu/
# found school: Florida State University with url http://fsu.edu
# found school: University of Southern California with url http://usc.edu
# found school: Indiana University Bloomington with url http://iub.edu
# found school: University of Georgia with url http://uga.edu
# found school: University of California Irvine with url http://uci.edu
# found school: University of Colorado Boulder with url http://colorado.edu
# found school: University of Maine with url http://umaine.edu
# found school: Boston College with url http://bc.edu
# found school: Northwestern University  with url https://www.northwestern.edu/
# found school: Regent University with url http://regent.edu
# found school: University of Oklahoma Norman with url www.ou.edu/
# found school: Lewis & Clark College with url https://www.lclark.edu/
# found school: Duke University with url http://duke.edu
# found school: Chicago-Kent College of Law with url www.uh.edu/
# found school: Suffolk University with url http://suffolk.edu
# found school: Boston University with url http://bu.edu
# found school: New York University with url http://nyu.edu
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: Drake University with url http://drake.edu
# found school: Georgetown University with url http://georgetown.edu
# found school: New York University with url http://nyu.edu
# found school: University of Texas Austin with url https://www.utexas.edu/
# found school: Emory University with url http://emory.edu
# found school: Seton Hall University with url http://shu.edu
# found school: University of Kentucky with url www.uky.edu/
# found school: University of Wisconsin Madison with url https://www.wisc.edu/
# found school: American University with url http://american.edu
# found school: Ohio State University with url http://osu.edu
# found school: University of Illinois with url http://illinois.edu
# found school: Georgetown University with url http://georgetown.edu
# found school: University of Texas Austin with url https://www.utexas.edu/
# found school: University of Southern California with url http://usc.edu
# found school: Rutgers University Camden with url https://www.camden.rutgers.edu/
# found school: University of Minnesota Twin Cities with url https://twin-cities.umn.edu/
# found school: University of Connecticut with url http://uconn.edu
# found school: Wake Forest University with url http://wfu.edu
# found school: University of Chicago with url http://uchicago.edu
# found school: Santa Clara University with url http://scu.edu
# found school: Texas Tech University with url http://ttu.edu
# found school: University of Illinois with url http://illinois.edu
# found school: University of Wisconsin Madison with url https://www.wisc.edu/
# found school: University of Pittsburgh with url http://pitt.edu
# found school: University of Notre Dame with url http://nd.edu
# found school: Boston University with url http://bu.edu
# found school: University of the Pacific McGeorge School of Law with url https://www.mcgeorge.edu/
# found school: University of Houston with url www.uh.edu/
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: University of Connecticut with url http://uconn.edu
# found school: University of Chicago with url http://uchicago.edu
# found school: Columbia University  with url https://www.columbia.edu/
# found school: Southern Methodist University with url http://smu.edu
# found school: University of North Carolina Chapel Hill with url https://www.unc.edu/
# found school: Rutgers University Camden with url https://www.camden.rutgers.edu/
# found school: New York University with url http://nyu.edu
# found school: University of Maryland with url http://umaryland.edu
# found school: University of Iowa with url https://uiowa.edu/
# found school: University of Akron with url https://www.uakron.edu/
# found school: University of Missouri with url https://missouri.edu/
# found school: University of Minnesota Twin Cities with url https://twin-cities.umn.edu/
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: Washington & Lee University with url https://www.wlu.edu/
# found school: University of Illinois with url http://illinois.edu
# found school: Seton Hall University with url http://shu.edu
# found school: Northwestern University with url http://northwestern.edu
# found school: University of Melbourne with url https://www.unimelb.edu.au/
# found school: University of California Irvine with url http://uci.edu
# found school: University of Texas Austin with url https://www.utexas.edu/
# found school: DePaul University with url http://depaul.edu
# found school: Northwestern University with url http://northwestern.edu
# found school: Saint Louis University with url http://slu.edu
# found school: University of California Davis with url http://ucdavis.edu
# found school: Yale University with url http://yale.edu
# found school: University of San Diego with url http://sandiego.edu
# found school: College of William and Mary with url http://sandiego.edu
# found school: University of Missouri Kansas City with url http://umkc.edu
# found school: University of Cincinnati with url http://uc.edu
# found school: University of Louisville with url louisville.edu/
# found school: Creighton Universitiy with url https://www.creighton.edu/
# found school: Pace University with url http://pace.edu
# found school: University of Denver Sturm College of Law with url https://www.law.du.edu/
# found school: Syracuse University with url http://syr.edu
# found school: Vermont Law School with url http://vermontlaw.edu
# found school: Seattle University with url http://seattleu.edu
# found school: University of Colorado Boulder with url http://colorado.edu
# found school: Fordham University with url http://fordham.edu
# found school: New York Law School with url http://fordham.edu
# found school: Albany Law School with url https://www.albanylaw.edu/
# found school: University of Houston with url www.uh.edu/
# found school: Florida State University with url http://fsu.edu
# found school: American University with url http://american.edu
# found school: John Marshall Law School (Atlanta)  with url http://american.edu
# found school: University of Texas Austin with url https://www.utexas.edu/
# found school: University of Richmond with url http://richmond.edu
# found school: University of Connecticut with url http://uconn.edu
# found school: University of San Diego with url http://sandiego.edu
# found school: University of San Diego with url http://sandiego.edu
# found school: University of Southern California with url http://usc.edu
# found school: Cornell University with url http://cornell.edu
# found school: University of Cincinnati with url http://uc.edu
# found school: University of California Hastings with url https://www.uchastings.edu/
# found school: Loyola Law School Los Angeles with url https://www.lls.edu/
# found school: Brooklyn Law School with url http://northwestern.edu
# found school: Seton Hall University with url http://shu.edu
# found school: Cornell University with url http://cornell.edu
# found school: Columbia University with url http://columbia.edu
# found school: Southern Methodist University with url http://smu.edu
# found school: New York University with url http://nyu.edu
# found school: University of Amsterdam with url https://www.uva.nl/en
# found school: Brooklyn Law School with url http://northwestern.edu
# found school: University of California Hastings with url https://www.uchastings.edu/
# found school: University of Texas Austin with url https://www.utexas.edu/
# found school: University of Virginia with url http://virginia.edu
# found school: Seattle University with url http://seattleu.edu
# found school: Ohio State University with url http://osu.edu
# found school: Washington & Lee University with url https://www.wlu.edu/
# found school: University of Pennsylvania with url http://upenn.edu
# found school: Rutgers University at Newark with url https://www.newark.rutgers.edu/
# found school: University of Chicago with url http://uchicago.edu
# found school: University of Mississippi with url https://olemiss.edu/
# found school: University of Virginia with url http://virginia.edu
# found school: George Washington University with url https://www.gwu.edu/
# found school: University of Wisconsin at Madison with url https://www.wisc.edu/
# found school: University of Virginia with url http://virginia.edu
# found school: College of William & Mary with url https://wm.edu/
# found school: University of Southern California with url http://usc.edu
# found school: Vanderbilt University with url http://vanderbilt.edu
# found school: Southwestern Law School with url https://www.swlaw.edu/
# found school: Albany Law School with url https://www.albanylaw.edu/
# found school: University of Houston with url www.uh.edu/
# found school: University of Houston with url www.uh.edu/
# found school: University of Maryland with url http://umaryland.edu
# found school: University of Tennessee with url https://www.utk.edu/
# found school: University of Michigan with url http://umich.edu
# found school: University of British Columbia with url https://www.ubc.ca/
# found school: University of Pennsylvania with url http://upenn.edu
# found school: Chapman University with url http://chapman.edu
# found school: University of Wisconsin Madison with url https://www.wisc.edu/
# found school: Case Western Reserve University with url http://case.edu
# found school: McGeorge School of Law University of the Pacific with url https://www.mcgeorge.edu/
# found school: University of California Hastings with url https://www.uchastings.edu/
# found school: Brooklyn Law School with url http://northwestern.edu
# found school: Villanova University with url http://villanova.edu
# found school: Columbia University with url http://columbia.edu
# found school: University of Wisconsin Madison with url https://www.wisc.edu/
# found school: University of Washington at Seattle with url https://www.washington.edu/
# found school: University of Michigan with url http://umich.edu
# found school: George Washington University with url https://www.gwu.edu/
# found school: University of New Hampshire with url http://unh.edu
# found school: American University with url http://american.edu
# found school: Northwestern University with url http://northwestern.edu
# found school: Florida State University with url http://fsu.edu
# found school: University of Chicago with url http://uchicago.edu
# found school: University of California at Los Angeles with url www.ucla.edu/
# found school: Stanford University with url http://stanford.edu
# found school: Howard University with url http://howard.edu
# found school: George Washington University with url https://www.gwu.edu/
# found school: St. Thomas University (Florida)  with url https://www.stu.edu/
# found school: University of Southern California with url http://usc.edu
# found school: University of Nebraska Lincoln with url https://www.unl.edu/
# found school: American University with url http://american.edu
# found school: Ohio State University with url http://osu.edu
# found school: University of Colorado Boulder with url http://colorado.edu
# First half complete
# found school: University of Texas Austin with url https://www.utexas.edu/
# found school: American University with url http://american.edu
# found school: Temple University with url http://temple.edu
# found school: University of Arkansas Fayetteville with url https://www.uark.edu/
# found school: University of California Irvine with url http://uci.edu
# found school: University of California Los Angeles with url http://ucla.edu
# found school: University of Notre Dame with url http://nd.edu
# found school: University of California Los Angeles with url http://ucla.edu
# found school: Georgetown University with url http://georgetown.edu
# found school: University of Nevada Las Vegas with url http://unlv.edu
# found school: Vanderbilt University with url http://vanderbilt.edu
# found school: University of Nevada Las Vegas with url http://unlv.edu
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: University of Georgia with url http://uga.edu
# found school: Marquette University with url http://marquette.edu
# found school: University of California Irvine with url http://uci.edu
# found school: Golden Gate University with url https://www.ggu.edu/
# found school: George Mason University with url http://gmu.edu
# found school: Duke University with url http://duke.edu
# found school: Brooklyn Law School with url http://northwestern.edu
# found school: University of Pittsburgh with url http://pitt.edu
# found school: Drake University with url http://drake.edu
# found school: New York University with url http://nyu.edu
# found school: University of California Irvine with url http://uci.edu
# found school: Tulane University with url http://tulane.edu
# found school: Northwestern University with url http://northwestern.edu
# found school: University of Southern California with url http://usc.edu
# found school: George Mason University with url http://gmu.edu
# found school: Fordham University with url http://fordham.edu
# found school: University of Arkansas Fayetteville with url https://www.uark.edu/
# found school: University of Colorado Boulder with url http://colorado.edu
# found school: University of California Los Angeles with url http://ucla.edu
# found school: Columbia University with url http://columbia.edu
# found school: Stanford University with url http://stanford.edu
# found school: Indiana University Indianapolis with url https://www.iupui.edu/
# found school: New York University with url http://nyu.edu
# found school: Stanford University with url http://stanford.edu
# found school: University of North Carolina Chapel Hill with url https://www.unc.edu/
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: Columbia University with url http://columbia.edu
# found school: University of Dayton with url http://udayton.edu
# found school: Georgetown University with url http://georgetown.edu
# found school: Georgetown University with url http://georgetown.edu
# found school: Tulane University with url http://tulane.edu
# found school: Rutgers University with url http://rutgers.edu
# found school: University of Arizona with url http://arizona.edu
# found school: University of Richmond with url http://richmond.edu
# found school: Saint Louis University with url http://slu.edu
# found school: University of Montana with url http://umt.edu
# found school: Rutgers University with url http://rutgers.edu
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: Northeastern University with url http://northeastern.edu
# found school: Arizona State University with url http://asu.edu
# found school: New York University with url http://nyu.edu
# found school: University of Alabama with url http://ua.edu
# found school: Pennsylvania State University University Park with url https://www.psu.edu/
# found school: University of Georgia with url http://uga.edu
# found school: University of New Hampshire with url http://unh.edu
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: University of Houston with url www.uh.edu/
# found school: Georgetown University with url http://georgetown.edu
# found school: Villanova University with url http://villanova.edu
# found school: Indiana University Bloomington with url http://iub.edu
# found school: Rutgers University with url http://rutgers.edu
# found school: Washington & Lee University with url https://www.wlu.edu/
# found school: University of Missouri Columbia with url https://missouri.edu/
# found school: Northeastern University with url http://northeastern.edu
# found school: University of Florida Gainesville with url www.ufl.edu/
# found school: University of Pennsylvania with url http://upenn.edu
# found school: University of Pennsylvania with url http://upenn.edu
# found school: University of Akron with url https://www.uakron.edu/
# found school: University of Pennsylvania with url http://upenn.edu
# found school: University of Houston with url www.uh.edu/
# found school: Southern Methodist University with url http://smu.edu
# found school: University of Southern California with url http://usc.edu
# found school: University of Richmond with url http://richmond.edu
# found school: Northwestern University with url http://northwestern.edu
# found school: University of Virginia with url http://virginia.edu
# found school: Southern Methodist University with url http://smu.edu
# found school: University of Notre Dame with url http://nd.edu
# found school: University of Hawaii with url https://www.hawaii.edu/
# found school: Yale University with url http://yale.edu
# found school: University of California Irvine with url http://uci.edu
# found school: Yale University with url http://yale.edu
# found school: Boston College with url http://bc.edu
# found school: Harvard University with url http://harvard.edu
# found school: University of Nevada Las Vegas with url http://unlv.edu
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: Brooklyn Law School with url http://northwestern.edu
# found school: Arizona State University with url http://asu.edu
# found school: University of Southern California with url http://usc.edu
# found school: Georgetown University with url http://georgetown.edu
# found school: Tulane University with url http://tulane.edu
# found school: University of Southern California with url http://usc.edu
# found school: Harvard University with url http://harvard.edu
# found school: University of New Hampshire with url http://unh.edu
# found school: Georgetown University with url http://georgetown.edu
# found school: Rutgers University with url http://rutgers.edu
# found school: Texas A&M University with url http://tamu.edu
# found school: University of Missouri Kansas City with url http://umkc.edu
# found school: Georgia State University with url http://gsu.edu
# found school: Texas A&M University with url http://tamu.edu
# found school: University of Utah with url http://utah.edu
# found school: Emory University with url http://emory.edu
# found school: Southern Methodist University with url http://smu.edu
# found school: University of Houston with url www.uh.edu/
# found school: University of Virginia with url http://virginia.edu
# found school: Duke University with url http://duke.edu
# found school: American University with url http://american.edu
# found school: Syracuse University with url http://syr.edu
# found school: Cornell University with url http://cornell.edu
# found school: Southern Methodist University with url http://smu.edu
# found school: Southern Methodist University with url http://smu.edu
# found school: University of North Carolina Chapel Hill with url https://www.unc.edu/
# found school: University of North Carolina Chapel Hill with url https://www.unc.edu/
# found school: Georgetown University with url http://georgetown.edu
# found school: Chapman University with url http://chapman.edu
# found school: University of Houston with url www.uh.edu/
# found school: Northwestern University with url http://northwestern.edu
# found school: Villanova University with url http://villanova.edu
# found school: Texas A&M University with url http://tamu.edu
# found school: Texas A&M University with url http://tamu.edu
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: Loyola University Chicago with url http://luc.edu
# found school: University of Georgia with url http://uga.edu
# found school: New York University with url http://nyu.edu
# found school: University of Missouri Columbia with url https://missouri.edu/
# found school: University of Pennsylvania with url http://upenn.edu
# found school: Brooklyn Law School with url http://northwestern.edu
# found school: Texas A&M University with url http://tamu.edu
# found school: University of Texas Austin with url https://www.utexas.edu/
# found school: University of Houston with url www.uh.edu/
# found school: University of Texas Austin with url https://www.utexas.edu/
# found school: Hofstra University with url http://hofstra.edu
# found school: University of Texas Austin with url https://www.utexas.edu/
# found school: University of New Hampshire with url http://unh.edu
# found school: Harvard University with url http://harvard.edu
# found school: College of William & Mary with url https://wm.edu/
# found school: Cardozo Law School with url https://cardozo.yu.edu/
# found school: Texas A&M University with url http://tamu.edu
# found school: University of California Davis with url http://ucdavis.edu
# found school: Texas A&M University with url http://tamu.edu
# found school: Georgetown University with url http://georgetown.edu
# found school: Texas A&M University with url http://tamu.edu
# found school: New York University with url http://nyu.edu
# found school: University of Missouri Columbia with url https://missouri.edu/
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: Chicago-Kent College of Law with url www.uh.edu/
# found school: Texas A&M University with url http://tamu.edu
# found school: Arizona State University with url http://asu.edu
# found school: Texas A&M University with url http://tamu.edu
# found school: Georgia State University with url http://gsu.edu
# found school: Northwestern University with url http://northwestern.edu
# found school: Cornell University with url http://cornell.edu
# found school: Northwestern University with url http://northwestern.edu
# found school: Vanderbilt University with url http://vanderbilt.edu
# found school: University of California Los Angeles with url http://ucla.edu
# found school: Georgetown University with url http://georgetown.edu
# found school: University of California Hastings with url https://www.uchastings.edu/
# found school: University of North Carolina Chapel Hill with url https://www.unc.edu/
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: Campbell University with url http://campbell.edu
# found school: Texas A&M University with url http://tamu.edu
# found school: Florida State University with url http://fsu.edu
# found school: University of California Los Angeles with url http://ucla.edu
# found school: Northwestern University with url http://northwestern.edu
# found school: Northeastern University with url http://northeastern.edu
# found school: University of California Irvine with url http://uci.edu
# found school: Stanford University with url http://stanford.edu
# found school: Columbia University with url http://columbia.edu
# found school: Texas A&M University with url http://tamu.edu
# found school: Boston University with url http://bu.edu
# found school: Harvard University with url http://harvard.edu
# found school: University of Pennsylvania with url http://upenn.edu
# found school: Georgetown University with url http://georgetown.edu
# found school: University of Alabama with url http://ua.edu
# found school: University of Arkansas Fayetteville with url https://www.uark.edu/
# found school: University of Arizona with url http://arizona.edu
# found school: University of Utah with url http://utah.edu
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: University of Chicago with url http://uchicago.edu
# found school: University of Virginia with url http://virginia.edu
# found school: University of Chicago with url http://uchicago.edu
# found school: Washington University St. Louis with url https://wustl.edu/
# found school: University of Virginia with url http://virginia.edu
# found school: University of California Irvine with url http://uci.edu
# found school: University of California Irvine with url http://uci.edu
# found school: George Washington University with url https://www.gwu.edu/
# found school: Columbia University with url http://columbia.edu
# found school: University of Colorado Boulder with url http://colorado.edu
# found school: University of Washington Seattle with url https://www.washington.edu/
# found school: Brigham Young University with url http://byu.edu
# found school: College of William & Mary with url https://wm.edu/
# found school: Florida International University with url http://fiu.edu
# found school: Boston College with url http://bc.edu
# found school: University of Texas Austin with url https://www.utexas.edu/
# found school: Drexel University with url http://drexel.edu
# found school: University of Akron with url https://www.uakron.edu/
# found school: Stanford University with url http://stanford.edu
# found school: Boston College with url http://bc.edu
# found school: Columbia University with url http://columbia.edu
# found school: Harvard University with url http://harvard.edu
# found school: Indiana University Indianapolis with url https://www.iupui.edu/
# found school: Cornell University with url http://cornell.edu
# found school: University of Pennsylvania with url http://upenn.edu
# found school: Harvard University with url http://harvard.edu
# found school: University of Florida Gainesville with url www.ufl.edu/
# found school: University of California Irvine with url http://uci.edu
# found school: Florida International University with url http://fiu.edu
# found school: Arizona State University with url http://asu.edu
# found school: University of California Irvine with url http://uci.edu
# found school: Stanford University with url http://stanford.edu
# found school: University of Virginia with url http://virginia.edu
# found school: Brigham Young University with url http://byu.edu
# found school: University of Alabama with url http://ua.edu
# found school: Harvard University with url http://harvard.edu
# found school: Stanford University with url http://stanford.edu
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: Cornell University with url http://cornell.edu
# found school: Northwestern University with url http://northwestern.edu
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: University of Tennessee with url https://www.utk.edu/
# found school: McGill University with url https://www.mcgill.ca/
# found school: Columbia University with url http://columbia.edu
# found school: University of Florida Gainesville with url www.ufl.edu/
# found school: Chapman University with url http://chapman.edu
# found school: University of Minnesota Minneapolis-St. Paul with url https://twin-cities.umn.edu/
# found school: Pepperdine University with url http://pepperdine.edu
# found school: Michigan State University with url http://msu.edu
# found school: Texas Tech University with url http://ttu.edu
# found school: State University of New York Buffalo with url www.buffalo.edu/
# found school: Vermont Law School with url http://vermontlaw.edu
# found school: College of William & Mary with url https://wm.edu/
# found school: Pace University with url http://pace.edu
# found school: University of Alabama with url http://ua.edu
# found school: University of San Diego with url http://sandiego.edu
# found school: New York University with url http://nyu.edu
# found school: University of Maryland with url http://umaryland.edu
# found school: Howard University with url http://howard.edu
# found school: University of Alabama with url http://ua.edu
# found school: University of San Diego with url http://sandiego.edu
# found school: University of Florida Gainesville with url www.ufl.edu/
# found school: University of Tennessee with url https://www.utk.edu/
# found school: Northwestern University with url http://northwestern.edu
# found school: University of Alabama with url http://ua.edu
# found school: University of Virginia with url http://virginia.edu
# found school: University of California Davis with url http://ucdavis.edu
# found school: University of Florida Gainesville with url www.ufl.edu/
# found school: Duke University with url http://duke.edu
# found school: Stanford University with url http://stanford.edu
# found school: Duke University with url http://duke.edu
# found school: University of Texas Austin with url https://www.utexas.edu/
# found school: University of California Irvine with url http://uci.edu
# found school: University of California Los Angeles with url http://ucla.edu
# found school: University of Maryland with url http://umaryland.edu
# found school: University of Chicago with url http://uchicago.edu
# found school: Stanford University with url http://stanford.edu
# found school: University of North Texas with url http://unt.edu
# found school: Yale University with url http://yale.edu
# found school: University of California Irvine with url http://uci.edu
# found school: Vanderbilt University with url http://vanderbilt.edu
# found school: University of California Davis with url http://ucdavis.edu
# found school: Northwestern University with url http://northwestern.edu
# found school: New York University with url http://nyu.edu
# found school: University of Alabama with url http://ua.edu
# found school: Georgia Institute of Technology with url http://gatech.edu
# found school: University of Illinois with url http://illinois.edu
# found school: Duke University with url http://duke.edu
# found school: University of California Davis with url http://ucdavis.edu
# found school: Columbia University with url http://columbia.edu
# found school: Wayne State University with url https://wayne.edu/
# found school: Harvard University with url http://harvard.edu
# found school: Georgetown University with url http://georgetown.edu
# found school: McGill University with url https://www.mcgill.ca/
# found school: University of Notre Dame with url http://nd.edu
# found school: University of California Hastings with url https://www.uchastings.edu/
# found school: Emory University with url http://emory.edu
# found school: Duke University with url http://duke.edu
# found school: University of California Irvine with url http://uci.edu
# found school: Loyola University Chicago with url http://luc.edu
# found school: College of William & Mary with url https://wm.edu/
# found school: University of Nevada Las Vegas with url http://unlv.edu
# found school: University of Virginia with url http://virginia.edu
# found school: University of Colorado Boulder with url http://colorado.edu
# found school: University of California Los Angeles with url http://ucla.edu
# found school: Florida State University with url http://fsu.edu
# found school: Columbia University with url http://columbia.edu
# found school: University of Nevada Las Vegas with url http://unlv.edu
# found school: Temple University with url http://temple.edu
# found school: University of Houston with url www.uh.edu/
# found school: University of Nevada Las Vegas with url http://unlv.edu
# found school: University of New Hampshire with url http://unh.edu
# found school: University of Illinois with url http://illinois.edu
# found school: University of Iowa with url https://uiowa.edu/
# found school: University of Chicago with url http://uchicago.edu
# found school: Georgetown University with url http://georgetown.edu
# found school: Emory University with url http://emory.edu
# found school: University of California Los Angeles with url http://ucla.edu
# found school: Duke University with url http://duke.edu
# found school: Drexel University with url http://drexel.edu
# found school: University of Iowa with url https://uiowa.edu/
# found school: University of Pennsylvania with url http://upenn.edu
# found school: Vanderbilt University with url http://vanderbilt.edu
# found school: New York University with url http://nyu.edu
# found school: Cornell University with url http://cornell.edu
# found school: New York University with url http://nyu.edu
# found school: American University with url http://american.edu
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: University of Akron with url https://www.uakron.edu/
# found school: Yale University with url http://yale.edu
# found school: University of Montana with url http://umt.edu
# found school: University of Texas Austin with url https://www.utexas.edu/
# found school: University of California Berkeley with url https://www.berkeley.edu/
# found school: University of San Diego with url http://sandiego.edu
#      First Name Last Name Title                                     School  \
# 0       Richard    Albert    NA                             Boston College
# 1        Hilary     Allen    NA                         Suffolk University
# 2  Olufunmilayo     Arewa    NA           University of California, Irvine
# 3     Khaled A.   Beydoun    NA  University of Detroit Mercy School of Law
# 4        Joshua     Blank    NA                        New York University
#
#              School URL School URL short  \
# 0         http://bc.edu           bc.edu
# 1    http://suffolk.edu      suffolk.edu
# 2        http://uci.edu          uci.edu
# 3  www.law.udmercy.edu/  law.udmercy.edu
# 4        http://nyu.edu          nyu.edu
#
#                              New School           New School URL  \
# 0           University of Texas, Austin  https://www.utexas.edu/
# 1                   American University      http://american.edu
# 2                     Temple University        http://temple.edu
# 3  University of Arkansas, Fayetteville    https://www.uark.edu/
# 4      University of California, Irvine           http://uci.edu
#
#   New School URL short    ID
# 0           utexas.edu    46
# 1         american.edu   832
# 2           temple.edu  2248
# 3             uark.edu   656
# 4              uci.edu  7894

# %%
#The updated data is saved as a new CSV so that we don't have to do these steps again
new_data.to_csv(create_path('multi_school_data', 'multi_school_data', 'new_professor_name_data.csv'))

# %%
#This is the final dataframe. It is used as input to the main part of the code
new_data
# Out:
#           First Name    Last Name Title  \
# 0            Richard       Albert    NA
# 1             Hilary        Allen    NA
# 2       Olufunmilayo        Arewa    NA
# 3          Khaled A.      Beydoun    NA
# 4             Joshua        Blank    NA
# 5            William         Boyd    NA
# 6             Samuel         Bray    NA
# 7           Jennifer       Chacon    NA
# 8             Anupam      Chander    NA
# 9            Stewart        Chang    NA
# 10           Jessica       Clarke    NA
# 11        Frank Rudy       Cooper    NA
# 12              Seth        Davis    NA
# 13        Melissa J.       Durkee    NA
# 14             Atiba        Ellis    NA
# 15            Victor    Fleischer    NA
# 16             David     Franklyn    NA
# 17              Nuno      Garoupa    NA
# 18           Brandon      Garrett    NA
# 19            Andrew         Gold    NA
# 20            Philip      Hackney    NA
# 21       Christopher       Holman    NA
# 22            Robert      Jackson    NA
# 23             Dalie      Jimenez    NA
# 24           Kristin      Johnson    NA
# 25           Michael         Kang    NA
# 26              Orin         Kerr    NA
# 27            Eugene  Kontorovich    NA
# 28           Rebecca        Kysar    NA
# 29       Jill Wieber         Lens    NA
# ..               ...          ...   ...
# 290             Jill      Horwitz    NA
# 291         Shi-Ling          Hsu    NA
# 292             Jody        Kraus    NA
# 293         Francine       Lipman    NA
# 294         Jonathan       Lipson    NA
# 295       Jacqueline       Lipton    NA
# 296           Thomas         Main    NA
# 297           Calvin       Massey    NA
# 298            Jason      Mazzone    NA
# 299           Robert       Miller    NA
# 300        Edward R.     Morrison    NA
# 301         Victoria       Nourse    NA
# 302           Rafael        Pardo    NA
# 303           Edward       Parson    NA
# 304     H. Jefferson       Powell    NA
# 305          Dana A.        Remus    NA
# 306          L. Song   Richardson    NA
# 307          Dorothy      Roberts    NA
# 308              Jim        Rossi    NA
# 309             Adam       Samaha    NA
# 310             Lynn        Stout    NA
# 311             Alan        Sykes    NA
# 312           Andrew      Taslitz    NA
# 313           Amanda        Tyler    NA
# 314        Katharine   Van Tassel    NA
# 315           Gideon        Yaffe    NA
# 316           Sandra      Zellmer    NA
# 317          Stephen      Vladeck    NA
# 182  Steven Davidoff      Solomon    NA
# 240          Miranda        Perry    NA
#
#                                                 School  \
# 0                                       Boston College
# 1                                   Suffolk University
# 2                     University of California, Irvine
# 3            University of Detroit Mercy School of Law
# 4                                  New York University
# 5                      University of Colorado, Boulder
# 6                University of California, Los Angeles
# 7                     University of California, Irvine
# 8                      University of California, Davis
# 9                                  Whittier Law School
# 10                             University of Minnesota
# 11                                  Suffolk University
# 12                    University of California, Irvine
# 13                   University of Washington, Seattle
# 14                            West Virginia University
# 15                             University of San Diego
# 16                         University of San Francisco
# 17                                Texas A&M University
# 18                              University of Virginia
# 19                                   DePaul University
# 20                          Louisiana State University
# 21                 University of Missouri, Kansas City
# 22                                 Columbia University
# 23                           University of Connecticut
# 24                               Seton Hall University
# 25                                    Emory University
# 26                        George Washington University
# 27                             Northwestern University
# 28                                 Brooklyn Law School
# 29                                   Baylor University
# ..                                                 ...
# 290                             University of Michigan
# 291                     University of British Columbia
# 292                         University of Pennsylvania
# 293                                 Chapman University
# 294                   University of Wisconsin, Madison
# 295                    Case Western Reserve University
# 296  McGeorge School of Law, University of the Pacific
# 297                 University of California, Hastings
# 298                                Brooklyn Law School
# 299                               Villanova University
# 300                                Columbia University
# 301                   University of Wisconsin, Madison
# 302                University of Washington at Seattle
# 303                             University of Michigan
# 304                       George Washington University
# 305                        University of New Hampshire
# 306                                American University
# 307                            Northwestern University
# 308                           Florida State University
# 309                              University of Chicago
# 310            University of California at Los Angeles
# 311                                Stanford University
# 312                                  Howard University
# 313                       George Washington University
# 314                   St. Thomas University (Florida)
# 315                  University of Southern California
# 316                    University of Nebraska, Lincoln
# 317                                American University
# 182                              Ohio State University
# 240                    University of Colorado, Boulder
#
#                         School URL  School URL short  \
# 0                    http://bc.edu            bc.edu
# 1               http://suffolk.edu       suffolk.edu
# 2                   http://uci.edu           uci.edu
# 3             www.law.udmercy.edu/   law.udmercy.edu
# 4                   http://nyu.edu           nyu.edu
# 5              http://colorado.edu      colorado.edu
# 6                  http://ucla.edu          ucla.edu
# 7                   http://uci.edu           uci.edu
# 8               http://ucdavis.edu       ucdavis.edu
# 9    https://www.law.whittier.edu/  law.whittier.edu
# 10                  http://umn.edu           umn.edu
# 11              http://suffolk.edu       suffolk.edu
# 12                  http://uci.edu           uci.edu
# 13     https://www.washington.edu/    washington.edu
# 14                  http://wvu.edu           wvu.edu
# 15             http://sandiego.edu      sandiego.edu
# 16                http://usfca.edu         usfca.edu
# 17                 http://tamu.edu          tamu.edu
# 18             http://virginia.edu      virginia.edu
# 19               http://depaul.edu        depaul.edu
# 20                  http://lsu.edu           lsu.edu
# 21                 http://umkc.edu          umkc.edu
# 22             http://columbia.edu      columbia.edu
# 23                http://uconn.edu         uconn.edu
# 24                  http://shu.edu           shu.edu
# 25                http://emory.edu         emory.edu
# 26            https://www.gwu.edu/           gwu.edu
# 27         http://northwestern.edu  northwestern.edu
# 28         http://northwestern.edu  northwestern.edu
# 29               http://baylor.edu        baylor.edu
# ..                             ...               ...
# 290               http://umich.edu         umich.edu
# 291            https://www.ubc.ca/            ubc.ca
# 292               http://upenn.edu         upenn.edu
# 293             http://chapman.edu       chapman.edu
# 294          https://www.wisc.edu/          wisc.edu
# 295                http://case.edu          case.edu
# 296      https://www.mcgeorge.edu/      mcgeorge.edu
# 297    https://www.uchastings.edu/    uchastings.edu
# 298        http://northwestern.edu  northwestern.edu
# 299           http://villanova.edu     villanova.edu
# 300            http://columbia.edu      columbia.edu
# 301          https://www.wisc.edu/          wisc.edu
# 302    https://www.washington.edu/    washington.edu
# 303               http://umich.edu         umich.edu
# 304           https://www.gwu.edu/           gwu.edu
# 305                 http://unh.edu           unh.edu
# 306            http://american.edu      american.edu
# 307        http://northwestern.edu  northwestern.edu
# 308                 http://fsu.edu           fsu.edu
# 309            http://uchicago.edu      uchicago.edu
# 310                  www.ucla.edu/          ucla.edu
# 311            http://stanford.edu      stanford.edu
# 312              http://howard.edu        howard.edu
# 313           https://www.gwu.edu/           gwu.edu
# 314           https://www.stu.edu/           stu.edu
# 315                 http://usc.edu           usc.edu
# 316           https://www.unl.edu/           unl.edu
# 317            http://american.edu      american.edu
# 182                 http://osu.edu           osu.edu
# 240            http://colorado.edu      colorado.edu
#
#                                 New School             New School URL  \
# 0              University of Texas, Austin    https://www.utexas.edu/
# 1                      American University        http://american.edu
# 2                        Temple University          http://temple.edu
# 3     University of Arkansas, Fayetteville      https://www.uark.edu/
# 4         University of California, Irvine             http://uci.edu
# 5    University of California, Los Angeles            http://ucla.edu
# 6                 University of Notre Dame              http://nd.edu
# 7    University of California, Los Angeles            http://ucla.edu
# 8                    Georgetown University      http://georgetown.edu
# 9          University of Nevada, Las Vegas            http://unlv.edu
# 10                   Vanderbilt University      http://vanderbilt.edu
# 11         University of Nevada, Las Vegas            http://unlv.edu
# 12      University of California, Berkeley  https://www.berkeley.edu/
# 13                   University of Georgia             http://uga.edu
# 14                    Marquette University       http://marquette.edu
# 15        University of California, Irvine             http://uci.edu
# 16                  Golden Gate University       https://www.ggu.edu/
# 17                 George Mason University             http://gmu.edu
# 18                         Duke University            http://duke.edu
# 19                     Brooklyn Law School    http://northwestern.edu
# 20                University of Pittsburgh            http://pitt.edu
# 21                        Drake University           http://drake.edu
# 22                     New York University             http://nyu.edu
# 23        University of California, Irvine             http://uci.edu
# 24                       Tulane University          http://tulane.edu
# 25                 Northwestern University    http://northwestern.edu
# 26       University of Southern California             http://usc.edu
# 27                 George Mason University             http://gmu.edu
# 28                      Fordham University         http://fordham.edu
# 29    University of Arkansas, Fayetteville      https://www.uark.edu/
# ..                                     ...                        ...
# 290  University of California, Los Angeles            http://ucla.edu
# 291               Florida State University             http://fsu.edu
# 292                    Columbia University        http://columbia.edu
# 293        University of Nevada, Las Vegas            http://unlv.edu
# 294                      Temple University          http://temple.edu
# 295                  University of Houston                www.uh.edu/
# 296        University of Nevada, Las Vegas            http://unlv.edu
# 297            University of New Hampshire             http://unh.edu
# 298                 University of Illinois        http://illinois.edu
# 299                     University of Iowa         https://uiowa.edu/
# 300                  University of Chicago        http://uchicago.edu
# 301                  Georgetown University      http://georgetown.edu
# 302                       Emory University           http://emory.edu
# 303  University of California, Los Angeles            http://ucla.edu
# 304                        Duke University            http://duke.edu
# 305                      Drexel University          http://drexel.edu
# 306                     University of Iowa         https://uiowa.edu/
# 307             University of Pennsylvania           http://upenn.edu
# 308                  Vanderbilt University      http://vanderbilt.edu
# 309                    New York University             http://nyu.edu
# 310                     Cornell University         http://cornell.edu
# 311                    New York University             http://nyu.edu
# 312                    American University        http://american.edu
# 313     University of California, Berkeley  https://www.berkeley.edu/
# 314                    University of Akron    https://www.uakron.edu/
# 315                        Yale University            http://yale.edu
# 316                  University of Montana             http://umt.edu
# 317            University of Texas, Austin    https://www.utexas.edu/
# 182     University of California, Berkeley  https://www.berkeley.edu/
# 240                University of San Diego        http://sandiego.edu
#
#     New School URL short    ID
# 0             utexas.edu    46
# 1           american.edu   832
# 2             temple.edu  2248
# 3               uark.edu   656
# 4                uci.edu  7894
# 5               ucla.edu   301
# 6                 nd.edu  2493
# 7               ucla.edu  2814
# 8         georgetown.edu  8807
# 9               unlv.edu  1723
# 10        vanderbilt.edu  9893
# 11              unlv.edu  1824
# 12          berkeley.edu  6296
# 13               uga.edu  6667
# 14         marquette.edu    74
# 15               uci.edu  6793
# 16               ggu.edu  3743
# 17               gmu.edu  2171
# 18              duke.edu  5069
# 19      northwestern.edu  7402
# 20              pitt.edu  7046
# 21             drake.edu  8826
# 22               nyu.edu  5470
# 23               uci.edu   217
# 24            tulane.edu  3590
# 25      northwestern.edu  4133
# 26               usc.edu  6675
# 27               gmu.edu  1180
# 28           fordham.edu  1104
# 29              uark.edu  5384
# ..                   ...   ...
# 290             ucla.edu  7499
# 291              fsu.edu  5670
# 292         columbia.edu  1100
# 293             unlv.edu  8223
# 294           temple.edu  8230
# 295               uh.edu  2118
# 296             unlv.edu  5728
# 297              unh.edu  4588
# 298         illinois.edu  3833
# 299            uiowa.edu  1459
# 300         uchicago.edu  1863
# 301       georgetown.edu  9064
# 302            emory.edu  9014
# 303             ucla.edu  3957
# 304             duke.edu  1038
# 305           drexel.edu  9387
# 306            uiowa.edu  2780
# 307            upenn.edu  2123
# 308       vanderbilt.edu    13
# 309              nyu.edu  7437
# 310          cornell.edu  8860
# 311              nyu.edu   956
# 312         american.edu  6176
# 313         berkeley.edu  6066
# 314           uakron.edu  4704
# 315             yale.edu   555
# 316              umt.edu  7177
# 317           utexas.edu  4898
# 182         berkeley.edu  7669
# 240         sandiego.edu  4193
#
# [314 rows x 10 columns]

# %%
#This function searches for a professor's name on Hein. It goes through the papers that show up and checks for authors
#with the same first and last name. Once a match is found, the name is searched on Bing using the function check_google
#If the correct school name shows up on the Bing search, the name is added to the alternative name list (alt_fm_names.
#Otherwise, the name is added to the error list (err_fm_names)
def search_names(mid_first_name, last_name, school_url):
    link = 'https://heinonline-org.proxy01.its.virginia.edu/HOL/LuceneSearch?typea=title&termsa=&operator=AND&typeb=creator&termsb=' + last_name + '+' + mid_first_name + '&operatorb=AND&typec=text&termsc=&operatorc=AND&typed=title&termsd=&operatord=AND&typee=title&termse=&operatore=AND&typef=title&termsf=&yearlo=&yearhi=&tabfrom=&searchtype=field&collection=all&submit=Go'
    driver.get(link)
    try:
        webpage_wait('//*[@id="heinlogo"]/a/img')
        driver.find_element_by_xpath('//*[@id="search_modify"]/form/div/div/div/div/a[4]/i').click()
    except:
        driver.find_element_by_xpath('//*[@id="search_modify"]/div')
    element = driver.find_elements_by_tag_name('a')
    full_name = mid_first_name + ' ' +  last_name
    alt_fm_names = []
    err_fm_names = []
    if ' ' in mid_first_name.lower():
        first_name = mid_first_name.split(' ')[0]
    else: 
        first_name = mid_first_name
    page = 1
    while element:
        for link in element:
            link_text = link.text.lower()
            if first_name.lower() in link_text.lower() and last_name.lower() in link_text.lower() and '[' not in link_text:
                try:
                    new_last = link_text.split(', ')[0]
                    new_first_mid = link_text.split(', ')[1]
                    if first_name.lower() in new_first_mid and last_name.lower() == new_last:
                        new_fm = link.text.split(', ')[1]
                        if not new_fm in alt_fm_names and not new_fm in err_fm_names:
                            faculty = check_google(new_fm, last_name, school_url)
                            if faculty: 
                                alt_fm_names.append(new_fm)
                            else: 
                                err_fm_names.append(new_fm)
                except:
                    continue
        if page < 2:
            try:
                driver.find_element_by_xpath('//*[@id="thenext"]/span').click()
                time.sleep(3)
                element = driver.find_elements_by_tag_name('a') 
                page += 1
            except:
                element = []
        else: 
            element = []
    return alt_fm_names, err_fm_names

#This function checks if any of the names in the similar names list of the Hein page are the relevant author
def similar_names(alt_name_list, err_fm_names, mid_first_name, last_name):
    try:
        driver.find_element_by_xpath('//*[@id="page_content"]/div[2]/div/b/a').click()
        element = driver.find_element_by_xpath('//*[@id="simlist"]/ul[1]')
        similar_name_list = [a.strip() for a in element.text.split('\n')]
        middle_name = ''
        if ' ' in mid_first_name.lower():
            first_name = mid_first_name.split(' ')[0]
            middle_name = mid_first_name.split(' ')[1]
        else: 
            first_name = mid_first_name
        for name in similar_name_list:
            if '*' in name:
                name = name.split('*')[1]
            elif '#' in name:
                name = name.split('#')[1]
            if first_name.lower() in name.lower() and last_name.lower() in name.lower() and ', ' in name.lower():
                new_fm = name.split(', ', 1)[1]            
                new_last = name.split(', ', 1)[0]
                print(new_fm + ' ' + new_last)
                if new_fm not in alt_name_list and last_name.lower() == new_last.lower() and not new_fm in err_fm_names:
                    if ' ' in new_fm.lower() and middle_name != '':
                        new_mi = new_fm.split(' ')[1][0].lower()
                        if new_mi == middle_name[0].lower():
                            alt_name_list.append(new_fm)
                            continue
                    faculty = check_google(new_fm, last_name, school_url)
                    if faculty: 
                        alt_name_list.append(new_fm)
                    else: 
                        err_fm_names.append(new_fm)
    except:
        print('No similar names found.')
    return alt_name_list, err_fm_names

#This function searches for a name on Bing and checks if any of the results that come up contain the school URL.
#When there is no middle initial or middle name, the school url is included in the search. Otherwise, only the name is 
#searched. I found that this method works well because when there is no middle name, there is sometimes a more famous
#person with the same name
def check_google(mid_first_name, last_name, school_url):
    faculty = False
    for url in school_url:
        if faculty == True:
            break
        g_driver.get("http://bing.com")
        search = g_driver.find_element_by_xpath('//*[@id="sb_form_q"]')
        if not ' ' in mid_first_name:
            search.send_keys(mid_first_name + ' ' + last_name + ' ' + url)
        else: 
            search.send_keys(mid_first_name + ' ' + last_name + ' ')
        search.send_keys(Keys.RETURN)
        elems = g_driver.find_elements_by_xpath("//a[@href]")

        for elem in elems:
            if url in elem.text:
                print(url + ' in: ' + elem.text)
                faculty = True
                break

        g_driver.get("http://amazon.com")
        time.sleep(3)
        g_driver.get("http://facebook.com")
    return faculty

#This function changes the list of names manually
def mod_names(fm_names, err_fm_names, name_mod):
    if not name_mod.query('@mid_first_name == first_mid_name and @last_name == last_name')['fm_names'].empty or not name_mod.query('@mid_first_name == first_mid_name and @last_name == last_name')['err_fm_names'].empty:
        print('passed')
        if [x for x in list(name_mod.query('@mid_first_name == first_mid_name and @last_name == last_name')['fm_names']) if str(x) != 'nan']:
            print('passed 1')
            for name in name_mod.query('@mid_first_name == first_mid_name and @last_name == last_name')['fm_names'].values[0].split(',')
                if name not in fm_names:
                    fm_names = fm_names + [name]
                print(fm_names)
        if [x for x in list(name_mod.query('@mid_first_name == first_mid_name and @last_name == last_name')['err_fm_names']) if str(x) != 'nan']:
            print('passed 2')
            try:
                fm_names.remove(list(name_mod.query('@mid_first_name == first_mid_name and @last_name == last_name')['err_fm_names'])[0])
            except:
                print('Name {} was not in the list'.format(name_mod.query('@mid_first_name == first_mid_name and @last_name == last_name')['err_fm_names'].values[0].split(',')))
    print(fm_names)
    return fm_names

#This function gets all the paper data and appends it to the list data_stream
def get_paper_data(last_name, prof_id, title_index, scroll_num):
    data_stream = []
    data_stream = dict.fromkeys(['Title','Author', 'id', 'Journal', 'BBCite', 'Topics'], 'na')
    data_stream['id'] = prof_id
    if scroll_num == 0:
        element = driver.find_elements_by_xpath('//*[@id="save_results"]/div/div/div/div[' + str(title_index) + ']/div[2]')      
    elif scroll_num > 0:
        element = driver.find_elements_by_xpath('//*[@id="save_results"]/div[' + str(title_index) + ']/div[2]')
    for elm in element:
        my_list = elm.text
    data_list = my_list.split('\n')
    data_stream['Title'] = data_list[0]
    for a in data_list[1:]:
        if not 'More Information' in a and not a == '':
            if 'Topics: ' in a:
                data_stream['Topics'] = a.split('Topics: ')[1]
            elif 'Vol.' in a:
                data_stream['Journal'] = a
            elif last_name in a:
                data_stream['Author'] = a
            else:
                data_stream['BBCite'] = a
    return data_stream

# %%
#I don't think this is used anymore, 
#but it converted numbers like 1,000 to ints or floats
#I think I found a better way to do it
def to_float_or_int(input_list):
    new_list = []
    for x in input_list:
        x = x.replace(',','')
        try:
            value = int(x)
        except ValueError:
            try:
                value = float(x)
            except:
                value = ''
        new_list.append(value)
    return new_list

#This converts a zipped list into a dictionary
#It skips missing elements. 
#The function wouldn't be necessary if all the entries were always present
def create_dataframe_dict(my_list):
    #, person, school, data_type):
#     my_dict = {'Person': person, 
#               'School': school, 
#               'Type': data_type}
    my_dict = {}
    for stat in stats:
        my_dict[stat] = ''
        for item in my_list:   
            if item[0] == stat:
                my_dict[stat] = item[1]  
    return my_dict

#This function waits for the webpage to load by waiting until a webpage element appears
def webpage_wait(xpath):
    element = []
    while not element:
        try:
            element = driver.find_element_by_xpath(xpath)
        except:
            print('Page has not loaded, sleeping for 3 seconds')
            time.sleep(3)

#Removes commas from all values in a row of a dataframe
def remove_commas(df1):
    for col in df1.columns:
        df1[col] = df1[col].str.replace(',', '')
    return df1

#This function checks to see if a file with the papers from a professor has already been created
#If it has, their name is skipped (their data is not rescraped)
def check_files(fm_name, last_name, current_files):
    done = False
    for cur_file in current_files:
        if fm_name.lower() in cur_file.lower() and last_name.lower() in cur_file.lower():
            done = True
            break
    return done

#This function checks to see if a dataframe for a specific stat and school already exists
#This allows the program to pick up where it left off if it stops
def check_df(current_stats, school_name):
    file = ''
    for cur_stat in current_stats:
        if school_name in cur_stat.lower():
            file = cur_stat
            break
    return file

# %%
stats = ['Cited by Cases','Cited by Articles','Accessed (Past 12 Months)','Cited by Articles (Past 10 Years)', 'Cited by Articles (Past 1-2 years)', 'ScholarCheck Rank', 'Average Citations per Article', 'Average Citations per Document', 'Self-Citations']
#This is the path to the directory where the individual CSVs will be stored
path = create_path('multi_school_data', 'multi_school_data')
#This gives the files that are currently in the directory
files = os.listdir(path)
print(files)
#If we were scraping a specific school, it would be named here
school_name = 'multi_school'
#This is how long the webdriver will wait while loading pages
delay = 5
#This is a dataframe of names that we want to manually change 
#This can be used if we found errors in the data (for example, names were not scraped)
name_mod = pd.read_csv('Professor_Names_name_mod.csv')
#This line removes white space before or after names in the dataframe of names
name_mod = name_mod.apply(lambda x: x.str.strip() if x.dtype == "str" else x)
#These three lines give a list of the files that have already been scraped
#Papers gives a list of the papers by each author
#Stats gives the stat table at the top of each author's page
#Skip gives a list of the skipped names
current_papers = os.listdir(create_path('author_papers', 'multi school data'))
current_stats = os.listdir(create_path('school_stats'))
current_skip = os.listdir(create_path('skipped_names'))
#The file should be the list of names. If there are multiple schools, the files are the individual files for each school
for file in files:
    print(file)
    #This creates that main stat dataframe that will be modified
    main_df = pd.DataFrame()
    #This funciton checks if a stat CSV for the school has already been created. 
    file1 = check_df(current_stats, school_name)
    #If a stat CSV for the school has been created, it is loaded. This is useful if the program stopped before it finishe 
    #going through the full name list
    if file1 != '':
        main_df = pd.read_csv(create_path('school_stats', file1))
    #This creates that main skipped name dataframe that will be modified
    skip_df = pd.DataFrame(columns = ['Full Name', 'School'])
    #This function checks if a skipped name dataframe has already been created
    file2 = check_df(current_skip, school_name)
    #If a stat CSV for the school has been created, it is loaded. This is useful if the program stopped before it finishe 
    #going through the full name list
    if file2 != '':
        skip_df = pd.read_csv(create_path('skipped_names', file2))
    #This step reads the main data (this is the list of names of professors)
    data = pd.read_csv(os.path.join(path, file)) 
    #This loop goes through each name
    for i in range(len(data)):
        #This section gets the professor's information from the dataframe 
        #ID
        prof_id = data['ID'][i]
        #First Name and middle name
        mid_first_name = data['First Name'][i]
        #Last Name
        last_name = data['Last Name'][i]
        #Full Name
        full_name = mid_first_name + ' ' +  last_name
        #This line gets the school URLs from the dataframe
        school_url = [data['School URL short'][i], data['New School URL short'][i]]
        #Checks if a file for the papers from the professor has already been created
        done = check_files(mid_first_name, last_name, current_papers)
        #If a file has already been created for the professor, the loop moves onto the next name
        if done:
            print('File for ' + full_name + ' has already been created.')
            continue
        #School name
        school = data['School'][i]
        #New school name
        new_school = data['New School'][i]
        #Title 
        title = data['Title'][i]
        page_name = []
        err_fm_names = []
        df_sub = pd.DataFrame()
        print(mid_first_name)
        print(mid_first_name)
        print(last_name)
        
        #Search by author to find potential alternative first and middle names:
        fm_names, err_fm_names = search_names(mid_first_name, last_name, school_url)
        #This function manually changes names using the name_mod dataframe
        fm_names = mod_names(fm_names, err_fm_names, name_mod)

        #If there were no matching names, the name is added to the skipped names list and the loop moves onto the next name
        if not fm_names:
            print('Name ' + full_name + ' was not found')
            skip_df = skip_df.append(pd.DataFrame([[full_name, school, new_school, title]], columns = ['Full Name', 'School', 'New School', 'Title']), sort=False)
            
        #This section loops through the list of alternative names and goes directly to their pages on Hein
        for fm_name in fm_names:
            #Link to Heil page
            link = 'https://heinonline-org.proxy01.its.virginia.edu/HOL/AuthorProfile?action=edit&search_name=' + last_name +  '%2C ' + fm_name + '&collection=journals'
            #Direct the webdriver to the page
            driver.get(link)
            #This function waits for the webpage to load
            webpage_wait('//*[@id="page_content"]/div[1]/div/div[1]/div[1]')
            #This gets the page HTML
            soup=bs.BeautifulSoup(driver.page_source, 'lxml')
            #This find the stat table at the top of the page
            table_rows = soup.findAll('td', {'style': 'text-align:right;'})
            #This gives the full name
            full_name = fm_name + ' ' +  last_name
            #This function checks the similar names list on the Hein page to append additional names
            fm_names, err_fm_names = similar_names(fm_names, err_fm_names, fm_name, last_name)
            #This function checks the name_mod CSV again
            fm_names = mod_names(fm_names, err_fm_names, name_mod)
            
            
            cur_page = driver.find_element_by_xpath('//*[@id="page_content"]/div[1]/div/div[1]/div[1]').text
            if not table_rows:
                got_page = False
                new_names = False
                link_index = 1
                while new_names == False:
                    try:
                        if link_index == 1:
                            element =driver.find_element_by_xpath('//*[@id="page_content"]/div[2]/div/ul/li/a')
                        else: 
                            element =driver.find_element_by_xpath('//*[@id="page_content"]/div[2]/div/ul/li[' + str(link_index) + ']/a')            
                        new_fm_name = element.text.split(', ')[1]
                        new_last_name = element.text.split(', ')[0]
                        if last_name == new_last_name and mid_first_name in new_fm_name:
                            if not new_fm_name in fm_names:
                                check_google(new_fm_name, last_name, school_url)
                                fm_names.append(new_fm_name)
                            
                    except: 
                        new_names = True
                        got_page = True
                        if not scraped_papers:
                            print('Name ' + full_name + ' is not in the database. You may be missing a middle initial.')
                            skip_df = skip_df.append(pd.DataFrame([[full_name, school, title]], columns = ['Full Name', 'School', 'Title']), sort=False)
                        else:
                            print('No remaining pages to scrape from {}.'.format(full_name))
                    link_index += 1
            #If there is a table on the page
            elif table_rows and cur_page not in page_name: 
                element = driver.find_element_by_xpath('//*[@id="page_content"]/div[1]/div/div[2]')
                table_element = element.text.split('\n')
                #If the table is empty, there is no data to scrape
                if len(table_element) < 5:
                    print('No data available on Hein for {} {}'.format(fm_name, last_name))
                #If the table is full, this section rearranges the data into a better format
                else:
                    number_list = []
                    rank_list = []
                    stat_list = []
                    #This section finds each stat in the table and adds them to lists so that they can be saved to 
                    #dataframes
                    for stat in stats:
                        find_index = [table_element.index(s) for s in table_element if stat == s]
                        if find_index:
                            my_list = table_element[find_index[0]+1].split(' ')
                            number_list.append(my_list[0])
                            stat_list.append(stat)
                            if len(my_list) > 1:
                                rank_list.append(my_list[-1])
                        if stat == 'Self-Citations':
                            find_index = [table_element.index(s) for s in table_element if stat in s]
                            if find_index:
                                stat_list.append(stat)
                                number_list.append(table_element[find_index[0]].split(' ')[1])
                    #This section takes the lists and zips them to keep the stat names and stat values together
                    zip_number_list = list(zip(stat_list, number_list))
                    zip_rank_list = list(zip(stat_list, rank_list))
                    number_dict = create_dataframe_dict(zip_number_list)
                    rank_dict = create_dataframe_dict(zip_rank_list)
                    df_number = pd.DataFrame.from_dict(number_dict, orient='index').transpose()
                    df_rank = pd.DataFrame.from_dict(rank_dict, orient='index').transpose()
                    df_number = df_number.replace('na', '0')
                    df_number = df_number.replace('', '0')
                    df_number = df_number.replace(' ', '0')
                    df_number = remove_commas(df_number)
                    df_number = df_number.astype(float)
                    #This section adds the number stats to the dataframe of stats so that it can be added to the 
                    #final dataframe
                    if df_sub.empty:
                        df_sub = df_number
                    else: 
                        df_sub = df_sub.add(df_number)
                    
                    #This section scrapes the paper data. The index values are based on the way the xpaths are incremented
                    #The scroll number tracks the number of times the page has scrolled. This is for pages with a large number of 
                    #papers. The xpaths change when the page scrolls.
                    title_index = 3
                    stats_index = 4
                    topic_index = 0
                    scroll_num = 0
                    #This gets the page source
                    soup=bs.BeautifulSoup(driver.page_source, 'lxml')
                    #This section gets the paper topics
                    topic_array = soup.findAll('div', {'class': 'topics'})
                    element = title_index
                    page_name = []
                    df = pd.DataFrame(columns = ['Title', 'Author(s)', 'ID', 'Journal', 'BBCite', 'Topics', 'Cited (articles)', 'Cited (cases)', 'Accessed'])
                    #This while loop will continue until there are no more papers on the page
                    while element:
                        #Data stream is a list of the data in the paper data box (for example, authors, topics, journal)
                        data_stream = []
                        #This funciton returns a dictionary with various fields for each variable in the data box
                        #Sometimes some of the variables are missing (for example, there are papers without a journal listed)
                        #In this case, the dictionary returns an empty value for these variables
                        data_dict = get_paper_data(last_name, prof_id, title_index, scroll_num)
                        #This section gets the paper stats box. This is the box that says how many citations the paper
                        #has received
                        if scroll_num == 0:
                            element = driver.find_elements_by_xpath('//*[@id="save_results"]/div/div/div/div[' + str(stats_index) + ']/div[2]/div')
                        elif scroll_num > 0:
                            element = driver.find_elements_by_xpath('//*[@id="save_results"]/div[' + str(stats_index) + ']/div[2]/div')
                        #This section extracts the data from the paper stats box
                        for elm in element:
                            cited_text = elm.text
                        article_citations = 'na'
                        case_citations = 'na'
                        accessed = 'na'
                        if not isinstance(cited_text, list):
                            cited_text = cited_text.split('\n')
                            #This section finds the value for each paper stat
                            for stat in cited_text:
                                if 'Article' in stat:
                                    article_citations = int(re.search(r'\d+', stat).group())
                                if 'Case' in stat:
                                    case_citations = int(re.search(r'\d+', stat).group())
                                if 'Accessed' in stat:
                                    accessed = int(re.search(r'\d+', stat).group())
                        #The values are appended to the data_stream list
                        data_stream.append(article_citations)
                        data_stream.append(case_citations)
                        data_stream.append(accessed)
                        #This line adds the output from the function get_paper_data to the data_stream list
                        data_stream = list(data_dict.values()) + data_stream
                        #The data_stream list is used to add a line of data to the overall paper dataframe for this author
                        df = df.append(pd.DataFrame([data_stream], columns = ['Title', 'Author(s)', 'ID', 'Journal', 'BBCite', 'Topics', 'Cited (articles)', 'Cited (cases)', 'Accessed']), sort=False)
                        #The indices are augmented to get the next paper
                        stats_index +=4
                        title_index += 4
                        page_name.append(cur_page)
                        #Check that next paper exists:
                        if scroll_num == 0:
                            x_path_title = '//*[@id="save_results"]/div/div/div/div[' + str(title_index) + ']/div[2]/dt[1]/div'
                        #If the page has scrolled, the xpath we need to check has changed
                        if scroll_num > 0:
                            x_path_title = '//*[@id="save_results"]/div[' + str(title_index) + ']/div[2]/dt[1]/div'
                        element = driver.find_elements_by_xpath(x_path_title)
                        #If we can't find a next paper, it could be because we need to scroll again
                        #This section attempts to scroll the page. 
                        if not element:
                            scroll_num +=1
                            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                            box_element = driver.find_elements_by_xpath('//*[@id="results_total"]')
                            num_papers = int(box_element[0].text.split(' ')[0])
                            #If there are more than 100 papers, we know there are still paper left to scrape
                            if num_papers > 100*scroll_num:
                                time.sleep(15)
                                title_index = 3
                                stats_index = 4
                                topic_index = 0
                                x_path_title = '//*[@id="save_results"]/div[' + str(title_index) + ']/div[2]/dt[1]/div'
                                element = driver.find_elements_by_xpath(x_path_title)
                    #This line saves the CSV of papers
                    df.to_csv(create_path('author_papers', 'multi school data', '{}_{}_{}_papers.csv'.format(full_name, prof_id, school)),index=False)
                    time.sleep(3)
                #If we reach this point, all the pages for that author have been scraped
                print('No remaining pages to scrape for {}.'.format(fm_name + ' ' + last_name))  
        #If there are elements in the sub stat dataframe, they need to be added to the main stat dataframe
        if not df_sub.empty:
            my_dict = {'Person': [full_name], 'ID': [prof_id], 'School': [school], 'Type': ['number']}
            name_data = pd.DataFrame(my_dict)
            df_sub = pd.concat([name_data, df_sub], sort = False, axis = 1)
            main_df = pd.concat([main_df, df_sub], sort = False)
            main_df.replace(0, 'na')
            main_df.to_csv(create_path('school_stats', '{}_stats.csv'.format(school_name)),index=False)                
#         skip_df.to_csv(create_path('skipped_names', '{}_skipped.csv'.format(school_name)), index = False)

#These lines save the final version of the stat and skipped names CSVs. We only want to save the skipped names at the 
#end becuase we want the code to consider those names if we rerun it. 
skip_df.to_csv(create_path('skipped_names', '{}_skipped.csv'.format(school_name)),index=False)
main_df.replace(0, 'na')
main_df.to_csv(create_path('school_stats', '{}_stats.csv'.format(school_name)),index=False)
# Out:
# ['new_professor_name_data.csv']
# new_professor_name_data.csv
# Richard
# Richard
# Albert
# bc.edu in: Richard Albert - bc.edu
# ['Richard']
# ['Richard']
# No remaining pages to scrape for Richard Albert.
# File for Hilary Allen has already been created.
# File for Olufunmilayo Arewa has already been created.
# File for Khaled A. Beydoun has already been created.
# File for Joshua Blank has already been created.
# William
# William
# Boyd
# ucla.edu in: William Boyd - ioes.ucla.edu
# ['William']
# ['William']
# No remaining pages to scrape for William Boyd.
# File for Samuel Bray has already been created.
# File for Jennifer Chacon has already been created.
# File for Anupam Chander has already been created.
# File for Stewart Chang has already been created.
# File for Jessica Clarke has already been created.
# File for Frank Rudy Cooper has already been created.
# File for Seth Davis has already been created.
# File for Melissa J. Durkee has already been created.
# File for Atiba Ellis has already been created.
# File for Victor Fleischer has already been created.
# File for David Franklyn has already been created.
# File for Nuno Garoupa has already been created.
# File for Brandon Garrett has already been created.
# File for Andrew Gold has already been created.
# File for Philip Hackney has already been created.
# File for Christopher Holman has already been created.
# File for Robert Jackson has already been created.
# File for Dalie Jimenez has already been created.
# File for Kristin Johnson has already been created.
# File for Michael Kang has already been created.
# File for Orin Kerr has already been created.
# File for Eugene Kontorovich has already been created.
# File for Rebecca Kysar has already been created.
# File for Jill Wieber Lens has already been created.
# File for Suzette Malveaux has already been created.
# File for David Marcus has already been created.
# File for Justin McCrary has already been created.
# File for Curtis Milhaupt has already been created.
# File for Seema Mohapatra has already been created.
# File for Melissa Murray has already been created.
# File for Anne Joseph O'Connell has already been created.
# File for Leigh Osofsky has already been created.
# File for Frank Partnoy has already been created.
# File for Jedediah Purdy has already been created.
# File for Christopher Roederer has already been created.
# File for Hillary Sale has already been created.
# File for Madhavi Sunder has already been created.
# File for Kim Talus has already been created.
# File for Rose Cuison Villazor has already been created.
# File for Andrew Woods has already been created.
# File for Kevin Woodson has already been created.
# File for Ruqaiijah A. Yearby has already been created.
# File for Sandi Zellmer has already been created.
# File for Sahar Aziz has already been created.
# File for Adam Badawi has already been created.
# File for Shalanda Baker has already been created.
# File for Angela Banks has already been created.
# File for Richard R. W. Brooks has already been created.
# File for Alfred Brophy has already been created.
# File for Eleanor Brown has already been created.
# File for Christopher Bruner has already been created.
# File for Tonya Evans has already been created.
# File for Catherine Fisk has already been created.
# File for Victor Flatt has already been created.
# File for Sheila Foster has already been created.
# File for Brett Frischmann has already been created.
# File for David Gamage has already been created.
# File for Rachel Godsil has already been created.
# File for Sarah Haan has already been created.
# File for Sam Halabi has already been created.
# File for Woodrow Hartzog has already been created.
# File for David Hasen has already been created.
# File for Allison Hoffman has already been created.
# File for David Hoffman has already been created.
# File for Ryan Holte has already been created.
# File for Herbert Hovenkamp has already been created.
# File for Blake Hudson has already been created.
# File for Lolita Buckner Inniss has already been created.
# File for Orin Kerr has already been created.
# File for Kurt Lash has already been created.
# File for Yoon-Ho Alex Lee has already been created.
# File for Dayna Matthew has already been created.
# File for Pamela Metzger has already been created.
# File for Paul Miller has already been created.
# File for Nicholas A. Mirkay has already been created.
# File for Samuel Moyn has already been created.
# File for Alexandra Natapoff has already been created.
# File for Douglas NeJaime has already been created.
# File for Shu-Yi Oei has already been created.
# File for Ruth Okediji has already been created.
# File for David Orentlicher has already been created.
# File for Frank Partnoy has already been created.
# File for Alice Ristroph has already been created.
# File for Victoria Sahani has already been created.
# File for Michael Simkovic has already been created.
# File for Brad Snyder has already been created.
# File for Kim Talus has already been created.
# File for Franita Tolson has already been created.
# File for Rebecca Tushnet has already been created.
# File for Ryan Vacca has already been created.
# File for Urska Velikonja has already been created.
# File for Rose Cuison Villazor has already been created.
# File for Nancy Welsh has already been created.
# File for Del Wright has already been created.
# File for Edward Afield has already been created.
# File for Lisa Alexander has already been created.
# File for RonNell Andersen Jones has already been created.
# File for Margo Bagley has already been created.
# File for Dale Carpenter has already been created.
# File for David Fagundes has already been created.
# File for Joshua Fischman has already been created.
# File for Michael Frakes has already been created.
# File for Susan Franck has already been created.
# File for Shubha Ghosh has already been created.
# File for James Grimmelman has already been created.
# File for Joanna Grossman has already been created.
# File for Grant Hayden has already been created.
# File for Andrew Hessick has already been created.
# File for Carissa Byrne Hessick has already been created.
# File for David Hyman has already been created.
# File for Janine Kim has already been created.
# File for Renee Knake has already been created.
# File for Sarah Lawsky has already been created.
# File for Andrew Lund has already been created.
# File for Fatma Marouf has already been created.
# File for Thomas Mitchell has already been created.
# File for Angela Onwuachi-Willig has already been created.
# File for Jordan Paradise has already been created.
# File for Gregg Polsky has already been created.
# File for Edward B. Rock has already been created.
# File for Amy Schmitz has already been created.
# File for Beth Simmons has already been created.
# File for Alex Stein has already been created.
# File for Elizabeth Trujillo has already been created.
# File for Steve Vladeck has already been created.
# File for Gina Warren has already been created.
# File for Melissa Wasserman has already been created.
# File for Ellen Yaroshefsky has already been created.
# File for Owen Anderson has already been created.
# File for Ann Bartow has already been created.
# File for Thomas Brennan has already been created.
# File for Aaron Bruhl has already been created.
# File for Christopher Buccafusco has already been created.
# File for Irene Calboli has already been created.
# File for William Dodge has already been created.
# File for Susan Fortney has already been created.
# File for Brian Galle has already been created.
# File for Nuno Garoupa has already been created.
# File for C. Scott Hemphill has already been created.
# File for Robert Jerry has already been created.
# File for Sonia Katyal has already been created.
# File for Daniel Katz has already been created.
# File for Charlotte Ku has already been created.
# File for Erik Luna has already been created.
# File for Glynn S. Lunney has already been created.
# File for Timothy Lytton has already been created.
# File for Bruce Markell has already been created.
# File for Andrei Marmor has already been created.
# File for Ajay Mehrotra has already been created.
# File for Timothy Meyer has already been created.
# File for Douglas NeJaime has already been created.
# File for Paul Ohm has already been created.
# File for Dave Owen has already been created.
# File for Mary-Rose Papandrea has already been created.
# File for Dylan Penningroth has already been created.
# File for Scott Pryor has already been created.
# File for Srividhya Ragavan has already been created.
# File for Erin Ryan has already been created.
# File for James Salzman has already been created.
# File for David Schwartz has already been created.
# File for Jessica Silbey has already been created.
# File for Kenneth Simons has already been created.
# File for Alan O. Sykes has already been created.
# Eric
# Eric
# Talley
# columbia.edu in: See results only from law.columbia.edu
# ['Eric']
# ['Eric']
# No remaining pages to scrape for Eric Talley.
# File for Peter Yu has already been created.
# File for Kathryn Zeiler has already been created.
# File for Oren Bar-Gill has already been created.
# File for Mitchell N. Berman has already been created.
# File for William Buzbee has already been created.
# File for Jenny Carroll has already been created.
# File for Stephen Clowney has already been created.
# File for Andrew Coan has already been created.
# File for Jorge Contreras has already been created.
# File for Steven Davidoff has already been created.
# File for Dhammika Dharmapala has already been created.
# File for Michael Doran has already been created.
# File for Justin Driver has already been created.
# File for Lee Epstein has already been created.
# File for Kimberly Ferzan has already been created.
# File for Michele B. Goodwin has already been created.
# File for Kaaryn Gustafson has already been created.
# File for Emily Hammond has already been created.
# File for Bernard Harcourt has already been created.
# File for David Hasen has already been created.
# File for Michael Hatfield has already been created.
# File for Christine Hurt has already been created.
# File for Darian Ibrahim has already been created.
# File for Charles Jalloh has already been created.
# File for Cathleen Kaveny has already been created.
# File for Andrew Kull has already been created.
# File for Amy Landers has already been created.
# File for Jacqueline Lipton has already been created.
# File for Robert MacCoun has already been created.
# File for Patricia McCoy has already been created.
# File for Edward R. Morrison has already been created.
# File for Samuel Moyn has already been created.
# File for Xuan-Thao Nguyen has already been created.
# File for Saule Omarova has already been created.
# File for Wendell Pritchett has already been created.
# File for Intisar A. Rabb has already been created.
# File for Robert Rhee has already been created.
# File for L. Song Richardson has already been created.
# File for Kalyani Robbins has already been created.
# File for Troy Rule has already been created.
# File for Gregory Shaffer has already been created.
# File for David Sklansky has already been created.
# File for A. Benjamin Spencer has already been created.
# File for Paul Stancil has already been created.
# File for Adam Steinman has already been created.
# File for Kristen Stilt has already been created.
# File for David Studdert has already been created.
# File for Christopher Tomlins has already been created.
# File for Gerald Torres has already been created.
# File for Deborah Tuerkheimer has already been created.
# File for Kenneth Ayotte has already been created.
# File for Teri Dobbins Baxter has already been created.
# File for Andrea K. Bjorklund has already been created.
# File for Richard Brooks has already been created.
# File for Karen Burke has already been created.
# File for Lan Cao has already been created.
# File for June Carbone has already been created.
# File for Paul Caron has already been created.
# File for Jim Chen has already been created.
# File for Eric A. Chiappinelli has already been created.
# File for Luis E. Chiesa has already been created.
# File for Christine Cimini has already been created.
# File for Evan Criddle has already been created.
# File for Jason Czarnezki has already been created.
# File for Richard Delgado has already been created.
# File for Miranda Perry Fleischer has already been created.
# File for Jeanne Fromer has already been created.
# File for James Grimmelmann has already been created.
# File for Lenese Herbert has already been created.
# File for Julie Hill has already been created.
# File for Adam Hirsch has already been created.
# File for Darren Hutchinson has already been created.
# File for Lucy Jewel has already been created.
# File for Emily Kadens has already been created.
# File for Alberto Lopez has already been created.
# File for Ruth Mason has already been created.
# File for Lesley McAllister has already been created.
# File for Grayson McCouch has already been created.
# File for Mathew McCubbins has already been created.
# File for Bernadette Meyler has already been created.
# File for Darrell Miller has already been created.
# File for Susan Morse has already been created.
# File for Douglas NeJaime has already been created.
# File for James Park has already been created.
# File for Frank Pasquale has already been created.
# File for Eduardo Penalver has already been created.
# File for Nathaniel Persily has already been created.
# File for Ellen Smith Pryor has already been created.
# File for Cristina Rodriguez has already been created.
# File for Benjamin van Rooij has already been created.
# File for Christopher Serkin has already been created.
# File for Darien Shanske has already been created.
# File for Matthew Spitzer has already been created.
# File for Christopher Sprigman has already been created.
# File for Jean Stefancic has already been created.
# File for Peter Swire has already been created.
# File for Robin Fretwell Wilson has already been created.
# File for Matthew Adler has already been created.
# File for Karima Bennoune has already been created.
# File for Anu Bradford has already been created.
# File for Charles Brower has already been created.
# File for Tomiko Brown-Nagin has already been created.
# File for Paul Butler has already been created.
# File for Allison Christians has already been created.
# File for Barry Cushman has already been created.
# File for Scott Dodson has already been created.
# File for Mary Dudziak has already been created.
# File for Nita Farahany has already been created.
# File for Bryant Garth has already been created.
# File for James Gathii has already been created.
# File for Adam Gershowitz has already been created.
# File for Leslie Griffin has already been created.
# File for Deborah Hellman has already been created.
# File for Jennifer Hendricks has already been created.
# File for Jill Horwitz has already been created.
# File for Shi-Ling Hsu has already been created.
# File for Jody Kraus has already been created.
# File for Francine Lipman has already been created.
# File for Jonathan Lipson has already been created.
# File for Jacqueline Lipton has already been created.
# File for Thomas Main has already been created.
# File for Calvin Massey has already been created.
# File for Jason Mazzone has already been created.
# File for Robert Miller has already been created.
# File for Edward R. Morrison has already been created.
# File for Victoria Nourse has already been created.
# File for Rafael Pardo has already been created.
# File for Edward Parson has already been created.
# File for H. Jefferson Powell has already been created.
# File for Dana A. Remus has already been created.
# File for L. Song Richardson has already been created.
# File for Dorothy Roberts has already been created.
# File for Jim Rossi has already been created.
# File for Adam Samaha has already been created.
# File for Lynn Stout has already been created.
# File for Alan Sykes has already been created.
# File for Andrew Taslitz has already been created.
# File for Amanda Tyler has already been created.
# File for Katharine Van Tassel has already been created.
# File for Gideon Yaffe has already been created.
# File for Sandra Zellmer has already been created.
# File for Stephen Vladeck has already been created.
# File for Steven Davidoff Solomon has already been created.
# File for Miranda Perry has already been created.
