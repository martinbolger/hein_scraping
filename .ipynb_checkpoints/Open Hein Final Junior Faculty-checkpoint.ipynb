# %%
from selenium import webdriver
import pandas as pd
import bs4 as bs
import os
import numpy as np
import re
import time
from selenium.webdriver.common.keys import Keys
import nltk
import requests
import random
import uuid

# %%
driver = webdriver.Chrome()
driver.get("http://proxy.its.virginia.edu/login?url=http://heinonline.org/HOL/Welcome")
g_driver = webdriver.Chrome()

# %% [markdown]
# You can use this part to automatically login, but DUO two step authentication is still required. You will have to enter that manually. After entering the DUO code, you will be given a warning that the information you enter could be sent over an insecure connection. Click continue.

# %%
username = 'meb2fv'
password = '0ver In 2018!'
driver.find_element_by_id("user").send_keys(username);
driver.find_element_by_id("pass").send_keys(password);
driver.find_element_by_xpath("/html/body/main/div[2]/fieldset/form/input").click()

# %% [markdown]
# After you have logged in, Selenium is able to navigate to any webpage. We will navigate to the pages on the list:

# %%
def search_names(mid_first_name, last_name, school_url):
    link = 'https://heinonline-org.proxy01.its.virginia.edu/HOL/LuceneSearch?typea=title&termsa=&operator=AND&typeb=creator&termsb=' + last_name + '+' + mid_first_name + '&operatorb=AND&typec=text&termsc=&operatorc=AND&typed=title&termsd=&operatord=AND&typee=title&termse=&operatore=AND&typef=title&termsf=&yearlo=&yearhi=&tabfrom=&searchtype=field&collection=all&submit=Go'
    driver.get(link)
    try:
        webpage_wait('//*[@id="heinlogo"]/a/img')
        driver.find_element_by_xpath('//*[@id="search_modify"]/form/div/div/div/div/a[4]/i').click()
    except:
        driver.find_element_by_xpath('//*[@id="search_modify"]/div')
    element = driver.find_elements_by_tag_name('a')
    full_name = mid_first_name + ' ' +  last_name
    alt_fm_names = []
    err_fm_names = []
    if ' ' in mid_first_name.lower():
        first_name = mid_first_name.split(' ')[0]
    else: 
        first_name = mid_first_name
    page = 1
    
    while element:
        for link in element:
            link_text = link.text.lower()
            if first_name.lower() in link_text.lower() and last_name.lower() in link_text.lower() and '[' not in link_text:
                try:
                    new_last = link_text.split(', ')[0]
                    new_first_mid = link_text.split(', ')[1]
                    if first_name.lower() in new_first_mid and last_name.lower() == new_last:
                        new_fm = link.text.split(', ')[1]
                        if not new_fm in alt_fm_names and not new_fm in err_fm_names:
                            faculty = check_google(new_fm, last_name, school_url)
                            if faculty: 
                                alt_fm_names.append(new_fm)
                            else: 
                                err_fm_names.append(new_fm)
                except:
                    continue
        if page < 2:
            try:
                driver.find_element_by_xpath('//*[@id="thenext"]/span').click()
                time.sleep(3)
                element = driver.find_elements_by_tag_name('a') 
                page += 1
            except:
                element = []
        else: 
            element = []
    return alt_fm_names, err_fm_names

# %%
def similar_names(alt_name_list, err_fm_names, mid_first_name, last_name):
    try:
        driver.find_element_by_xpath('//*[@id="page_content"]/div[2]/div/b/a').click()
        element = driver.find_element_by_xpath('//*[@id="simlist"]/ul[1]')
        similar_name_list = [a.strip() for a in element.text.split('\n')]
        middle_name = ''
        if ' ' in mid_first_name.lower():
            first_name = mid_first_name.split(' ')[0]
            middle_name = mid_first_name.split(' ')[1]
        else: 
            first_name = mid_first_name
        for name in similar_name_list:
            if first_name.lower() in name.lower() and last_name.lower() in name.lower() and ', ' in name.lower():
                new_fm = name.split(', ', 1)[1]            
                new_last = name.split(', ', 1)[0]
                print(new_fm + ' ' + new_last)
                if new_fm not in alt_name_list and last_name.lower() == new_last.lower() and not new_fm in err_fm_names:
                    if ' ' in new_fm.lower() and middle_name != '':
                        new_mi = new_fm.split(' ')[1][0].lower()
                        if new_mi == middle_name[0].lower():
                            alt_name_list.append(new_fm)
                            continue
                    faculty = check_google(new_fm, last_name, school_url)
                    if faculty: 
                        alt_name_list.append(new_fm)
                    else: 
                        err_fm_names.append(new_fm)
    except:
        print('No similar names found.')
    return alt_name_list, err_fm_names

# %%
def check_google(mid_first_name, last_name, school_url):
    faculty = False
    for url in school_url:
        if faculty == True:
            break
        g_driver.get("http://google.com")
        search = g_driver.find_element_by_name('q')
        if not ' ' in mid_first_name:
            search.send_keys(mid_first_name + ' ' + last_name + ' ' + url)
        else: 
            search.send_keys(mid_first_name + ' ' + last_name + ' ')
        search.send_keys(Keys.RETURN)
        elems = g_driver.find_elements_by_xpath("//a[@href]")

        for elem in elems:
            if url in elem.text:
                print(url + ' in: ' + elem.text)
                faculty = True
                break
    return faculty

# %% [markdown]
# If there is no middle name, a more famous person with the same first and last name will
#     be at the top of the search results, so we need to add the school name
#     In this case it will be ambiguous is another professor with the same first and last name
#     is in Hein anyway, so there is really no good way to tell if we are getting the wrong one.
#     If they have a middle initial, I assume there is not another professor using the same exact name
#     at a different school. Therefore, to avoid conflict with more famous people, I use the school name
#     in the search

# %%
def create_path(*args):
    cur_path = os.getcwd()
    for value in args:
        cur_path  = os.path.join(cur_path, value)
    return cur_path

def to_float_or_int(input_list):
    new_list = []
    for x in input_list:
        x = x.replace(',','')
        try:
            value = int(x)
        except ValueError:
            try:
                value = float(x)
            except:
                value = ''
        new_list.append(value)
    return new_list

def create_dataframe_dict(my_list):#, person, school, data_type):
#     my_dict = {'Person': person, 
#               'School': school, 
#               'Type': data_type}
    my_dict = {}
    for stat in stats:
        my_dict[stat] = ''
        for item in my_list:   
            if item[0] == stat:
                my_dict[stat] = item[1]  
    return my_dict

def get_id():
    id = uuid.uuid1().int
    return str(id)[:6]

def webpage_wait(xpath):
    element = []
    while not element:
        try:
            element = driver.find_element_by_xpath(xpath)
        except:
            print('Page has not loaded, sleeping for 3 seconds')
            time.sleep(3)

def remove_commas(df1):
    for col in df1.columns:
        df1[col] = df1[col].str.replace(',', '')
    return df1

def check_files(fm_name, last_name, current_files):
    done = False
    for cur_file in current_files:
        if fm_name.lower() in cur_file.lower() and last_name.lower() in cur_file.lower():
            done = True
            break
    return done

def check_df(current_stats, school_name):
    file = ''
    for cur_stat in current_stats:
        if school_name in cur_stat.lower():
            file = cur_stat
            break
    return file

def short_url(data):
    url_list = []
    for url in data:
        if '.edu' in url:
            end = '.edu'
        elif '.ca' in url:
            end = '.ca'
        elif '.ac.uk' in url:
            end = '.ac.uk'
        elif '.hk' in url:
            end = '.hk'
        elif '.ac.il' in url:
            end = '.ac.il'
        elif 'yu' in url:
            end = 'yu'
        if 'https://www.' in url:
            new_url = url.split('https://www.')[1].split(end)[0]
        elif 'http://www.' in url:
            new_url = url.split('http://www.')[1].split(end)[0]
        elif 'https://www1.' in url:
            new_url = url.split('https://www1.')[1].split(end)[0]
        elif 'https://www2.' in url:
            new_url = url.split('https://www2.')[1].split(end)[0]
        elif 'www.' in url:
            new_url = url.split('www.')[1].split(end)[0]
        elif 'https://' in url:
            new_url = url.split('https://')[1].split(end)[0]
        elif 'http://' in url:
            new_url = url.split('http://')[1].split(end)[0]
        url_list.append(new_url)
    return url_list

# %%
data = pd.read_csv(create_path('multi_school_data','Junior_Faculty_Hires.csv'))
urls = pd.read_csv(create_path('University and College Websites update.csv'))
data.head()

fm_name = [x.split(', ')[1] if ',' in x else ' '.join(x.split(' ')[:-1]) for x in data['Entry-Level Prof']]
last_name = [x.split(',')[0] if ',' in x else x.split(' ')[-1] for x in data['Entry-Level Prof']]

title = ['NA']*len(last_name)
new_data = pd.DataFrame({'First Name': fm_name, 'Last Name': last_name, 'Title': title, 'School': data['Hiring School']})

# %%
def get_school_urls(urls_df, school_list):
    url_list = []
    for school_name in school_list:
        school_name = school_name.replace(',', '')
        try: 
            index = urls_df[urls_df['School Name'] == school_name + ' university'].index[0]
            url_name = urls_df['URL'][index]
            school_name = urls_df['School Name'][index]
            print('found school: {} with url {}'.format(school_name, url_name))
            url_list.append(url_name)
        except:
            g_driver.get("http://google.com")
            search = g_driver.find_element_by_name('q')
            school_name = school_name + ' university'
            search.send_keys(school_name)
            search.send_keys(Keys.RETURN)
            element = g_driver.find_elements_by_xpath('//*[@id="rso"]/div[1]/div/div[1]/div/div/div[1]/a/div/cite')
            if not element:
                element = g_driver.find_elements_by_xpath('//*[@id="rso"]/div[1]/div/div/div/div[1]/a/div/cite')
                if not element: 
                    element = g_driver.find_elements_by_xpath('//*[@id="rso"]/div[2]/div/div/div/div/div[1]/a/div/cite')
            for elm in element:
                print(elm.text)
                url_name = elm.text
            url_list.append(url_name)
            print('Creating entry for {} with url {}'.format(school_name, url_name))
            urls_df = urls_df.append(pd.DataFrame({'School Name': [school_name], 'URL': [url_name]}), ignore_index=True, sort = False)
            g_driver.get("http://amazon.com")
            time.sleep(3)
            g_driver.get("http://facebook.com")    
    urls_df.to_csv(create_path('University and College Websites update.csv'), index=False)
    return url_list

def get_paper_data(last_name, prof_id, title_index):
    data_stream = []
    data_stream = dict.fromkeys(['Title','Author', 'id', 'Journal', 'BBCite'], 'na')
    data_stream['id'] = prof_id
    element = driver.find_elements_by_xpath('//*[@id="save_results"]/div/div/div/div[' + str(title_index) + ']/div[2]')
    for elm in element:
        my_list = elm.text
    data_list = [a for a in my_list.split('\n') if a != '' and a != 'More Information' and not 'Topics'  in a]
    data_stream['Title'] = data_list[0]
    for a in data_list[1:]:
        if 'Vol.' in a:
            data_stream['Journal'] = a
        if last_name in a:
            data_stream['Author'] = a

    remaining_value = list(set(data_list) - set(list(data_stream.values())))
    if len(remaining_value) == 1:
        data_stream['BBCite'] = data_list[-1]
    return data_stream

# %%
url_list = get_school_urls(urls, new_data['School'])
new_data.insert(4, "School URL", url_list) 
url_list = short_url(new_data['School URL'])
new_data.insert(5, "School URL short", url_list)
print('Complete')
# Out:
# found school: Akron university with url https://www.uakron.edu/
# found school: Akron university with url https://www.uakron.edu/
# found school: Akron university with url https://www.uakron.edu/
# found school: Akron university with url https://www.uakron.edu/
# found school: Alabama university with url https://www.ua.edu/
# found school: Alabama university with url https://www.ua.edu/
# found school: Alabama university with url https://www.ua.edu/
# found school: Alabama university with url https://www.ua.edu/
# found school: Alabama university with url https://www.ua.edu/
# found school: Alabama university with url https://www.ua.edu/
# found school: Alabama university with url https://www.ua.edu/
# found school: Alabama university with url https://www.ua.edu/
# found school: Albany university with url https://www.albany.edu/
# found school: Alberta university with url https://www.ualberta.ca/
# found school: American (Wash Coll of Law) university with url https://www.wcl.american.edu/
# found school: American (Wash Coll of Law) university with url https://www.wcl.american.edu/
# found school: Arizona university with url https://www.arizona.edu/
# found school: Arizona university with url https://www.arizona.edu/
# found school: Arizona university with url https://www.arizona.edu/
# found school: Arizona State university with url https://www.asu.edu/
# found school: Arizona State university with url https://www.asu.edu/
# found school: Arizona State university with url https://www.asu.edu/
# found school: Arizona State university with url https://www.asu.edu/
# found school: Arizona State university with url https://www.asu.edu/
# found school: Arizona State university with url https://www.asu.edu/
# found school: Arkansas university with url https://www.uark.edu/
# found school: Arkansas-Fayetteville university with url https://www.uark.edu/
# found school: Arkansas-Fayetteville university with url https://www.uark.edu/
# found school: Arkansas-Fayetteville university with url https://www.uark.edu/
# found school: Baltimore university with url www.ubalt.edu/
# found school: Baltimore university with url www.ubalt.edu/
# found school: Barry university with url https://www.barry.edu/
# found school: Barry university with url https://www.barry.edu/
# found school: Barry university with url https://www.barry.edu/
# found school: Barry university with url https://www.barry.edu/
# found school: Barry university with url https://www.barry.edu/
# found school: Barry university with url https://www.barry.edu/
# found school: Berkeley university with url https://www.berkeley.edu/
# found school: Berkeley university with url https://www.berkeley.edu/
# found school: Berkeley university with url https://www.berkeley.edu/
# found school: Berkeley university with url https://www.berkeley.edu/
# found school: Boston College university with url https://www.bc.edu/
# found school: Boston College university with url https://www.bc.edu/
# found school: Boston College university with url https://www.bc.edu/
# found school: Boston College university with url https://www.bc.edu/
# found school: Boston College university with url https://www.bc.edu/
# found school: Boston College university with url https://www.bc.edu/
# found school: Boston University university with url https://www.bu.edu/
# found school: Boston University university with url https://www.bu.edu/
# found school: Boston University university with url https://www.bu.edu/
# found school: Boston University university with url https://www.bu.edu/
# found school: Boston University university with url https://www.bu.edu/
# found school: Brooklyn university with url https://www.bu.edu/
# found school: Brooklyn university with url https://www.bu.edu/
# found school: Brooklyn university with url https://www.bu.edu/
# found school: Brooklyn university with url https://www.bu.edu/
# found school: Brooklyn College Sociology university with url www.brooklyn.cuny.edu › ... › Departments › Sociology
# found school: Buffalo university with url www.buffalo.edu/
# found school: Buffalo university with url www.buffalo.edu/
# found school: BYU university with url https://www.byu.edu/
# found school: BYU university with url https://www.byu.edu/
# found school: BYU university with url https://www.byu.edu/
# found school: BYU university with url https://www.byu.edu/
# found school: BYU university with url https://www.byu.edu/
# found school: BYU university with url https://www.byu.edu/
# found school: Cal Western university with url https://www.lostcolleges.com/california-western-university
# found school: Cal Western university with url https://www.lostcolleges.com/california-western-university
# found school: Cal Western university with url https://www.lostcolleges.com/california-western-university
# found school: Calgary university with url https://www.ucalgary.ca/
# found school: California Western university with url https://www.lostcolleges.com/california-western-university
# found school: California Western university with url https://www.lostcolleges.com/california-western-university
# found school: California Western university with url https://www.lostcolleges.com/california-western-university
# found school: Campbell university with url https://www.campbell.edu/
# found school: Cardozo university with url https://cardozo.yu.edu/
# found school: Cardozo university with url https://cardozo.yu.edu/
# found school: Cardozo university with url https://cardozo.yu.edu/
# found school: Chicago university with url https://www.uchicago.edu/
# found school: Chicago university with url https://www.uchicago.edu/
# found school: Chicago university with url https://www.uchicago.edu/
# found school: Chicago university with url https://www.uchicago.edu/
# found school: Chicago university with url https://www.uchicago.edu/
# found school: Chinese U of Hong Kong university with url www.cuhk.edu.hk/
# found school: Chinese University of Hong Kong university with url www.cuhk.edu.hk/
# found school: Colorado university with url https://www.colorado.edu/
# found school: Colorado university with url https://www.colorado.edu/
# found school: Colorado university with url https://www.colorado.edu/
# found school: Colorado university with url https://www.colorado.edu/
# found school: Colorado university with url https://www.colorado.edu/
# found school: Colorado university with url https://www.colorado.edu/
# found school: Columbia university with url https://www.columbia.edu/
# found school: Columbia university with url https://www.columbia.edu/
# found school: Columbia university with url https://www.columbia.edu/
# found school: Columbia university with url https://www.columbia.edu/
# found school: Columbia university with url https://www.columbia.edu/
# found school: Concordia university with url https://www.csp.edu/
# found school: Concordia university with url https://www.csp.edu/
# found school: Concordia university with url https://www.csp.edu/
# found school: Concordia university with url https://www.csp.edu/
# found school: Concordia university with url https://www.csp.edu/
# found school: Connecticut university with url https://uconn.edu/
# found school: Connecticut university with url https://uconn.edu/
# found school: Connecticut university with url https://uconn.edu/
# found school: Connecticut university with url https://uconn.edu/
# found school: Cornell university with url https://www.cornell.edu/
# found school: Cornell university with url https://www.cornell.edu/
# found school: Cornell university with url https://www.cornell.edu/
# found school: Cornell university with url https://www.cornell.edu/
# found school: Cornell university with url https://www.cornell.edu/
# found school: Cornell university with url https://www.cornell.edu/
# found school: CUNY university with url https://www2.cuny.edu/
# found school: Davis university with url https://www.ucdavis.edu/
# found school: Davis university with url https://www.ucdavis.edu/
# found school: Dayton university with url https://udayton.edu/
# found school: Deakin university with url https://www.deakin.edu.au/
# found school: Denver university with url https://www.du.edu/
# found school: Denver university with url https://www.du.edu/
# found school: Detroit Mercy university with url https://www.udmercy.edu/
# found school: Drexel university with url https://drexel.edu/
# found school: Duke university with url https://www.duke.edu/
# found school: Duke university with url https://www.duke.edu/
# found school: Duke university with url https://www.duke.edu/
# found school: Duquesne university with url https://www.duq.edu/
# found school: Duquesne university with url https://www.duq.edu/
# found school: Duquesne university with url https://www.duq.edu/
# found school: Emory university with url www.emory.edu/home/index.html
# found school: Emory university with url www.emory.edu/home/index.html
# found school: Florida university with url www.ufl.edu/
# found school: Florida university with url www.ufl.edu/
# found school: Florida State university with url https://www.fsu.edu/
# found school: Florida State university with url https://www.fsu.edu/
# found school: Florida State university with url https://www.fsu.edu/
# found school: Florida State university with url https://www.fsu.edu/
# found school: Fordham university with url https://www.fordham.edu/
# found school: George Mason university with url https://www2.gmu.edu/
# found school: George Mason university with url https://www2.gmu.edu/
# found school: George Mason university with url https://www2.gmu.edu/
# found school: George Mason university with url https://www2.gmu.edu/
# found school: George Mason university with url https://www2.gmu.edu/
# found school: Georgetown university with url https://www.georgetown.edu/
# found school: Georgetown university with url https://www.georgetown.edu/
# found school: Georgetown university with url https://www.georgetown.edu/
# found school: Georgetown university with url https://www.georgetown.edu/
# found school: Georgetown university with url https://www.georgetown.edu/
# found school: Georgetown university with url https://www.georgetown.edu/
# found school: Georgetown university with url https://www.georgetown.edu/
# found school: Georgetown university with url https://www.georgetown.edu/
# found school: Georgia university with url https://www.uga.edu/
# found school: Georgia university with url https://www.uga.edu/
# found school: Georgia State university with url https://www.gsu.edu/
# found school: GW university with url https://www.gwu.edu/
# found school: GW university with url https://www.gwu.edu/
# found school: Harvard university with url https://www.harvard.edu/
# found school: Harvard university with url https://www.harvard.edu/
# found school: Harvard university with url https://www.harvard.edu/
# found school: Harvard university with url https://www.harvard.edu/
# found school: Harvard university with url https://www.harvard.edu/
# found school: Harvard university with url https://www.harvard.edu/
# found school: Harvard Medical School university with url https://hms.harvard.edu/
# found school: Hastings university with url https://www.hastings.edu/
# found school: Hastings university with url https://www.hastings.edu/
# found school: Hastings university with url https://www.hastings.edu/
# found school: Hastings university with url https://www.hastings.edu/
# found school: Hawaii university with url https://www.hawaii.edu/
# found school: Hebrew university with url https://new.huji.ac.il/en
# found school: Hebrew University university with url https://overseas.huji.ac.il/
# found school: Hofstra university with url https://www.hofstra.edu/
# found school: Hofstra university with url https://www.hofstra.edu/
# found school: Hong Kong university with url https://www.hku.hk/
# found school: Houston university with url www.uh.edu/
# found school: Houston university with url www.uh.edu/
# found school: Houston university with url www.uh.edu/
# found school: Howard university with url https://home.howard.edu/
# found school: Howard university with url https://home.howard.edu/
# found school: Howard university with url https://home.howard.edu/
# found school: Idaho university with url https://www.uidaho.edu/
# found school: Idaho university with url https://www.uidaho.edu/
# found school: Idaho university with url https://www.uidaho.edu/
# found school: Idaho university with url https://www.uidaho.edu/
# found school: Idaho university with url https://www.uidaho.edu/
# found school: Illinois university with url https://illinois.edu/
# found school: Illinois university with url https://illinois.edu/
# found school: Indiana (Bloomington) university with url https://www.indiana.edu/
# found school: Indiana (Bloomington) university with url https://www.indiana.edu/
# found school: Indiana Kelley Sch of Bus university with url https://kelley.iu.edu/
# found school: Indiana Tech university with url https://www.indianatech.edu/
# found school: Indiana-Bloomington university with url https://www.indiana.edu/
# found school: Indiana-Bloomington university with url https://www.indiana.edu/
# found school: Iowa university with url https://uiowa.edu/
# found school: Iowa university with url https://uiowa.edu/
# found school: Iowa university with url https://uiowa.edu/
# found school: Iowa university with url https://uiowa.edu/
# found school: Iowa university with url https://uiowa.edu/
# found school: Iowa university with url https://uiowa.edu/
# found school: Iowa university with url https://uiowa.edu/
# found school: Iowa university with url https://uiowa.edu/
# found school: Iowa university with url https://uiowa.edu/
# found school: Kelley School (Indiana) university with url https://kelley.iu.edu/
# found school: Kentucky university with url www.uky.edu/
# found school: Kentucky university with url www.uky.edu/
# found school: Kentucky university with url www.uky.edu/
# found school: LaVerne university with url https://laverne.edu/
# found school: LaVerne university with url https://laverne.edu/
# found school: Legal Stud. Dept Fox Bus. Sch. Temple university with url https://www.fox.temple.edu/departments/legal-studies-in-business/
# found school: London School of Economics university with url www.lse.ac.uk/
# found school: Louisville university with url louisville.edu/
# found school: Louisville university with url louisville.edu/
# found school: Loyola-Chicago university with url https://www.luc.edu/
# found school: LSU university with url https://www.lsu.edu/
# found school: LSU university with url https://www.lsu.edu/
# found school: LSU university with url https://www.lsu.edu/
# found school: LSU university with url https://www.lsu.edu/
# found school: Maine university with url https://umaine.edu/
# found school: Maine university with url https://umaine.edu/
# found school: Marine Corps University university with url https://www.usmcu.edu/
# found school: Marquette university with url https://www.marquette.edu/
# found school: Marron Institute (NYU) university with url https://marroninstitute.nyu.edu/
# found school: Maryland university with url https://www.umd.edu/
# found school: Massachusetts university with url https://www.massachusetts.edu/
# found school: McGeorge university with url https://www.mcgeorge.edu/
# found school: Memphis university with url https://www.memphis.edu/
# found school: Miami university with url miamioh.edu/
# found school: Miami university with url miamioh.edu/
# found school: Michigan university with url https://umich.edu/
# found school: Michigan university with url https://umich.edu/
# found school: Michigan university with url https://umich.edu/
# found school: Michigan State university with url https://msu.edu/
# found school: MIchigan State university with url https://msu.edu/
# found school: Mississippi university with url https://en.wikipedia.org/wiki/University_of_Mississippi
# found school: Mississippi College university with url https://www.mc.edu/
# found school: Missouri university with url https://missouri.edu/
# found school: Missouri university with url https://missouri.edu/
# found school: Missouri - Kansas City university with url https://www.umkc.edu/
# found school: Monash Business School university with url https://www.monash.edu/business
# found school: Montana university with url https://www.umt.edu/
# found school: Nebraska university with url https://www.unl.edu/
# found school: Nebraska university with url https://www.unl.edu/
# found school: New Hampshire university with url https://www.snhu.edu/
# found school: New Hampshire university with url https://www.snhu.edu/
# found school: New Hampshire university with url https://www.snhu.edu/
# found school: New Mexico university with url https://www.unm.edu/
# found school: New York Law university with url https://www.law.nyu.edu/
# found school: New York Law university with url https://www.law.nyu.edu/
# found school: Newcastle (Australia) university with url https://www.newcastle.edu.au/
# found school: North Carolina university with url https://www.unc.edu/
# found school: North Carolina university with url https://www.unc.edu/
# found school: North South U (Bangladesh) university with url www.northsouth.edu/
# found school: Northeastern university with url https://www.northeastern.edu/
# found school: Northern Illinois university with url https://www.niu.edu/
# found school: Northern Illinois university with url https://www.niu.edu/
# found school: Northern Illinois university with url https://www.niu.edu/
# found school: Northern Illinois university with url https://www.niu.edu/
# found school: Northern Kentucky university with url https://www.nku.edu/
# found school: Northwestern university with url https://www.northwestern.edu/
# found school: Northwestern university with url https://www.northwestern.edu/
# found school: Northwestern university with url https://www.northwestern.edu/
# found school: Northwestern university with url https://www.northwestern.edu/
# found school: Notre Dame university with url https://www.nd.edu/
# found school: Notre Dame university with url https://www.nd.edu/
# found school: Notre Dame university with url https://www.nd.edu/
# found school: Notre Dame university with url https://www.nd.edu/
# found school: NYU university with url https://www.nyu.edu/
# found school: Ohio Northern university with url https://www.onu.edu/
# found school: Ohio Northern university with url https://www.onu.edu/
# found school: Ohio Northern university with url https://www.onu.edu/
# found school: Ohio Northern university with url https://www.onu.edu/
# found school: Ohio State university with url https://www.osu.edu/
# found school: Ohio State university with url https://www.osu.edu/
# found school: Ohio State university with url https://www.osu.edu/
# found school: Ohio State university with url https://www.osu.edu/
# found school: Ohio State university with url https://www.osu.edu/
# found school: Ohio State university with url https://www.osu.edu/
# found school: Ohio State university with url https://www.osu.edu/
# found school: Oklahoma university with url www.ou.edu/
# found school: Oklahoma university with url www.ou.edu/
# found school: Oklahoma university with url www.ou.edu/
# found school: Oregon university with url https://www.uoregon.edu/
# found school: Pace university with url https://www.pace.edu/
# found school: Pace university with url https://www.pace.edu/
# found school: Penn university with url https://www.upenn.edu/
# found school: Penn university with url https://www.upenn.edu/
# found school: Penn State university with url https://www.psu.edu/
# found school: Penn State (University Park) university with url https://www.psu.edu/
# found school: Penn State (University Park) university with url https://www.psu.edu/
# found school: Penn State Dickinson university with url https://dickinsonlaw.psu.edu/
# found school: Pitt university with url https://www.pitt.edu/
# found school: Pittsburgh university with url https://www.pitt.edu/
# found school: Puerto Rico Poli Sci Dept university with url https://polsci.umass.edu/people/roberto-alejandro
# found school: Queen's university with url https://www.queensu.ca/
# found school: Quinnipiac university with url https://www.qu.edu/
# found school: Quinnipiac university with url https://www.qu.edu/
# found school: Richmond university with url https://www.richmond.edu/
# found school: Richmond university with url https://www.richmond.edu/
# found school: Richmond university with url https://www.richmond.edu/
# found school: Richmond university with url https://www.richmond.edu/
# found school: Richmond university with url https://www.richmond.edu/
# found school: Richmond university with url https://www.richmond.edu/
# found school: Richmond university with url https://www.richmond.edu/
# found school: Roger Williams university with url https://www.rwu.edu/
# found school: Rutgers university with url https://www.rutgers.edu/
# found school: Rutgers (Camden) university with url https://www.camden.rutgers.edu/
# found school: Rutgers (Camden) university with url https://www.camden.rutgers.edu/
# found school: Rutgers (Camden) university with url https://www.camden.rutgers.edu/
# found school: Samford (Cumberland) university with url https://www.samford.edu/cumberlandlaw/
# found school: San Diego university with url https://www.sandiego.edu/
# found school: Savannah university with url https://www.savannahstate.edu/
# found school: Savannah university with url https://www.savannahstate.edu/
# found school: Seton Hall university with url https://www.shu.edu/
# found school: SF State university with url https://www.sfsu.edu/
# found school: SMU university with url https://www.smu.edu/
# found school: SMU university with url https://www.smu.edu/
# found school: South Carolina university with url https://www.sc.edu/
# found school: South Carolina university with url https://www.sc.edu/
# found school: South Carolina university with url https://www.sc.edu/
# found school: South Carolina university with url https://www.sc.edu/
# found school: South Carolina university with url https://www.sc.edu/
# found school: South Carolina university with url https://www.sc.edu/
# found school: South Carolina university with url https://www.sc.edu/
# found school: South Carolina university with url https://www.sc.edu/
# found school: South Carolina university with url https://www.sc.edu/
# found school: South Carolina university with url https://www.sc.edu/
# found school: South Dakota university with url https://www.usd.edu/
# found school: Southwestern university with url https://www.southwestern.edu/
# found school: St. John's university with url https://www.stjohns.edu/
# found school: St. John's university with url https://www.stjohns.edu/
# found school: St. John's university with url https://www.stjohns.edu/
# found school: St. John's university with url https://www.stjohns.edu/
# found school: St. Louis university with url https://www.slu.edu/
# found school: St. Thomas (Minnesota) university with url https://www.stthomas.edu/
# found school: Stanford university with url https://www.stanford.edu/
# found school: Stanford university with url https://www.stanford.edu/
# found school: Stanford university with url https://www.stanford.edu/
# found school: Stanford university with url https://www.stanford.edu/
# found school: Stanford university with url https://www.stanford.edu/
# found school: Suffolk university with url https://www.suffolk.edu/
# found school: Suffolk university with url https://www.suffolk.edu/
# found school: Suffolk university with url https://www.suffolk.edu/
# found school: SUNY Buffalo university with url https://www.suny.edu/campuses/buffalo/
# found school: Surrey university with url https://www.surrey.ac.uk/
# found school: Surrey university with url https://www.surrey.ac.uk/
# found school: Surrey university with url https://www.surrey.ac.uk/
# found school: Surrey university with url https://www.surrey.ac.uk/
# found school: Surrey university with url https://www.surrey.ac.uk/
# found school: Surrey university with url https://www.surrey.ac.uk/
# found school: Temple university with url https://www.temple.edu/
# found school: Temple university with url https://www.temple.edu/
# found school: Tennessee university with url https://www.utk.edu/
# found school: Texas A&M university with url https://www.tamu.edu/
# found school: Texas A&M university with url https://www.tamu.edu/
# found school: Texas A&M university with url https://www.tamu.edu/
# found school: Texas A&M university with url https://www.tamu.edu/
# found school: Texas A&M university with url https://www.tamu.edu/
# found school: Texas A&M university with url https://www.tamu.edu/
# found school: Texas A&M university with url https://www.tamu.edu/
# found school: Texas Tech university with url https://www.ttu.edu/
# found school: Texas Tech university with url https://www.ttu.edu/
# found school: Toldeo university with url https://www.utoledo.edu/
# found school: Toronto university with url https://www.utoronto.ca/
# found school: Toronto university with url https://www.utoronto.ca/
# found school: Tulane university with url https://tulane.edu/
# found school: Tulsa university with url https://utulsa.edu/
# found school: Tulsa university with url https://utulsa.edu/
# found school: UC Davis university with url https://www.ucdavis.edu/
# found school: UC Davis university with url https://www.ucdavis.edu/
# found school: UC Davis university with url https://www.ucdavis.edu/
# found school: UC Hastings university with url https://www.uchastings.edu/
# found school: UC Irvine university with url https://uci.edu/
# found school: UC Irvine university with url https://uci.edu/
# found school: UC Irvine university with url https://uci.edu/
# found school: UC Irvine university with url https://uci.edu/
# found school: UC Irvine university with url https://uci.edu/
# found school: UCLA university with url www.ucla.edu/
# found school: UCLA university with url www.ucla.edu/
# found school: UCLA university with url www.ucla.edu/
# found school: UCLA university with url www.ucla.edu/
# found school: UCLA university with url www.ucla.edu/
# found school: UCLA university with url www.ucla.edu/
# found school: UDC university with url https://www.udc.edu/
# found school: University of British Columbia university with url https://www.ubc.ca/
# found school: UNLV university with url https://www.unlv.edu/
# found school: USC university with url https://www.usc.edu/
# found school: Utah university with url https://www.utah.edu/
# found school: Utah university with url https://www.utah.edu/
# found school: Valparaiso university with url https://www.valpo.edu/
# found school: Vanderbilt university with url https://www.vanderbilt.edu/
# found school: Vanderbilt university with url https://www.vanderbilt.edu/
# found school: Vanderbilt university with url https://www.vanderbilt.edu/
# found school: Vanderbilt university with url https://www.vanderbilt.edu/
# found school: Vermont university with url https://www.uvm.edu/
# found school: Vermont university with url https://www.uvm.edu/
# found school: Villanova university with url https://www1.villanova.edu/
# found school: Villanova university with url https://www1.villanova.edu/
# found school: Virginia university with url www.virginia.edu/
# found school: Virginia university with url www.virginia.edu/
# found school: Virginia university with url www.virginia.edu/
# found school: Virginia university with url www.virginia.edu/
# found school: Wake Forest university with url https://www.wfu.edu/
# found school: Wake Forest university with url https://www.wfu.edu/
# found school: Washburn university with url https://washburn.edu/
# found school: Washington (St. Louis) university with url https://wustl.edu/
# found school: Washington (St. Louis) university with url https://wustl.edu/
# found school: Washington (University of) university with url https://wustl.edu/
# found school: Washington (University of) university with url https://wustl.edu/
# found school: Wayne university with url https://wayne.edu/
# found school: Wayne State university with url https://wayne.edu/
# found school: Wayne State university with url https://wayne.edu/
# found school: Wayne State university with url https://wayne.edu/
# found school: West Virginia university with url https://www.wvu.edu/
# found school: West Virginia university with url https://www.wvu.edu/
# found school: Wharton university with url https://www.wharton.upenn.edu/
# found school: Wharton university with url https://www.wharton.upenn.edu/
# found school: Wharton Legal Studies university with url https://lgst.wharton.upenn.edu/
# found school: Wharton Legal Studies university with url https://lgst.wharton.upenn.edu/
# found school: Willamette university with url https://willamette.edu/
# found school: Willamette university with url https://willamette.edu/
# found school: Willamette university with url https://willamette.edu/
# found school: William & Mary university with url https://www.wm.edu/
# found school: William & Mary university with url https://www.wm.edu/
# found school: Wisconsin university with url https://www.wisc.edu/
# found school: Wisconsin university with url https://www.wisc.edu/
# found school: Wisconsin university with url https://www.wisc.edu/
# found school: Wisconsin university with url https://www.wisc.edu/
# found school: Wisconsin university with url https://www.wisc.edu/
# found school: Wisconsin university with url https://www.wisc.edu/
# found school: Wyoming university with url www.uwyo.edu/
# found school: Wyoming university with url www.uwyo.edu/
# found school: Yale university with url https://www.yale.edu/
# found school: Yale university with url https://www.yale.edu/
# found school: Yale university with url https://www.yale.edu/
# found school: Yale university with url https://www.yale.edu/
# Complete

# %%
new_data.to_csv(create_path('multi_school_data', 'new_junior_faculty_name_data.csv'))

# %%
os.getcwd()
stats = ['Cited by Cases','Cited by Articles','Accessed (Past 12 Months)','Cited by Articles (Past 10 Years)', 'Cited by Articles (Past 1-2 years)', 'ScholarCheck Rank', 'Average Citations per Article', 'Average Citations per Document', 'Self-Citations']
path = create_path('multi_school_data', 'junior_faculty')
files = os.listdir(path)
school_name = 'junior_faculty_multi_school'
delay = 5
current_papers = os.listdir(create_path('author_papers'))
current_stats = os.listdir(create_path('school_stats'))
current_skip = os.listdir(create_path('skipped_names'))
for file in files:
    print(file)
    main_df = pd.DataFrame()
    file1 = check_df(current_stats, school_name)
    if file1 != '':
        main_df = pd.read_csv(create_path('school_stats', file1))
    skip_df = pd.DataFrame(columns = ['Full Name', 'School'])
    file2 = check_df(current_skip, school_name)
    if file2 != '':
        skip_df = pd.read_csv(create_path('skipped_names', file2))
    data = pd.read_csv(os.path.join(path, file)) 
    if not 'id' in data.columns:
        data.insert(len(data.columns), 'id', random.sample(range(10000), len(data)), True)   
        data.to_csv(os.path.join(path, file))
    for i in range(len(data)):
        prof_id = data['id'][i]
        #Get name and information from the database
        mid_first_name = data['First Name'][i]
        last_name = data['Last Name'][i]
        full_name = mid_first_name + ' ' +  last_name
        done = check_files(mid_first_name, last_name, current_papers)
        #old url
        school_url = [data['School URL short'][i]]
        if done:
            print('File for ' + full_name + ' has already been created.')
            continue
        school = data['School'][i]
        title = data['Title'][i]
        page_name = []
        err_fm_names = []
        df_sub = pd.DataFrame()
        #Search by author to find potential alternative first and middle names:
        fm_names, err_fm_names = search_names(mid_first_name, last_name, school_url)
        print(fm_names)
        if not fm_names:
            print('Name ' + full_name + ' was not found')
            skip_df = skip_df.append(pd.DataFrame([[full_name, school, title]], columns = ['Full Name', 'School', 'Title']), sort=False)
            
        for fm_name in fm_names:
            link = 'https://heinonline-org.proxy01.its.virginia.edu/HOL/AuthorProfile?action=edit&search_name=' + last_name +  '%2C ' + fm_name + '&collection=journals'
            driver.get(link)
            soup=bs.BeautifulSoup(driver.page_source, 'lxml')
            table_rows = soup.findAll('td', {'style': 'text-align:right;'})
            full_name = fm_name + ' ' +  last_name
            webpage_wait('//*[@id="page_content"]/div[1]/div/div[1]/div[1]')
            fm_names, err_fm_names = similar_names(fm_names, err_fm_names, fm_name, last_name)
            cur_page = driver.find_element_by_xpath('//*[@id="page_content"]/div[1]/div/div[1]/div[1]').text
            if not table_rows:
                got_page = False
                new_names = False
                link_index = 1
                while new_names == False:
                    try:
                        if link_index == 1:
                            element =driver.find_element_by_xpath('//*[@id="page_content"]/div[2]/div/ul/li/a')
                        else: 
                            element =driver.find_element_by_xpath('//*[@id="page_content"]/div[2]/div/ul/li[' + str(link_index) + ']/a')            
                        new_fm_name = element.text.split(', ')[1]
                        new_last_name = element.text.split(', ')[0]
                        if last_name == new_last_name and mid_first_name in new_fm_name:
                            if not new_fm_name in fm_names:
                                check_google(new_fm_name, last_name, school_url)
                                fm_names.append(new_fm_name)
                            
                    except: 
                        new_names = True
                        got_page = True
                        if not scraped_papers:
                            print('Name ' + full_name + ' is not in the database. You may be missing a middle initial.')
                            skip_df = skip_df.append(pd.DataFrame([[full_name, school, title]], columns = ['Full Name', 'School', 'Title']), sort=False)
                        else:
                            print('No remaining pages to scrape from {}.'.format(full_name))
                    link_index += 1
                    
            elif table_rows and cur_page not in page_name: 
                element = driver.find_element_by_xpath('//*[@id="page_content"]/div[1]/div/div[2]')
                table_element = element.text.split('\n')
                if len(table_element) < 5:
                    print('No data available on Hein for {} {}'.format(fm_name, last_name))
                else:
                    number_list = []
                    rank_list = []
                    stat_list = []
                    for stat in stats:
                        find_index = [table_element.index(s) for s in table_element if stat == s]
                        if find_index:
                            my_list = table_element[find_index[0]+1].split(' ')
                            number_list.append(my_list[0])
                            stat_list.append(stat)
                            if len(my_list) > 1:
                                rank_list.append(my_list[-1])
                        if stat == 'Self-Citations':
                            find_index = [table_element.index(s) for s in table_element if stat in s]
                            if find_index:
                                stat_list.append(stat)
                                number_list.append(table_element[find_index[0]].split(' ')[1])
                    zip_number_list = list(zip(stat_list, number_list))
                    zip_rank_list = list(zip(stat_list, rank_list))
                    number_dict = create_dataframe_dict(zip_number_list)
                    rank_dict = create_dataframe_dict(zip_rank_list)
                    df_number = pd.DataFrame.from_dict(number_dict, orient='index').transpose()
                    df_rank = pd.DataFrame.from_dict(rank_dict, orient='index').transpose()
                    df_number = df_number.replace('na', '0')
                    df_number = df_number.replace('', '0')
                    df_number = df_number.replace(' ', '0')
                    df_number = remove_commas(df_number)
                    df_number = df_number.astype(float)
                    if df_sub.empty:
                        df_sub = df_number
                    else: 
                        df_sub = df_sub.add(df_number)

                    title_index = 3
                    stats_index = 4
                    topic_index = 0
                    topic_div_index = 0
                    soup=bs.BeautifulSoup(driver.page_source, 'lxml')
                    topic_array = soup.findAll('div', {'class': 'topics'})
                    element = title_index
                    page_name = []
                    df = pd.DataFrame(columns = ['Title', 'Author(s)', 'id', 'Journal', 'BBCite', 'Cited (articles)', 'Cited (cases)', 'Accessed', 'Topics'])
                    while element:
                        data_stream = []
                        data_dict = get_paper_data(last_name, prof_id, title_index)
                        element = driver.find_elements_by_xpath('//*[@id="save_results"]/div/div/div/div[' + str(stats_index) + ']/div[2]/div')
                        for elm in element:
                            cited_text = elm.text
                        article_citations = 'na'
                        case_citations = 'na'
                        accessed = 'na'
                        if not isinstance(cited_text, list):
                            cited_text = cited_text.split('\n')
                            cited_text
                            for stat in cited_text:
                                if 'Article' in stat:
                                    article_citations = int(re.search(r'\d+', stat).group())
                                if 'Case' in stat:
                                    case_citations = int(re.search(r'\d+', stat).group())
                                if 'Accessed' in stat:
                                    accessed = int(re.search(r'\d+', stat).group())
                        data_stream.append(article_citations)
                        data_stream.append(case_citations)
                        data_stream.append(accessed)
                        if 'Topics:' in my_list:
                            data_stream.append(topic_array[topic_div_index].text.split(':')[1])
                            topic_div_index +=1
                        else:
                            data_stream.append('na')
                        data_stream = list(data_dict.values()) + data_stream
                        df = df.append(pd.DataFrame([data_stream], columns = ['Title', 'Author(s)', 'id', 'Journal', 'BBCite', 'Cited (articles)', 'Cited (cases)', 'Accessed', 'Topics']))
                        stats_index +=4
                        title_index += 4
                        page_name.append(cur_page)
                        #Check that next paper exists:
                        x_path_title = '//*[@id="save_results"]/div/div/div/div[' + str(title_index) + ']/div[2]/dt[1]/div'
                        element = driver.find_elements_by_xpath(x_path_title)
                    df.to_csv(create_path('author_papers', '{}_{}_{}_papers.csv'.format(full_name, prof_id, school)),index=False)
                    time.sleep(3)
                print('No remaining pages to scrape for {}.'.format(fm_name + ' ' + last_name))  
        if not df_sub.empty:
            my_dict = {'Person': [full_name], 'ID': [prof_id], 'School': [school], 'Type': ['number']}
            name_data = pd.DataFrame(my_dict)
            df_sub = pd.concat([name_data, df_sub], sort = False, axis = 1)
            main_df = pd.concat([main_df, df_sub], sort = False)
            main_df.replace(0, 'na')
            main_df.to_csv(create_path('school_stats', '{}_stats.csv'.format(school_name)),index=False)                
        skip_df.to_csv(create_path('skipped_names', '{}_skipped.csv'.format(school_name)), index = False)
                    
skip_df.to_csv(create_path('skipped_names', '{}_skipped.csv'.format(school_name)),index=False)
main_df.replace(0, 'na')
main_df.to_csv(create_path('school_stats', '{}_stats.csv'.format(school_name)),index=False)
# Out:
# new_junior_faculty_name_data.csv
# uakron in: Vera Korzun - The University of Akron
# https://www.uakron.edu/law/docs/Vera%20Korzun%20CV%20August%202018.pdf
# ['Vera']
# No remaining pages to scrape for Vera Korzun.
# []
# Name Dan Brean was not found
# uakron in: Camilla Hrdy - The University of Akron
# https://www.uakron.edu/law/faculty/profile.dot?identity=f930a63d-04e8-4c6e-91ee...
# uakron in: Camilla Hrdy - The University of Akron
# https://www.uakron.edu/law/faculty/profile.dot?identity=f930a63d-04e8-4c6e-91ee...
# ['Camilla A.', 'Camilla']
# No remaining pages to scrape for Camilla A. Hrdy.
# uakron in: Elizabeth Knowles - The University of Akron
# https://www.uakron.edu/law/faculty/directory/profile.dot?u=eknowles
# ['Elizabeth']
# No remaining pages to scrape for Elizabeth Knowles.
# ua in: Benjamin J. McMichael - University of Alabama School of Law
# https://www.law.ua.edu/directory/files/cv/McMichael-Benjamin-cv.pdf
# ['Benjamin J.']
# No remaining pages to scrape for Benjamin J. McMichael.
# ua in: Deepa Das Acevedo | University of Alabama School of Law
# https://www.law.ua.edu/directory/People/view/Deepa_Das_Acevedo
# ['Deepa']
# No remaining pages to scrape for Deepa Das Acevedo.
# ua in: Meghan Boone | University of Alabama School of Law
# https://www.law.ua.edu/directory/People/view/Meghan_Boone
# ua in: Meghan Boone | University of Alabama School of Law
# https://www.law.ua.edu/directory/People/view/Meghan_Boone
# ['Meghan', 'Meghan M.']
# No remaining pages to scrape for Meghan Boone.
# ua in: Casey Faucon | University of Alabama School of Law
# https://www.law.ua.edu/directory/People/view/Casey_Faucon
# ['Casey E.']
# No remaining pages to scrape for Casey E. Faucon.
# ua in: Yonathan Arbel | University of Alabama School of Law
# https://www.law.ua.edu/directory/People/view/Yonathan_Arbel
# ['Yonathan A.']
# No remaining pages to scrape for Yonathan A. Arbel.
# ua in: Courtney K. Cross | University of Alabama School of Law
# https://www.law.ua.edu/directory/People/view/Courtney_K._Cross
# ['Courtney']
# No remaining pages to scrape for Courtney Cross.
# ua in: Allyson E. Gold | University of Alabama School of Law
# https://www.law.ua.edu/directory/People/view/Allyson_E._Gold
# ua in: Allyson E. Gold | University of Alabama School of Law
# https://www.law.ua.edu/directory/People/view/Allyson_E._Gold
# ['Allyson', 'Allyson E.']
# No remaining pages to scrape for Allyson Gold.
# ua in: ua
# ['Stephen']
# No remaining pages to scrape for Stephen Rushin.
# []
# Name Ted De Barbieri was not found
# ualberta in: Jessica Eisen | Faculty of Law - University of Alberta
# https://www.ualberta.ca/law/faculty-and-research/profiles/jessica-eisen
# ['Jessica']
# No remaining pages to scrape for Jessica Eisen.
# wcl.american in: Rebecca Hamilton - Faculty - American University Washington ...
# https://www.wcl.american.edu › Our Community › Faculty
# wcl.american in: Rebecca Hamilton - Faculty - American University Washington ...
# https://www.wcl.american.edu › Our Community › Faculty
# ['Rebecca', 'Rebecca J.']
# No remaining pages to scrape for Rebecca Hamilton.
# wcl.american in: Anita Sinha - Faculty - American University Washington College of Law
# https://www.wcl.american.edu › Our Community › Faculty
# ['Anita']
# No remaining pages to scrape for Anita Sinha.
# arizona in: Tammi Walker | University of Arizona Law
# https://law.arizona.edu/tammi-walker
# ['Tammi']
# No remaining pages to scrape for Tammi Walker.
# arizona in: Jason Kreag | University of Arizona Law
# https://law.arizona.edu/jason-kreag
# ['Jason']
# No remaining pages to scrape for Jason Kreag.
# arizona in: Sergio Puig | University of Arizona Law
# https://law.arizona.edu/sergio-puig
# ['Sergio']
# Sergio Puig De La Parra
# No remaining pages to scrape for Sergio Puig.
# asu in: Justin Weinstein-Tull - iSearch - Arizona State University
# https://isearch.asu.edu/profile/3330817
# ['Justin']
# No remaining pages to scrape for Justin Weinstein-Tull.
# asu in: Trevor Reed - iSearch - Arizona State University
# https://isearch.asu.edu/profile/3322065
# ['Trevor']
# No remaining pages to scrape for Trevor Reed.
# asu in: Bijal Shah | iSearch
# https://isearch.asu.edu/profile/3011691
# ['Bijal']
# No remaining pages to scrape for Bijal Shah.
# asu in: Laura Napoli Coordes | iSearch
# https://isearch.asu.edu/profile/2204645
# ['Laura Napoli']
# No remaining pages to scrape for Laura Napoli Coordes.
# asu in: Erin Scharff | iSearch
# https://isearch.asu.edu/profile/2434987
# ['Erin Adele']
# No remaining pages to scrape for Erin Adele Scharff.
# asu in: Kaiponanea Matsumura | iSearch
# https://isearch.asu.edu/profile/2436475
# asu in: Kaiponanea Matsumura | iSearch
# https://isearch.asu.edu/profile/2436475
# ['Kaiponanea', 'Kaiponanea T.']
# No remaining pages to scrape for Kaiponanea Matsumura.
# uark in: Beth Katya Zilberman | Faculty Directory | School of Law | University of ...
# https://law.uark.edu/directory/directory-faculty/uid/bkzilber/.../Beth+Katya+Zilberman...
# ['Beth K.']
# No remaining pages to scrape for Beth K. Zilberman.
# uark in: Alan Trammell - University of Arkansas School of Law
# https://law.uark.edu/directory/directory-faculty/uid/amtramme/.../Alan-Trammell/
# uark in: Alan M. Trammell | Faculty Directory | School of Law | University of ...
# https://law.uark.edu/directory/directory-faculty/uid/amtramme/.../Alan+M.+Trammell/
# ['Alan', 'Alan M.']
# Alan M. *Trammell
# No remaining pages to scrape for Alan Trammell.
# Alan Trammell
# No remaining pages to scrape for Alan M. Trammell.
# uark in: Jordan Blair Woods | Faculty Directory | School of Law | University of ...
# https://law.uark.edu/directory/directory-faculty/uid/jbwoods/.../Jordan+Blair+Woods/
# uark in: Jordan Woods | Faculty Directory | School of Law | University of ...
# https://law.uark.edu/directory/directory-faculty/uid/jbwoods/name/Jordan-Woods/
# ['Jordan Blair', 'Jordan B.']
# Jordan Blair Woods
# Jordan B. Woods
# No remaining pages to scrape for Jordan Blair Woods.
# Jordan Blair *Woods
# Jordan Blair Woods
# No remaining pages to scrape for Jordan B. Woods.
# uark in: Sara Gosman | Faculty Directory | School of Law | University of Arkansas
# https://law.uark.edu/directory/directory-faculty/uid/sgosman/name/Sara-Gosman/
# ['Sara']
# Sara R. *Gosman
# No remaining pages to scrape for Sara Gosman.
# []
# Name Mattiangai Sirleaf was not found
# ubalt in: Natalie Ram - University of Baltimore
# law.ubalt.edu › Faculty › Profiles
# ['Natalie']
# No remaining pages to scrape for Natalie Ram.
# barry in: Nadia B. Ahmad, Faculty Listing : Faculty : Future ... - Barry University
# https://www.barry.edu › Dwayne O. Andreas School of Law › Future Students › Faculty
# barry in: Nadia B. Ahmad, Faculty Listing : Faculty : Future Students : Dwayne O ...
# https://www.barry.edu › Dwayne O. Andreas School of Law › Future Students › Faculty
# ['Nadia', 'Nadia B.']
# Nadia B. *Ahmad
# No remaining pages to scrape for Nadia Ahmad.
# Nadia Ahmad
# No remaining pages to scrape for Nadia B. Ahmad.
# barry in: Nancy Chi Cantalupo, Faculty Listing : Faculty : Future Students ...
# https://www.barry.edu › Dwayne O. Andreas School of Law › Future Students › Faculty
# barry in: Nancy Chi Cantalupo, Faculty Listing : Faculty ... - Barry University
# https://www.barry.edu › Dwayne O. Andreas School of Law › Future Students › Faculty
# ['Nancy Chi', 'Nancy']
# Nancy Chi Cantalupo
# Nancy Cantalupo
# No remaining pages to scrape for Nancy Chi Cantalupo.
# Nancy Chi *Cantalupo
# Nancy Chi Cantalupo
# No remaining pages to scrape for Nancy Cantalupo.
# barry in: "Disaggregated Classes" by Benjamin P. Edwards
# lawpublications.barry.edu/facultyscholarship/93/
# ['Benjamin']
# Benjamin E. *Edwards
# Benjamin P. *Edwards
# Benjamin R. *Edwards
# No remaining pages to scrape for Benjamin Edwards.
# barry in: Denitsa R. Mavrova Heinrich, Faculty Listing : Faculty : Future ...
# https://www.barry.edu › Dwayne O. Andreas School of Law › Future Students › Faculty
# ['Denitsa R. Mavrova']
# Denitsa Mavrova Heinrich
# Denitsa Mavrova Heinrich
# No remaining pages to scrape for Denitsa R. Mavrova Heinrich.
# []
# Name Khaled Beydoun was not found
# barry in: Barry University News - Barry Law Professor Michael Morley talking on ...
# www.barry.edu › News
# ['Michael']
# Michael J. *Morley
# Michael P. *Morley
# Michael R. *Morley
# No remaining pages to scrape for Michael Morley.
# berkeley in: Abbye Atkinson | Berkeley Law
# https://www.law.berkeley.edu › Faculty Profiles › Professor
# ['Abbye']
# No remaining pages to scrape for Abbye Atkinson.
# berkeley in: Joy Milligan | Berkeley Law
# https://www.law.berkeley.edu › Faculty Profiles › Professor
# ['Joy']
# No remaining pages to scrape for Joy Milligan.
# berkeley in: Tejas Narechania | Berkeley Law
# https://www.law.berkeley.edu › Faculty Profiles › Professor
# ['Tejas N.']
# No remaining pages to scrape for Tejas N. Narechania.
# berkeley in: Catherine Crump | Berkeley Law
# https://www.law.berkeley.edu › Faculty Profiles › Clinical Professor
# ['Catherine']
# No remaining pages to scrape for Catherine Crump.
# bc in: Hiba Hafiz - Law School - Boston College
# https://www.bc.edu/bc-web/schools/law/academics-faculty/faculty.../hiba-hafiz.html
# ['Hiba']
# No remaining pages to scrape for Hiba Hafiz.
# bc in: Daniel Farbman- Law School - Boston College
# https://www.bc.edu/bc-web/schools/law/academics-faculty/.../dan-farbman.html
# ['Daniel']
# No remaining pages to scrape for Daniel Farbman.
# []
# Name Maureen Van Neste was not found
# bc in: Jeffrey Cohen - Law School - Boston College
# https://www.bc.edu/bc-web/schools/law/academics-faculty/.../jeffrey-cohen.html
# bc in: Jeffrey Cohen - Law School - Boston College
# https://www.bc.edu/bc-web/schools/law/academics-faculty/.../jeffrey-cohen.html
# ['Jeffrey', 'Jeffrey M.']
# Jeffrey A. *Cohen
# Jeffrey Allan *Cohen
# Jeffrey B. *Cohen
# Jeffrey C. *Cohen
# Jeffrey F. *Cohen
# Jeffrey H. Cohen
# Jeffrey L. Cohen
# Jeffrey M. Cohen
# Jeffrey S. Cohen
# Jeffrey W. Cohen
# No remaining pages to scrape for Jeffrey Cohen.
# Jeffrey A. *Cohen
# Jeffrey B. *Cohen
# Jeffrey C. *Cohen
# Jeffrey F. *Cohen
# Jeffrey H. *Cohen
# Jeffrey L. *Cohen
# Jeffrey S. *Cohen
# Jeffrey W. *Cohen
# Jeffrey Cohen
# Jeffrey Allan Cohen
# No remaining pages to scrape for Jeffrey M. Cohen.
# bc in: Ryan Williams - Law School - Boston College
# https://www.bc.edu/bc-web/schools/law/academics-faculty/.../ryan-williams.html
# bc in: Ryan Williams - Law School - Boston College
# https://www.bc.edu/bc-web/schools/law/academics-faculty/.../ryan-williams.html
# bc in: Ryan Williams - Law School - Boston College
# https://www.bc.edu/bc-web/schools/law/academics-faculty/.../ryan-williams.html
# bc in: Ryan Williams - Law School - Boston College
# https://www.bc.edu/bc-web/schools/law/academics-faculty/.../ryan-williams.html
# ['Ryan', 'Ryan T.', 'Ryan C.', 'M. Ryan']
# Bryan *Williams
# Bryan F. Jr. *Williams
# Bryan L. *Williams
# Ryan C. *Williams
# Ryan J. *Williams
# Ryan K. *Williams
# Ryan M. *Williams
# M. Ryan Williams
# Ryan T. Williams
# No remaining pages to scrape for Ryan Williams.
# Ryan C. *Williams
# Ryan J. *Williams
# Ryan K. *Williams
# Ryan M. *Williams
# M. Ryan Williams
# Ryan Williams
# No remaining pages to scrape for Ryan T. Williams.
# Ryan J. *Williams
# Ryan K. *Williams
# Ryan M. *Williams
# Ryan T. *Williams
# M. Ryan Williams
# Ryan Williams
# No remaining pages to scrape for Ryan C. Williams.
# Ryan M. Williams
# No remaining pages to scrape for M. Ryan Williams.
# bc in: Natalya Shnitser - Law School - Boston College
# https://www.bc.edu/bc-web/schools/law/academics-faculty/.../natalya-shnitser.html
# ['Natalya']
# No remaining pages to scrape for Natalya Shnitser.
# bu in: Portia Pedro | School of Law - Boston University
# https://www.bu.edu/law/profile/portia-pedro/
# ['Portia']
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# No remaining pages to scrape from Portia Pedro.
# bu in: Scott Hirst | School of Law - Boston University
# https://www.bu.edu/law/profile/scott-hirst/
# ['Scott']
# No remaining pages to scrape for Scott Hirst.
# bu in: Ahmed Ghappour | School of Law - Boston University
# https://www.bu.edu/law/profile/ahmed-ghappour/
# ['Ahmed']
# No remaining pages to scrape for Ahmed Ghappour.
# bu in: Rory Van Loo | School of Law - Boston University
# https://www.bu.edu/law/profile/rory-van-loo/
# ['Rory']
# No remaining pages to scrape for Rory Van Loo.
# bu in: Rebecca Ingber | School of Law - Boston University
# https://www.bu.edu/law/profile/rebecca-ingber/
# ['Rebecca']
# No remaining pages to scrape for Rebecca Ingber.
# []
# Name Christina Skinner was not found
# bu in: bu
# ['Julian']
# No remaining pages to scrape for Julian Arato.
# bu in: K. Sabeel Rahman | Take Care
# https://takecareblog.com/contributors/k-sabeel-rahman
# ['K. Sabeel']
# No remaining pages to scrape for K. Sabeel Rahman.
# bu in: bu
# ['Jocelyn']
# No remaining pages to scrape for Jocelyn Simonson.
# []
# Name Charisa Kiyo Smith was not found
# buffalo in: Hallett, Nicole - School of Law - University at Buffalo
# https://www.law.buffalo.edu/faculty/facultyDirectory/hallett-nicole.html
# ['Nicole']
# No remaining pages to scrape for Nicole Hallett.
# buffalo in: Manes, Jonathan - School of Law - University at Buffalo
# https://www.law.buffalo.edu/faculty/facultyDirectory/manes-jonathan.html
# ['Jonathan']
# No remaining pages to scrape for Jonathan Manes.
# byu in: Stephanie Barclay – BYU J. Reuben Clark Law School
# https://law.byu.edu/faculty/stephanie-barclay/
# byu in: Stephanie Hall - BYU Law School
# https://law.byu.edu/wp-content/uploads/2018/08/CV-Stephanie-Barclay.pdf
# byu in: Stephanie Barclay – BYU J. Reuben Clark Law School
# https://law.byu.edu/faculty/stephanie-barclay/
# ['Stephanie', 'Stephanie Hall', 'Stephanie H.']
# No remaining pages to scrape for Stephanie Barclay.
# byu in: No Toil nor Labor Fear: The Story of William Clayton | BYU Studies
# https://byustudies.byu.edu/content/no-toil-nor-labor-fear-story-william-clayton
# byu in: William W. Clayton – BYU J. Reuben Clark Law School
# https://law.byu.edu/faculty/william-clayton/
# ['William Clayton', 'William']
# William Clayton
# William (I) Clayton
# byu in: William W. Clayton – BYU J. Reuben Clark Law School
# https://law.byu.edu/faculty/william-clayton/
# William F. Clayton
# William G. Clayton
# William R. Clayton
# William Clayton II Taylor
# William Clayton Vandivort
# No data available on Hein for William Clayton Clayton
# No remaining pages to scrape for William Clayton Clayton.
# William F. *Clayton
# William G. *Clayton
# William (I) *Clayton
# William R. *Clayton
# William Clayton II Taylor
# William Clayton Vandivort
# No remaining pages to scrape for William Clayton.
# William F. *Clayton
# William G. *Clayton
# William R. *Clayton
# William Clayton
# William Clayton II Taylor
# William Clayton Vandivort
# No remaining pages to scrape for William (I) Clayton.
# byu in: Gladriel Shobe – BYU J. Reuben Clark Law School
# https://law.byu.edu/faculty/gladriel-shobe/
# ['Gladriel']
# No remaining pages to scrape for Gladriel Shobe.
# byu in: Jarrod Shobe – BYU J. Reuben Clark Law School
# https://law.byu.edu/faculty/jarrod-shobe/
# ['Jarrod']
# No remaining pages to scrape for Jarrod Shobe.
# byu in: Stephanie Plamondon Bair – BYU J. Reuben Clark Law School
# https://law.byu.edu/faculty/stephanie-bair/
# byu in: Stephanie Plamondon Bair – BYU J. Reuben Clark Law School
# https://law.byu.edu/faculty/stephanie-bair/
# ['Stephanie', 'Stephanie Plamondon']
# No remaining pages to scrape for Stephanie Bair.
# byu in: Clark D. Asay – BYU J. Reuben Clark Law School
# https://law.byu.edu/faculty/clark-d-asay/
# ['Clark D.']
# No remaining pages to scrape for Clark D. Asay.
# []
# Name Tabrez Ebrahim was not found
# []
# Name I. India Thusi was not found
# lostcolleges.com/california-western-university in: More images for Hannah Brenner lostcolleges.com/california-western-university
# ['Hannah']
# Hannah *Brennere
# No remaining pages to scrape for Hannah Brenner.
# ucalgary in: Erin Sheley | News | University of Calgary
# news.ucalgary.ca/taxonomy/term/108
# ['Erin']
# Erin L. *Sheley
# No remaining pages to scrape for Erin Sheley.
# []
# Name Pooja R. Dadhania was not found
# []
# Name Catherine Hardee was not found
# lostcolleges.com/california-western-university in: More images for Greg Reilly lostcolleges.com/california-western-university
# ['Greg']
# Gregory B. *Reilly
# Gregory M. *Reilly
# No remaining pages to scrape for Greg Reilly.
# campbell in: Shawn E. Fields | Directory | Campbell University
# https://directory.campbell.edu › Directory › People › Law › Law Faculty
# campbell in: Shawn E. Fields | Directory | Campbell University
# https://directory.campbell.edu › Directory › People › Law › Law Faculty
# ['Shawn', 'Shawn E.']
# Shawn E. *Fields
# No remaining pages to scrape for Shawn Fields.
# Shawn Fields
# No remaining pages to scrape for Shawn E. Fields.
# cardozo.yu in: jocelyn-getgen-kestenbaum | Cardozo Law
# https://cardozo.yu.edu/directory/jocelyn-getgen-kestenbaum
# ['Jocelyn Getgen']
# No remaining pages to scrape for Jocelyn Getgen Kestenbaum.
# cardozo.yu in: michael-pollack | Cardozo Law
# https://cardozo.yu.edu/directory/michael-pollack
# cardozo.yu in: michael-pollack | Cardozo Law
# https://cardozo.yu.edu/directory/michael-pollack
# ['Michael', 'Michael C.']
# Michael A. *Pollack
# Michael J. *Pollack
# No remaining pages to scrape for Michael Pollack.
# Michael A. *Pollack
# Michael J. *Pollack
# cardozo.yu in: sam-weinstein | Cardozo Law
# https://cardozo.yu.edu/directory/sam-weinstein
# cardozo.yu in: sam-weinstein | Cardozo Law
# https://cardozo.yu.edu/directory/sam-weinstein
# ['Samuel Noah', 'Samuel N.']
# No remaining pages to scrape for Samuel Noah Weinstein.
# uchicago in: Claudia M. Flores | University of Chicago Law School
# https://www.law.uchicago.edu/faculty/flores
# ['Claudia']
# Claudia E. M. *Flores
# No remaining pages to scrape for Claudia Flores.
# uchicago in: Daniel Hemel | University of Chicago Law School
# https://www.law.uchicago.edu/faculty/hemel
# uchicago in: Daniel Hemel | University of Chicago Law School
# https://www.law.uchicago.edu/faculty/hemel
# ['Daniel', 'Daniel J.']
# Daniel J. *Hemel
# No remaining pages to scrape for Daniel Hemel.
# Daniel Hemel
# No remaining pages to scrape for Daniel J. Hemel.
# uchicago in: Genevieve Lakier | University of Chicago Law School
# https://www.law.uchicago.edu/faculty/lakier
# ['Genevieve']
# No remaining pages to scrape for Genevieve Lakier.
# uchicago in: John Rappaport | University of Chicago Law School
# https://www.law.uchicago.edu/faculty/rappaport
# ['John']
# No remaining pages to scrape for John Rappaport.
# uchicago in: Adam Chilton | University of Chicago Law School
# https://www.law.uchicago.edu/faculty/chilton
# uchicago in: Adam Chilton | University of Chicago Law School
# https://www.law.uchicago.edu/faculty/chilton
# ['Adam', 'Adam S.']
# Adams S. *Chilton
# No remaining pages to scrape for Adam Chilton.
# Adams S. *Chilton
# cuhk in: William PARTLETT - CUHK Research Portal - CONVERIS Research ...
# https://aims.cuhk.edu.hk/converis/portal/Person/6095076?auxfun=&lang=en...
# ['William']
# No remaining pages to scrape for William Partlett.
# cuhk in: Rehan ABEYRATNE - Faculty of Law - Cuhk
# https://www.law.cuhk.edu.hk/en/people/info.php?id=241
# cuhk in: Prof. Rehan ABEYRATNE - The Faculty of Law of the Chinese ...
# https://www.law.cuhk.edu.hk/en/people/info.php?id=241
# ['Rehan', 'Rehan Aindri']
# Rehan Aindri *Abeyratne
# No remaining pages to scrape for Rehan Abeyratne.
# Rehan Abeyratne
# No remaining pages to scrape for Rehan Aindri Abeyratne.
# colorado in: Craig Konnoth - Tenured and Tenure-Track Faculty - Colorado Law
# https://lawweb.colorado.edu/profiles/profile.jsp?id=823
# colorado in: Craig Konnoth - Tenured and Tenure-Track Faculty - Colorado Law
# https://lawweb.colorado.edu/profiles/profile.jsp?id=823
# ['Craig', 'Craig J.']
# Craig J. *Konnoth
# No remaining pages to scrape for Craig Konnoth.
# Craig Konnoth
# No remaining pages to scrape for Craig J. Konnoth.
# colorado in: Benjamin Levin - Tenured and Tenure-Track Faculty - Colorado Law
# https://lawweb.colorado.edu/profiles/profile.jsp?id=824
# colorado in: Benjamin Levin - Tenured and Tenure-Track Faculty - Colorado Law
# https://lawweb.colorado.edu/profiles/profile.jsp?id=824
# colorado in: benjamin levin colorado
# colorado in: Benjamin Levin - Colorado Law
# https://lawweb.colorado.edu/files/vitae/levin.pdf
# ['Benjamin', 'Benjamin A.', 'Benjamin B.', 'Benjamin N.']
# Benjamin A. *Levin
# Benjamin B. *Levin
# Benjamin N. *Levin
# No remaining pages to scrape for Benjamin Levin.
# Benjamin B. *Levin
# Benjamin N. *Levin
# Benjamin Levin
# No remaining pages to scrape for Benjamin A. Levin.
# Benjamin A. *Levin
# Benjamin N. *Levin
# Benjamin Levin
# No remaining pages to scrape for Benjamin B. Levin.
# Benjamin A. *Levin
# Benjamin B. *Levin
# Benjamin Levin
# No remaining pages to scrape for Benjamin N. Levin.
# colorado in: Scott Skinner-Thompson - Tenured and Tenure-Track ... - Colorado Law
# https://lawweb.colorado.edu/profiles/profile.jsp?id=818
# ['Scott']
# No remaining pages to scrape for Scott Skinner-Thompson.
# colorado in: Sloan Speck - Tenured and Tenure-Track Faculty - Colorado Law
# https://lawweb.colorado.edu/profiles/profile.jsp?id=676
# ['Sloan G.']
# No remaining pages to scrape for Sloan G. Speck.
# colorado in: Kristelia A. García - Tenured and Tenure-Track Faculty - Colorado Law
# https://lawweb.colorado.edu/profiles/profile.jsp?id=625
# ['Kristelia A.']
# No remaining pages to scrape for Kristelia A. Garcia.
# colorado in: Sharon Jacobs - Tenured and Tenure-Track Faculty - Colorado Law
# https://lawweb.colorado.edu/profiles/profile.jsp?id=626
# colorado in: Sharon Jacobs - Tenured and Tenure-Track Faculty - Colorado Law
# https://lawweb.colorado.edu/profiles/profile.jsp?id=626
# colorado in: Sharon Jacobs - Tenured and Tenure-Track Faculty - Colorado Law
# https://lawweb.colorado.edu/profiles/profile.jsp?id=626
# colorado in: Sharon Jacobs - Tenured and Tenure-Track Faculty - Colorado Law
# https://lawweb.colorado.edu/profiles/profile.jsp?id=626
# ['Sharon', 'Sharon B.', 'Sharon B. (I)', 'Sharon (I)']
# Sharon B. (I) *Jacobs
# Sharon (I) *Jacobs
# No remaining pages to scrape for Sharon Jacobs.
# Sharon B. (I) *Jacobs
# Sharon (I) *Jacobs
# Sharon Jacobs
# Sharon (I) Jacobs
# Sharon B. Jacobs
# No remaining pages to scrape for Sharon B. (I) Jacobs.
# Sharon B. *Jacobs
# Sharon B. (I) *Jacobs
# Sharon Jacobs
# No remaining pages to scrape for Sharon (I) Jacobs.
# columbia in: Maeve Glass | Columbia Law School
# https://www.law.columbia.edu/faculty/maeve-glass
# columbia in: Maeve Glass | Columbia Law School
# https://www.law.columbia.edu/faculty/maeve-glass
# ['Maeve', 'Maeve Herbert']
# Maeve Herbert *Glass
# No remaining pages to scrape for Maeve Glass.
# Maeve Glass
# No remaining pages to scrape for Maeve Herbert Glass.
# columbia in: Kellen Richard Funk | Columbia Law School
# https://www.law.columbia.edu/faculty/kellen-funk
# ['Kellen']
# No remaining pages to scrape for Kellen Funk.
# columbia in: Joshua Mitts | Columbia Law School
# https://www.law.columbia.edu/faculty/joshua-mitts
# columbia in: Joshua Mitts | Columbia Law School
# https://www.law.columbia.edu/faculty/joshua-mitts
# ['Joshua', 'Joshua R.']
# No remaining pages to scrape for Joshua Mitts.
# columbia in: Kristen Underhill | Columbia Law School
# https://www.law.columbia.edu/faculty/kristen-underhill
# ['Kristen']
# No remaining pages to scrape for Kristen Underhill.
# columbia in: Jeremy Kessler | Columbia Law School
# https://www.law.columbia.edu/faculty/jeremy-kessler
# ['Jeremy K.']
# No remaining pages to scrape for Jeremy K. Kessler.
# []
# Name Summer Chandler was not found
# csp in: csp
# ['Ryan']
# No remaining pages to scrape for Ryan Stoa.
# []
# Name Latonia Keith was not found
# csp in: csp
# ['Jason']
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# Page has not loaded, sleeping for 3 seconds
# ...
# utoledo in: Professor Agnieszka McPeak Cited in New York Court of Appeals ...
# www.utoledo.edu/.../professor-agnieszka-mcpeak-cited-in-new-york-court-of-appeals...
# ['Agnieszka', 'Agnieszka A.']
# Agnieszka A. *McPeak
# Agnieszka, A. *McPeak
# No remaining pages to scrape for Agnieszka McPeak.
# Agnieszka, A. *McPeak
# Agnieszka McPeak
# No remaining pages to scrape for Agnieszka A. McPeak.
# utoronto in: Anna Su | University of Toronto Faculty of Law
# https://www.law.utoronto.ca/faculty-staff/full-time-faculty/anna-su
# ['Anna']
# Linchong *Suwannapokin
# No remaining pages to scrape for Anna Su.
# utoronto in: Emily Satterthwaite | University of Toronto Faculty of Law
# https://www.law.utoronto.ca/faculty-staff/full-time-faculty/emily-satterthwaite
# utoronto in: Emily Satterthwaite | University of Toronto Faculty of Law
# https://www.law.utoronto.ca/faculty-staff/full-time-faculty/emily-satterthwaite
# utoronto in: Emily Satterthwaite | University of Toronto Faculty of Law
# https://www.law.utoronto.ca/faculty-staff/full-time-faculty/emily-satterthwaite
# ['Emily', 'Emily Ann', 'Emily A.']
# Emily A. *Satterthwaite
# Emily Ann *Satterthwaite
# No remaining pages to scrape for Emily Satterthwaite.
# Emily Satterthwaite
# Emily A. Satterthwaite
# No remaining pages to scrape for Emily Ann Satterthwaite.
# Emily Ann *Satterthwaite
# Emily Satterthwaite
# No remaining pages to scrape for Emily A. Satterthwaite.
# tulane in: Ann M. Lipton | Tulane Law School
# https://law.tulane.edu/faculty/full-time/ann-lipton
# ['Ann M.']
# No remaining pages to scrape for Ann M. Lipton.
# utulsa in: Warigia Bowman - Faculty - The University of Tulsa
# https://faculty.utulsa.edu › Faculty
# ['Warigia']
# No remaining pages to scrape for Warigia Bowman.
# utulsa in: Ido Kilovaty - Faculty - The University of Tulsa
# https://faculty.utulsa.edu › Faculty
# ['Ido']
# No remaining pages to scrape for Ido Kilovaty.
# ucdavis in: Irene Oritseweyinmi Joe - UC Davis School of Law
# https://law.ucdavis.edu/faculty/joe/
# ['Irene Oritseweyinmi']
# No remaining pages to scrape for Irene Oritseweyinmi Joe.
# ucdavis in: Aaron Tang ucdavis
# ucdavis in: Faculty & Administration - tang - Aaron Tang - UC Davis School of Law
# https://law.ucdavis.edu/faculty/tang/
# ['Aaron', 'Aaron Y.']
# Aaron Y. *Tang
# No remaining pages to scrape for Aaron Tang.
# Aaron Tang
# No remaining pages to scrape for Aaron Y. Tang.
# ucdavis in: Jasmine E. Harris - UC Davis School of Law
# https://law.ucdavis.edu/faculty/harris-jasmine/
# ['Jasmine E.']
# No remaining pages to scrape for Jasmine E. Harris.
# uchastings in: Jared Ellias, Associate Professor of Law - UC Hastings College of the ...
# https://www.uchastings.edu/people/jared-ellias/
# uchastings in: Jared Ellias, Associate Professor of Law - UC Hastings College of the ...
# https://www.uchastings.edu/people/jared-ellias/
# ['Jared', 'Jared A.']
# No remaining pages to scrape for Jared Ellias.
# uci in: Emily Taylor Poppe - UCI Law
# https://www.law.uci.edu/faculty/full-time/taylorpoppe/
# ['Emily S. Taylor']
# No remaining pages to scrape for Emily S. Taylor Poppe.
# uci in: Leah Litman - UCI Law
# https://www.law.uci.edu/faculty/full-time/litman/
# uci in: Leah Litman - UCI Law
# https://www.law.uci.edu/faculty/full-time/litman/
# ['Leah', 'Leah M.']
# Leah M. *Litman
# No remaining pages to scrape for Leah Litman.
# Leah Litman
# No remaining pages to scrape for Leah M. Litman.
# uci in: Alison Mikkor - UCI Law
# https://www.law.uci.edu/faculty/full-time/mikkor/
# ['Alison M.']
# No remaining pages to scrape for Alison M. Mikkor.
# uci in: 6:38
# Sung Eun Kim. Aria di pazzia. Lucia di Lammemoor. I parte.
# ['Sung Eun']
# Sung-Gun *Kim
# Bo Sung Kim
# Hye-Sung Kim
# uci in: Eleana Kim - Faculty Websites - Uci
# https://faculty.sites.uci.edu/eleanakim/
# Sung Bae Kim
# Sung Hee Kim
# Sung Ho Kim
# Sung Hui Kim
# Sung Jae Kim
# Sung San Kim
# No remaining pages to scrape for Sung Eun Kim.
# No remaining pages to scrape for Hye-Sung Kim.
# uci in: Seth Davis & Leah Litman on civil rights under a Trump ... - UCI Law
# https://www.law.uci.edu/podcast/episode21.html
# ['Seth']
# No remaining pages to scrape for Seth Davis.
# ucla in: LaToya Baldwin Clark - Curriculum Guide - UCLA.edu
# https://curriculum.law.ucla.edu/Guide/Biography/8748
# ['LaToya Baldwin']
# No remaining pages to scrape for LaToya Baldwin Clark.
# ucla in: Blake Emerson - UCLA School of Law
# https://law.ucla.edu/faculty/faculty-profiles/blake-emerson/
# ['Blake']
# No remaining pages to scrape for Blake Emerson.
# ucla in: Kristen Eichensehr - UCLA School of Law
# https://law.ucla.edu/faculty/faculty-profiles/kristen-eichensehr/
# ucla in: Kristen Eichensehr - Biography Page
# https://law.ucla.edu/faculty/faculty-profiles/kristen-eichensehr/
# ['Kristen', 'Kristen E.']
# Kristen E. *Eichensehr
# No remaining pages to scrape for Kristen Eichensehr.
# Kristen Eichensehr
# No remaining pages to scrape for Kristen E. Eichensehr.
# ucla in: Beth A. Colgan - UCLA School of Law
# https://law.ucla.edu/faculty/faculty-profiles/beth-a-colgan/
# ucla in: Beth A. Colgan - Biography Page
# https://law.ucla.edu/faculty/faculty-profiles/beth-a-colgan/
# ['Beth', 'Beth A.']
# No remaining pages to scrape for Beth Colgan.
# ucla in: Richard M. Re - Biography Page
# https://www.law.ucla.edu/faculty/faculty-profiles/richard-m-re/
# ['Richard M.']
# No remaining pages to scrape for Richard M. Re.
# ucla in: E. Tendayi Achiume - UCLA School of Law
# https://law.ucla.edu/faculty/faculty-profiles/e-tendayi-achiume/
# ucla in: E. Tendayi Achiume - Biography Page
# https://law.ucla.edu/faculty/faculty-profiles/e-tendayi-achiume/
# ucla in: E. Tendayi Achiume - Biography Page
# https://law.ucla.edu/faculty/faculty-profiles/e-tendayi-achiume/
# ['Tendayi', 'E. Tendayi', 'Emily Tendayi']
# No remaining pages to scrape for Tendayi Achiume.
# udc in: School of Law Faculty - UDC David A. Clarke School of Law
# https://www.law.udc.edu/page/Faculty
# ['Norrinda Brown']
# Norrinda Brown Hayat
# No remaining pages to scrape for Norrinda Brown Hayat.
# ubc in: Camden Hutchison - Peter A. Allard School of Law
# www.allard.ubc.ca/faculty-staff/camden-hutchison
# ['Camden']
# No remaining pages to scrape for Camden Hutchison.
# unlv in: Eve Hanan | UNLV - William S. Boyd School of Law
# https://law.unlv.edu/faculty/eve-hanan
# unlv in: Eve Hanan | UNLV - William S. Boyd School of Law
# https://law.unlv.edu/faculty/eve-hanan
# ['Eve', 'M. Eve']
# M. Eve Hanan
# No remaining pages to scrape for Eve Hanan.
# Hanan M. Isaacs
# No remaining pages to scrape for M. Eve Hanan.
# []
# Name Dorothy Shapiro Lund was not found
# []
# Name Young Ran (Christine) Kim was not found
# utah in: Cathy Hwang - Home - Faculty Profile - The University of Utah
# https://faculty.utah.edu/u6005912-Cathy_Hwang/hm/index.hml
# ['Cathy']
# No remaining pages to scrape for Cathy Hwang.
# valpo in: Natalie Banta - Valparaiso University
# https://www.valpo.edu › About Us › Full Time Faculty › Natalie M. Banta
# valpo in: Natalie Banta - Valparaiso University
# https://www.valpo.edu › About Us › Full Time Faculty › Natalie M. Banta
# ['Natalie', 'Natalie M.']
# No remaining pages to scrape for Natalie Banta.
# []
# Name Gautam Hans was not found
# vanderbilt in: Lauren Rogal | Faculty | Law School | Vanderbilt University
# https://law.vanderbilt.edu/bio/lauren-rogal
# ['Lauren']
# No remaining pages to scrape for Lauren Rogal.
# vanderbilt in: Sara Mayeux | Faculty | Law School | Vanderbilt University
# https://law.vanderbilt.edu/bio/sara-mayeux
# ['Sara']
# No remaining pages to scrape for Sara Mayeux.
# vanderbilt in: Joseph Fishman | Faculty | Law School | Vanderbilt University
# https://law.vanderbilt.edu/bio/joseph-fishman
# vanderbilt in: Joseph Fishman | Faculty | Law School | Vanderbilt University
# https://law.vanderbilt.edu/bio/joseph-fishman
# ['Joseph P.', 'Joseph L.']
# No remaining pages to scrape for Joseph P. Fishman.
# Joseph P. *Fishman
# No remaining pages to scrape for Joseph L. Fishman.
# uvm in: CAS Department Updates - University of Vermont
# https://www.uvm.edu/cas/cas_department_updates
# ['Rachel']
# Rachel V. *Stevens
# No remaining pages to scrape for Rachel Stevens.
# []
# Name Jeannie Oliver was not found
# villanova in: Christine Speidel | Villanova University
# https://www1.villanova.edu/villanova/law/academics/faculty/.../ChristineSpeidel.html
# ['Christine']
# No remaining pages to scrape for Christine Speidel.
# villanova in: J.S. Nelson | Villanova University
# https://www1.villanova.edu/villanova/law/academics/faculty/.../jsnelson.html
# ['Josephine Sandler']
# Josephine (I) Nelson
# villanova in: J.S. Nelson | Villanova University
# https://www1.villanova.edu/villanova/law/academics/faculty/.../jsnelson.html
# No remaining pages to scrape for Josephine Sandler Nelson.
# Josephine Sandler Nelson
# No remaining pages to scrape for Josephine (I) Nelson.
# virginia in: Farah Peterson | University of Virginia School of Law - UVA Law
# https://www.law.virginia.edu/faculty/profile/fp9r/2708426
# ['Farah']
# No remaining pages to scrape for Farah Peterson.
# virginia in: Aditya Bamzai | University of Virginia School of Law
# https://www.law.virginia.edu/faculty/profile/ab3sy/2639868
# ['Aditya']
# No remaining pages to scrape for Aditya Bamzai.
# []
# Name Maureen (Molly) Brady was not found
# virginia in: Gregg Strauss | University of Virginia School of Law - UVA Law
# https://www.law.virginia.edu/faculty/profile/gs2df/2575027
# ['Gregg']
# No remaining pages to scrape for Gregg Strauss.
# []
# Name Marie-Amélie George was not found
# wfu in: Russell Gold - Faculty Profile | Faculty | Wake Forest School of Law
# web.law.wfu.edu/faculty/profile/goldrm/
# wfu in: Russell Gold - Faculty Profile | Faculty | Wake Forest School of Law
# web.law.wfu.edu/faculty/profile/goldrm/
# ['Russell M.', 'Russell A.']
# Russell A. *Gold
# No remaining pages to scrape for Russell M. Gold.
# Russell M. *Gold
# No remaining pages to scrape for Russell A. Gold.
# washburn in: Landmark Supreme Court Ruling Cites Pollvogt's Amicus Brief
# washburnlaw.edu/news/2015/07/pollvogt.html
# ['Susannah']
# Susannah W. *Pollvogt
# No remaining pages to scrape for Susannah Pollvogt.
# wustl in: Daniel Epps - WashULaw - Washington University School of Law
# https://law.wustl.edu/faculty-staff-directory/profile/daniel-epps/
# ['Daniel']
# No remaining pages to scrape for Daniel Epps.
# wustl in: Rachel Sachs - WashULaw - Washington University School of Law
# https://law.wustl.edu/faculty-staff-directory/profile/rachel-sachs/
# wustl in: Rachel Sachs - WashULaw
# https://law.wustl.edu/faculty-staff-directory/profile/rachel-sachs/
# ['Rachel', 'Rachel E.']
# Rachel E. *Sachs
# No remaining pages to scrape for Rachel Sachs.
# Rachel Sachs
# No remaining pages to scrape for Rachel E. Sachs.
# wustl in: wustl
# ['Angelica']
# No remaining pages to scrape for Angelica Chazaro.
# []
# Name Trevor Gardner was not found
# wayne in: William Ortman - Wayne Law - Wayne State University
# https://law.wayne.edu/profile/gb7147
# ['William']
# William B. *Ortman
# No remaining pages to scrape for William Ortman.
# wayne in: Anne Choike - Wayne Law - Wayne State University
# https://law.wayne.edu/profile/az6771
# ['Anne M.']
# No remaining pages to scrape for Anne M. Choike.
# wayne in: Sanjukta Paul - Wayne Law - Wayne State University
# https://law.wayne.edu/profile/gk8520
# wayne in: Sanjukta Paul - Wayne Law - Wayne State University
# https://law.wayne.edu/profile/gk8520
# ['Sanjukta', 'Sanjukta M.']
# Sanjukta M. *Paul
# No remaining pages to scrape for Sanjukta Paul.
# Sanjukta Paul
# No remaining pages to scrape for Sanjukta M. Paul.
# wayne in: Blanche Cook - Wayne Law - Wayne State University
# https://law.wayne.edu/profile/bh4405
# wayne in: Blanche Cook - Wayne Law - Wayne State University
# https://law.wayne.edu/profile/bh4405
# wayne in: blanche cook wayne state
# ['Blanche', 'Blanche Bong', 'Blanche Wiesen']
# Blanche Bong *Cook
# Blanche Wiesen *Cook
# No remaining pages to scrape for Blanche Cook.
# Blanche Cook
# Blanche Wiesen Cook
# No remaining pages to scrape for Blanche Bong Cook.
# Blanche Cook
# Blanche Bong Cook
# No remaining pages to scrape for Blanche Wiesen Cook.
# wvu in: Joshua Weishart | College of Law | West Virginia University
# https://www.law.wvu.edu/faculty-staff/full-time-faculty/joshua-weishart
# ['Joshua E.']
# No remaining pages to scrape for Joshua E. Weishart.
# wvu in: Valarie Blake | College of Law | West Virginia University
# https://www.law.wvu.edu/faculty-staff/full-time-faculty/valarie-blake
# wvu in: Valarie Blake | College of Law | West Virginia University
# https://www.law.wvu.edu/faculty-staff/full-time-faculty/valarie-blake
# ['Valarie', 'Valarie K.']
# Valarie K. *Blake
# No remaining pages to scrape for Valarie Blake.
# Valarie Blake
# No remaining pages to scrape for Valarie K. Blake.
# wharton.upenn in: Peter Conti-Brown - Wharton Legal Studies & Business Ethics
# https://lgst.wharton.upenn.edu/profile/petercb/
# ['Peter']
# No remaining pages to scrape for Peter Conti-Brown.
# []
# Name Vince Buccola was not found
# lgst.wharton.upenn in: Amanda Shanor - Wharton Legal Studies & Business Ethics
# https://lgst.wharton.upenn.edu/profile/_whrtn84/
# ['Amanda']
# No remaining pages to scrape for Amanda Shanor.
# lgst.wharton.upenn in: Brian D. Feinstein - LEGAL STUDIES & BUSINESS ETHICS Department
# https://lgst.wharton.upenn.edu/profile/bdfeinst/
# ['Brian D.']
# No remaining pages to scrape for Brian D. Feinstein.
# willamette in: Andrew Gilden Faculty Biography | Willamette University College of Law
# willamette.edu/law/faculty/profiles/gilden/index.html
# ['Andrew']
# No remaining pages to scrape for Andrew Gilden.
# willamette in: Aaron D. Simowitz Faculty Biography | Willamette University College ...
# willamette.edu/law/faculty/profiles/simowitz/index.html
# ['Aaron D.']
# No remaining pages to scrape for Aaron D. Simowitz.
# willamette in: Peter Molk Faculty Biography | Willamette University College of Law
# willamette.edu/law/faculty/profiles/molk/index.html
# ['Peter']
# No remaining pages to scrape for Peter Molk.
# wm in: Jay Butler | William & Mary Law School
# https://law2.wm.edu/faculty/bios/fulltime/jbutler.php
# ['Jay']
# Jeremy Jay Butler
# No remaining pages to scrape for Jay Butler.
# wm in: Sarah R. Wasserman Rajec | William & Mary Law School
# https://law2.wm.edu/faculty/bios/fulltime/srrajec.php
# ['Sarah R. Wasserman']
# Sarah R. Rajec Wasserman
# No remaining pages to scrape for Sarah R. Wasserman Rajec.
# wisc in: BJ Ard | University of Wisconsin Law School
# https://law.wisc.edu/profiles/ard2@wisc.edu
# ['BJ']
# No remaining pages to scrape for BJ Ard.
# wisc in: Ion Meyn wisconsin
# ['Ion']
# No remaining pages to scrape for Ion Meyn.
# wisc in: Yaron Nili | University of Wisconsin Law School
# https://law.wisc.edu/profiles/nili@wisc.edu
# ['Yaron']
# No remaining pages to scrape for Yaron Nili.
# wisc in: Gwendolyn Leachman | University of Wisconsin Law School
# https://law.wisc.edu/profiles/gleachman@wisc.edu
# ['Gwendolyn M.']
# No remaining pages to scrape for Gwendolyn M. Leachman.
# wisc in: Miriam Seifter wisconsin
# ['Miriam']
# No remaining pages to scrape for Miriam Seifter.
# wisc in: Robert Yablon wisconsin
# wisc in: Robert Yablon | University of Wisconsin Law School
# https://law.wisc.edu/profiles/ryablon@wisc.edu
# ['Robert', 'Robert M.']
# No remaining pages to scrape for Robert Yablon.
# uwyo in: Emily S. Bremer | College of Law | University of Wyoming
# https://www.uwyo.edu/law/directory/emily-bremer.html
# ['Emily S.']
# No remaining pages to scrape for Emily S. Bremer.
# uwyo in: Danielle R. Cover | College of Law | University of Wyoming
# www.uwyo.edu › College of Law › Faculty and Staff Directory
# ['Danielle R.']
# No remaining pages to scrape for Danielle R. Cover.
# yale in: Monica C. Bell - Yale Law School
# https://law.yale.edu/monica-c-bell
# yale in: Monica C. Bell - Yale Law School
# https://law.yale.edu/monica-c-bell
# ['Monica', 'Monica C.']
# No remaining pages to scrape for Monica Bell.
# yale in: Zachary Liscow - Yale Law School
# https://law.yale.edu/zachary-liscow
# yale in: Zachary Liscow - Yale Law School
# https://law.yale.edu/zachary-liscow
# ['Zachary', 'Zachary D.']
# No remaining pages to scrape for Zachary Liscow.
# yale in: Anika Singh Lemar - Yale Law School
# https://law.yale.edu/anika-singh-lemar
# ['Anika Singh']
# No remaining pages to scrape for Anika Singh Lemar.
# yale in: Issa Kohler-Hausmann - Yale Law School
# https://law.yale.edu/issa-kohler-hausmann
# ['Issa']
# No remaining pages to scrape for Issa Kohler-Hausmann.

# %% [markdown]
# #### file

# %%
table_element
# Out:
# ['Full Name Clayton, William Clayton', 'ScholarCheck Rank  ', '', 'H-Index']

# %%
# Out:
# Colorado Lawyer, Vol. 12, Issue 8 (August 1983), pp. 1207-1214
# Cohen, Jeffrey (Cited 3 times)
# 12 Colo. Law. 1207 (1983)
# {'Title': 'Partnership Reorganization under Chapter 11 [article]', 'Author': 'Cohen, Jeffrey (Cited 3 times)', 'Journal': 'Colorado Lawyer, Vol. 12, Issue 8 (August 1983), pp. 1207-1214', 'BBCite': '12 Colo. Law. 1207 (1983)'}

# %%
# df_sub = pd.DataFrame()
# main_df = pd.DataFrame()
stats = ['Cited by Cases','Cited by Articles','Accessed (Past 12 Months)','Cited by Articles (Past 10 Years)', 'Cited by Articles (Past 1-2 years)', 'ScholarCheck Rank', 'Average Citations per Article', 'Average Citations per Document', 'Self-Citations']
last_name = 'Dauber'
mid_first_name = 'Michele Landis'
full_name = mid_first_name + ' ' + last_name
school = 'Arizona'
link = 'https://heinonline-org.proxy01.its.virginia.edu/HOL/AuthorProfile?action=edit&search_name=' + last_name +  '%2C ' + mid_first_name + '&collection=journals'
driver.get(link)
element = driver.find_element_by_xpath('//*[@id="page_content"]/div[1]/div/div[2]/div[1]')
table_element = element.text.split('\n')
number_list = []
rank_list = []
stat_list = []
for stat in stats:
#     print(stat)
    find_index = [table_element.index(s) for s in table_element if stat == s]
    if find_index:
        my_list = table_element[find_index[0]+1].split(' ')
        number_list.append(my_list[0])
        stat_list.append(stat)
        if len(my_list) > 1:
            rank_list.append(my_list[-1])
    if stat == 'Self-Citations':
        find_index = [table_element.index(s) for s in table_element if stat in s]
        if find_index:
            stat_list.append(stat)
            number_list.append(table_element[find_index[0]].split(' ')[1])
zip_number_list = list(zip(stat_list, number_list))
zip_rank_list = list(zip(stat_list, rank_list))
number_dict = create_dataframe_dict(zip_number_list)
rank_dict = create_dataframe_dict(zip_rank_list)
df_number = pd.DataFrame.from_dict(number_dict, orient='index').transpose()
df_rank = pd.DataFrame.from_dict(rank_dict, orient='index').transpose()
df_number = df_number.replace('na', '0')
df_number = df_number.replace('', '0')
df_number = df_number.replace(' ', '0')
df_number = df_number.astype(float)
if df_sub.empty:
    df_sub = df_number
else: 
    df_sub = df_sub.add(df_number)
df_sub
my_dict = {'Person': [full_name], 'School': [school], 'Type': ['number']}
name_data = pd.DataFrame(my_dict)
df_sub = pd.concat([name_data, df_sub], sort = False, axis = 1)
main_df = pd.concat([main_df, df_sub])

# %%
    main_df
# Out:
#                   Person   School    Type  Cited by Cases  Cited by Articles  \
# 0  Michele Landis Dauber  Arizona  number             0.0               97.0
#
#    Accessed (Past 12 Months)  Cited by Articles (Past 10 Years)  \
# 0                       38.0                               45.0
#
#    Cited by Articles (Past 1-2 years)  ScholarCheck Rank  \
# 0                                 2.0                0.0
#
#    Average Citations per Article  Average Citations per Document  \
# 0                           97.0                           24.25
#
#    Self-Citations
# 0             0.0

# %%
df_number = df_number.replace('na', '0')
df_number = df_number.replace(' ', '0')
df_number = df_number.astype(float)
df_number.add(df_number)

# %%
my_dict = {'Person': ['adsfdsa'], 'School': ['dsafdsa'], 'Type': ['sdafdsaf']}
name_data = pd.DataFrame(my_dict)
pd.concat([name_data, df_number], sort = False, axis = 1)
# Out:
#     Person   School      Type  Cited by Cases  Cited by Articles  \
# 0  adsfdsa  dsafdsa  sdafdsaf             3.0              493.0
#
#    Accessed (Past 12 Months)  Cited by Articles (Past 10 Years)  \
# 0                      645.0                              296.0
#
#    Cited by Articles (Past 1-2 years)  ScholarCheck Rank  \
# 0                                36.0                0.0
#
#    Average Citations per Article  Average Citations per Document  \
# 0                          22.41                            15.9
#
#    Self-Citations
# 0            80.0

# %%
element = driver.find_element_by_xpath('//*[@id="page_content"]/div[1]/div/div[2]/div[1]')
stats = ['Cited by Cases','Cited by Articles','Accessed (Past 12 Months)','Cited by Articles (Past 10 Years)', 'Cited by Articles (Past 1-2 years)', 'ScholarCheck Rank', 'Average Citations per Article', 'Average Citations per Document', 'Self-Citations']
table_element = element.text.split('\n')
number_list = []
rank_list = []
stat_list = []
for stat in stats:
#     print(stat)
    find_index = [table_element.index(s) for s in table_element if stat == s]
    if find_index:
        my_list = table_element[find_index[0]+1].split(' ')
        number_list.append(my_list[0])
        stat_list.append(stat)
        if len(my_list) > 1:
            rank_list.append(my_list[-1])
    if stat == 'Self-Citations':
        find_index = [table_element.index(s) for s in table_element if stat in s]
        stat_list.append(stat)
        number_list.append(table_element[find_index[0]].split(' ')[1])

print(stat_list)
print(number_list)
print(rank_list)
# Out:
# ['Cited by Articles', 'Accessed (Past 12 Months)', 'Cited by Articles (Past 10 Years)', 'Cited by Articles (Past 1-2 years)', 'ScholarCheck Rank', 'Average Citations per Article', 'Average Citations per Document', 'Self-Citations']
# ['99', '212', '99', '18', '', '9.90', '9.00', '6']
# ['10,679', '8,754', '4,126', '1,898', '7,876']

# %%
# Out:
# The random id using uuid1() is : 700223
