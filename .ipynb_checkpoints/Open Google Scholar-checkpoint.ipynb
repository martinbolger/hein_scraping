# %%
from selenium import webdriver
import pandas as pd
import bs4 as bs
import os
import numpy as np
import re
import time
from selenium.webdriver.common.keys import Keys
import nltk
import requests

# %%
driver = webdriver.Chrome()
g_driver = webdriver.Chrome()
g_driver.get("http://google.com")

# %%
def check_google(mid_first_name, last_name, school_url):
    faculty = False
    for url in school_url:
        if faculty == True:
            break
        g_driver.get("http://google.com")
        search = g_driver.find_element_by_name('q')
        if not ' ' in mid_first_name:
            search.send_keys(mid_first_name + ' ' + last_name + ' ' + url)
        else: 
            search.send_keys(mid_first_name + ' ' + last_name + ' ')
        search.send_keys(Keys.RETURN)
        elems = g_driver.find_elements_by_xpath("//a[@href]")

        for elem in elems:
            if url in elem.text:
                print(url + ' in: ' + elem.text)
                faculty = True
                break
    return faculty

# %%
def split_name(full_name):
    space_count = full_name.count(' ')
    if space_count == 1:
        f_name = full_name.split(' ')[0] 
        last_name = full_name.split(' ')[1]
    elif space_count == 2:
        f_name = full_name.split(' ')[0] 
#                         m_name = full_name.split(' ')[1]
#         fm_name = f_name + ' ' + m_name
        last_name = full_name.split(' ')[2]
    elif space_count > 2:
        f_name = full_name.split(' ')[0] 
#                         m_name = full_name.split(' ')[1]
#         fm_name = f_name + ' ' + m_name
        last_name = ' '.join(full_name.split(' ')[2:])
    return f_name, last_name

# %%
def get_links(first_name, last_name, school_url, school_name):
    driver.get("https://scholar.google.com/citations?view_op=search_authors&mauthors=" +  first_name + '+' + last_name + "&hl=en&oi=ao")
    i = 1
    try:
        print(i)
        element = driver.find_element_by_xpath('//*[@id="gsc_sa_ccl"]/div[' + str(i) + ']/div/div/h3')
    except:
        element = []
    while element:
        full_name = element.text
        print(full_name)
        f_name, last_name = split_name(full_name)
        if last_name in full_name and f_name in full_name:
            affiliation = driver.find_element_by_xpath('//*[@id="gsc_sa_ccl"]/div[' + str(i) + ']/div/div/div[1]')
            print(affiliation.text.lower())
            if (school_name in affiliation.text.lower() or school_url in affiliation.text.lower()) and full_name not in correct_names:
                link_elm = driver.find_element_by_xpath('//*[@id="gsc_sa_ccl"]/div[' + str(i) + ']/div/div/h3/a')
                correct_name = (full_name, link_elm.get_attribute('href'))
                return correct_name
#             else:
#                 faculty = check_google(f_name, last_name, [school_url])
#                 if faculty and full_name not in correct_names:
#                     link_elm = driver.find_element_by_xpath('//*[@id="gsc_sa_ccl"]/div[' + str(i) + ']/div/div/h3/a')
#                     correct_name = (full_name, link_elm.get_attribute('href'))
#                     return correct_name
        i += 1
        try:
            element = driver.find_element_by_xpath('//*[@id="gsc_sa_ccl"]/div[' + str(i) + ']/div/div/h3')
        except:
            element = []

# %%
# element = driver.find_element_by_xpath('//*[@id="gsc_sa_ccl"]/div[' + str(i) + ']/div/div/h3')
element = driver.find_element_by_xpath('//*[@id="gsc_sa_ccl"]/div[1]/div/div/h3')
element.text
# Out:
# 'Kenneth W Abbott'

# %%
def create_path(*args):
    cur_path = os.getcwd()
    for value in args:
        cur_path  = os.path.join(cur_path, value)
    return cur_path

# %%
os.getcwd()
path = os.path.join(os.getcwd(), 'school_data')
files = os.listdir(path)
school_name = 'arizona'
school_url = 'asu'
for file in files[0:1]:
    main_df = pd.DataFrame(columns = ['Name', 'School', 'Link'])
    data = pd.read_csv(os.path.join(os.getcwd(), 'school_data', file))
    for i in range(len(data)):
        got_page = False
        mid_first_name = data['First Name'][i]
        last_name = data['Last Name'][i]
        full_name = mid_first_name + ' ' +  last_name
        school = data['School'][i]
        link = get_links(mid_first_name, last_name, school_url, school_name)
        print(link)
        driver.get('http://amazon.com')
        time.sleep(3)
        driver.get('http://facebook.com')
        time.sleep(3)
        if link:
            main_df = main_df.append(pd.DataFrame({'Name': [full_name], 'School': [school],'Link': [link[1]]}))
        else:
            main_df = main_df.append(pd.DataFrame({'Name': [full_name], 'School': [school],'Link': ['NA']}))
#         while got_page == False:
#             link = 'https://heinonline-org.proxy01.its.virginia.edu/HOL/AuthorProfile?action=edit&search_name=' + last_name +  '%2C ' + mid_first_name + '&collection=journals'
#             driver.get(link)
#             #Selenium hands the page source to Beautiful Soup
#             soup=bs.BeautifulSoup(driver.page_source, 'lxml')
#     #         table = soup.findAll('table', {'style': 'table noborder unpad'})
#             # main_table = table
#             table_rows = soup.findAll('td', {'style': 'text-align:right;'})
#             if str(table_rows[1]) == '<td style="text-align:right;"> 1 </td>':
#                 got_page = False
#                 new_names = False
#                 link_index = 1
#                 while new_names == False:
#                     try:
#                         if link_index == 1:
#                             element =driver.find_element_by_xpath('//*[@id="page_content"]/div[2]/div/ul/li/a')
#                         else: 
#                             element =driver.find_element_by_xpath('//*[@id="page_content"]/div[2]/div/ul/li[' + str(link_index) + ']/a')            

#                         if last_name == element.text.split(', ')[0] and mid_first_name in element.text.split(', ')[1]:
#                             last_name = element.text.split(', ')[0]
#                             mid_first_name = element.text.split(', ')[1]
#                             new_names = True
#                     except: 
#                         new_names = True
#                         got_page = True
#                         print('Name ' + full_name + ' is not in the database. You may be missing a middle initial.')
#                         skip_df = skip_df.append(pd.DataFrame([[full_name, school]], columns = ['Full Name', 'School']))
#                     link_index += 1
#             elif str(table_rows[1]) != '<td style="text-align:right;"> 1 </td>': 
#                 column_1 = [str(x).split('>')[1].split('<')[0] for i,x in enumerate(table_rows) if i%2 == 0]
#             #         print(column_1)
#                 column_2 = [str(x).split('>')[1].split('<')[0] for i,x in enumerate(table_rows) if i%2 != 0]
#             #         print(column_2)
#                 new_col_1 = to_float_or_int(column_1)
#                 new_col_2 = to_float_or_int(column_2)                       
#                 df = pd.DataFrame(columns = ['person', 'school', 'stat', 'number', 'rank'])
#                 stats = ['Cited by Cases','Cited by Articles ','Accessed (Past 12 Months)','Cited by Articles (Past 10 Years)', 'Cited by Articles (Past 1-2 years)', ' ScholarCheck Rank', 'Average Citations per Article', 'Self-Citations']
#                 df['person'] = pd.Series([full_name]*8)
#                 df['school'] = pd.Series([school]*8)
#                 df['stat'] = pd.Series(stats)
#                 df['number'] = pd.Series(new_col_1)
#                 df['rank'] = pd.Series(new_col_2)
#                 main_df = pd.concat([main_df, df])

#                 title_index = 3
#                 stats_index = 4
#                 topic_index = 0
#                 topic_div_index = 0
#                 topic_array = soup.findAll('div', {'class': 'topics'})
#     #             elements = driver.find_elements_by_xpath("//a[contains(@href, 'LuceneSearch?terms=topic')]")
#     #             topic_list = [elm.text for elm in elements]
#                 element = title_index
#                 df = pd.DataFrame(columns = ['Title', 'Author(s)', 'Journal', 'Cited (articles)', 'Cited (cases)', 'Accessed', 'Topics'])
#                 while element:
#                     data_stream = []
#                     x_path_title = '//*[@id="save_results"]/div/div/div/div[' + str(title_index) + ']/div[2]/dt[1]/div'
#                     element = driver.find_elements_by_xpath(x_path_title)
#                     #Get title:
#                     if element:
#                         for elm in element:
#                             data_stream.append(elm.text)

#                         element = driver.find_elements_by_xpath('//*[@id="save_results"]/div/div/div/div[' + str(title_index) + ']/div[2]')
#                         for elm in element:
#                             my_list = elm.text
#                         if [a for a in my_list.split('\n') if last_name in a]:   
#                             data_stream.append([a for a in my_list.split('\n') if last_name in a][0])
#                         else:
#                             data_stream.append('na')
#                         if [a for a in my_list.split('\n') if 'Vol.' in a]:
#                             data_stream.append([a for a in my_list.split('\n') if 'Vol.' in a][0])
#                         else:
#                             data_stream.append('na')
#         #                     for content_index in range(3,5):
#         #                         x_path_content = '//*[@id="save_results"]/div/div/div/div[' + str(title_index) + ']/div[2]/dt[' + str(content_index) +']'
#         #                         element = driver.find_elements_by_xpath(x_path_content)
#         #                         if element:
#         #                             for elm in element:
#         #                                 data_stream.append(elm.text)
#                         element = driver.find_elements_by_xpath('//*[@id="save_results"]/div/div/div/div[' + str(stats_index) + ']/div[2]/div')
#                         for elm in element:
#                             cited_text = elm.text
#                         article_citations = 'na'
#                         case_citations = 'na'
#                         accessed = 'na'
#                         if not isinstance(cited_text, list):
#                             cited_text = cited_text.split('\n')
#                             cited_text
#                             for stat in cited_text:
#                                 if 'Article' in stat:
#                                     article_citations = int(re.search(r'\d+', stat).group())
#                                 if 'Case' in stat:
#                                     case_citations = int(re.search(r'\d+', stat).group())
#                                 if 'Accessed' in stat:
#                                     accessed = int(re.search(r'\d+', stat).group())
#                         data_stream.append(article_citations)
#                         data_stream.append(case_citations)
#                         data_stream.append(accessed)
#                         try:
#                             data_stream.append(topic_array[topic_div_index].text.split(':')[1])
#                         except:
#                             data_stream.append('na')
#                         df = df.append(pd.DataFrame([data_stream], columns = ['Title', 'Author(s)', 'Journal', 'Cited (articles)', 'Cited (cases)', 'Accessed', 'Topics']))
#                         stats_index +=4
#                         title_index += 4
#                         topic_div_index +=1
#                         #Check that next paper exists:
#                         x_path_title = '//*[@id="save_results"]/div/div/div/div[' + str(title_index) + ']/div[2]/dt[1]/div'
#                         element = driver.find_elements_by_xpath(x_path_title)
#                 df.to_csv(create_path('author_papers', '{}_{}_papers.csv'.format(full_name, school)))
#                 got_page = False
#                 new_names = False
#                 link_index = 1
#                 while new_names == False:
#                     try:
#                         if link_index == 1:
#                             element =driver.find_element_by_xpath('//*[@id="page_content"]/div[2]/div/ul/li/a')
#                         else: 
#                             element =driver.find_element_by_xpath('//*[@id="page_content"]/div[2]/div/ul/li[' + str(link_index) + ']/a')            
#                         if last_name == element.text.split(', ')[0] and mid_first_name in element.text.split(', ')[1] and mid_first_name != prev_mid_first_name:
#                             prev_mid_first_name = mid_first_name
#                             last_name = element.text.split(', ')[0]
#                             mid_first_name = element.text.split(', ')[1]
#                             new_names = True
#                     except: 
#                         new_names = True
#                         got_page = True
#                         print('No remaining pages to scrape from {}.'.format(full_name))
#                     link_index += 1
#                 time.sleep(3)
                
# skip_df.to_csv(create_path('skipped_names', '{}_skipped.csv'.format(school)))
# main_df.to_csv(create_path('school_stats', '{}_stats.csv'.format(school)))
# Out:
# 1
# Kenneth W Abbott
# jack e brown chair in law emeritus, professor of global studies, arizona state university
# ('Kenneth W Abbott', 'https://scholar.google.com/citations?hl=en&user=hva7aGkAAAAJ')
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-93-6af34e5d4cad> in <module>
#      15         link = get_links(mid_first_name, last_name, school_url, school_name)
#      16         print(link)
# ---> 17         driver.get('amazon.com')
#      18         time.sleep(3)
#      19         driver.get('facebook.com')
#
# ~\Anaconda3\envs\webscraping\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ...

# %%
main_df
# Out:
#                     Name                                             School  \
# 0      Kenneth W. Abbott  Arizona State University Sandra Day O'Connor C...
# 0           Angela Banks  Arizona State University Sandra Day O'Connor C...
# 0            Paul Bender  Arizona State University Sandra Day O'Connor C...
# 0        Daniel Bodansky  Arizona State University Sandra Day O'Connor C...
# 0           Diana Bowman  Arizona State University Sandra Day O'Connor C...
# 0         Karen Bradshaw  Arizona State University Sandra Day O'Connor C...
# 0       Charles Calleros  Arizona State University Sandra Day O'Connor C...
# 0          Andrew Carter  Arizona State University Sandra Day O'Connor C...
# 0          Susan Chesler  Arizona State University Sandra Day O'Connor C...
# 0          Adam Chodorow  Arizona State University Sandra Day O'Connor C...
# 0            Jason Cohen  Arizona State University Sandra Day O'Connor C...
# ...

# %%
last_name = 'Brodin' 
first_mid_name = 'Mark'
link = 'https://heinonline-org.proxy01.its.virginia.edu/HOL/AuthorProfile?action=edit&search_name=' + last_name  +  '%2C ' + first_mid_name + '&collection=journals'
driver.get(link)
a = True
link_index = 1
while a == True:
    try:
        if link_index == 1:
            element =driver.find_element_by_xpath('//*[@id="page_content"]/div[2]/div/ul/li/a')
        else: 
            element =driver.find_element_by_xpath('//*[@id="page_content"]/div[2]/div/ul/li[' + str(link_index) + ']/a')            
        if last_name == element.text.split(',')[0] and first_mid_name in  element.text.split(',')[1]:
            last_name = element.text.split(',')[0]
            mid_first_name = element.text.split(',')[1]
            print(mid_first_name + ' ' + last_name)
    except: 
        a = False
    link_index += 1
# Out:
#  Mark S. Brodin

# %%
driver.get('https://heinonline-org.proxy01.its.virginia.edu/HOL/AuthorProfile?action=edit&search_name=Bilder%2C%20Mary&collection=journals')
soup=bs.BeautifulSoup(driver.page_source, 'lxml')
table_rows = soup.findAll('td', {'style': 'text-align:right;'})
if str(table_rows[1]) == '<td style="text-align:right;"> 1 </td>':
    print('yes')
# Out:
# yes

# %%
driver.get('https://heinonline-org.proxy01.its.virginia.edu/HOL/AuthorProfile?action=edit&search_name=Gartner%2C%20David&collection=journals')
soup=bs.BeautifulSoup(driver.page_source, 'lxml')

element = driver.find_elements_by_xpath("//a[contains(@href, 'AuthorProfile?action=edit')]")
for elm in element:
    print(elm.text)
# Out:
# Gartner, David
# Gartner, David
# Abbott, Kenneth W.
# Gartner, David
# Gartner, David
# Gartner, David
# Gartner, David
# Gartner, David
# Gartner, David
# Gartner, David
# Gartner, David
# Gartner, David

# %% [markdown]
# Get the article titles:

# %%
soup.find('b', text = 'Topics:')
soup.findAll('b')
article_name_indices = []
for i in range(len(soup.findAll('b'))):
    if str(soup.findAll('b')[i]) == '<b>Topics:</b>':
        article_name_indices.append(i+1)
for ind in article_name_indices[:-1]:
    print(soup.findAll('b')[ind])
# Out:
# <b>Federalism and the Corporation:  The Desirable Limits on State Competition in Corporate Law [article]</b>
# <b>A Theory of Path Dependence in Corporate Ownership and Governance [article]</b>
# <b>The Powerful Antitakeover Force of Staggered Boards: Theory, Evidence, and Policy [article]</b>
# <b>The Uneasy Case for the Priority of Secured Claims in Bankruptcy [article]</b>
# <b>Managerial Power and Rent Extraction in the Design of Executive Compensation [article]</b>
# <b>Foreword: The Debate on Contractual Freedom in Corporate Law [comments]</b>
# <b>A New Approach to Corporate Reorganizations [article]</b>
# <b>Vigorous Race or Leisurely Walk: Reconsidering the Competition over Corporate Charters [article]</b>
# <b>Limiting Contractual Freedom in Corporate Law:  The Desirable Constraints on Charter Amendments [article]</b>
# <b>Toward Undistorted Choice and Equal Treatment in Corporate Takeovers [article]</b>
# <b>Firms's Decisions Where to Incorporate [article]</b>
# ...

# %%
soup.findAll('dt', {'class': "search_result_line"})
# Out:
# [<dt class="search_result_line">
#  <div class="lucene_search_result_url_b" style="">
#  <a href="Page?public=true&amp;handle=hein.journals/hlr118&amp;div=38&amp;start_page=833&amp;collection=journals&amp;set_as_cursor=0&amp;men_tab=srchresults"><b>The Case for Increasing Shareholder Power [article]</b></a>
#  </div>
#  <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rfr_id=info%3Asid%2Focoins.info%3Agenerator&amp;rft.genre=article&amp;rft.atitle=The Case for Increasing Shareholder Power&amp;rft.title=Harvard Law Review&amp;rft.stitle= Harv. L. Rev.  (January )&amp;rft.date=2004-2005&amp;rft.volume=118&amp;rft.spage=0&amp;rft.au=Bebchuk, Lucian Arye&amp;rft_id=https://heinonline-org.proxy01.its.virginia.edu/HOL/Page?public%3Dtrue%26handle%3Dhein.journals/hlr118%26div%3D38%26start_page%3D833%26collection%3Djournals%26set_as_cursor%3D0%26men_tab%3Dsrchresults">
#  </span>
#  <!--end_check-->
#  </dt>,
# ...

# %%
topic_indices = []
for i in range(len(soup.findAll(['b', 'a']))):
    if str(soup.findAll(['b', 'a'])[i]) == '<b>Topics:</b>':
        topic_indices.append(i+1)
        print('working')
for ind in topic_indices[:-1]:
    print(soup.findAll(['b', 'a'])[ind])
# Out:
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# <a href="LuceneSearch?terms=topic%3A%22Corporations%22&amp;collection=journals&amp;searchtype=advanced&amp;typea=text&amp;tabfrom=&amp;submit=Go&amp;all=false">Corporations</a>
# <a href="LuceneSearch?terms=topic%3A%22Corporations%22&amp;collection=journals&amp;searchtype=advanced&amp;typea=text&amp;tabfrom=&amp;submit=Go&amp;all=false">Corporations</a>
# <a href="LuceneSearch?terms=topic%3A%22Corporations%22&amp;collection=journals&amp;searchtype=advanced&amp;typea=text&amp;tabfrom=&amp;submit=Go&amp;all=false">Corporations</a>
# ...

# %%
elements = driver.find_elements_by_xpath("//a[contains(@href, 'LuceneSearch?terms=topic')]")
topic_list = [elm.text for elm in elements]
topic_list
# Out:
# ['Corporations',
#  'Business Organizations',
#  'Legal History',
#  'Corporations',
#  'Economics',
#  'State and Local Government Law',
#  'Jurisdiction',
#  'Corporations',
#  'Economics',
#  'Jurisprudence',
#  'Law and Society',
#  'Corporations',
#  'Comparative Law',
#  'Business Organizations',
#  'Bankruptcy Law',
#  'Commercial Law',
#  'Corporations',
#  'Contracts',
#  'Corporations',
#  'Corporations',
#  'Bankruptcy Law',
#  'Corporations',
#  'State and Local Government Law',
#  'Corporations',
#  'Contracts',
#  'Commercial Law',
#  'Securities',
#  'Comparative Law',
#  'Economics',
#  'Corporations',
#  'State and Local Government Law',
#  'Corporations',
#  'State and Local Government Law',
#  'Jurisdiction',
#  'Corporations',
#  'State and Local Government Law',
#  'Practice and Procedure',
#  'Dispute Resolution',
#  'Business Organizations',
#  'Jurisprudence',
#  'Corporations',
#  'Securities',
#  'Corporations',
#  'Legal Analysis and Writing',
# ...

# %%
link = 'https://heinonline-org.proxy01.its.virginia.edu/HOL/AuthorProfile?action=edit&search_name=' + 'Weinstein' +  '%2C ' + 'James' + '&collection=journals'
driver.get(link)

# %% [markdown]
# Print titles:

# %%
title_index = 3
stats_index = 4
topic_index = 0
topic_div_index = 0
topic_array = soup.findAll('div', {'class': 'topics'})
elements = driver.find_elements_by_xpath("//a[contains(@href, 'LuceneSearch?terms=topic')]")
topic_list = [elm.text for elm in elements]
element = title_index
df = pd.DataFrame(columns = ['Title', 'Journal', 'Authors', 'Cited (articles)', 'Cited (cases)', 'Accessed', 'Topics'])
while element:
    data_stream = []
    x_path_title = '//*[@id="save_results"]/div/div/div/div[' + str(title_index) + ']/div[2]/dt[1]/div'
    element = driver.find_elements_by_xpath(x_path_title)
    if element:
        for elm in element:
            data_stream.append(elm.text)
        for content_index in range(3,5):
            x_path_content = '//*[@id="save_results"]/div/div/div/div[' + str(title_index) + ']/div[2]/dt[' + str(content_index) +']'
            element = driver.find_elements_by_xpath(x_path_content)
            if element:
                for elm in element:
                    data_stream.append(elm.text)
        element = driver.find_elements_by_xpath('//*[@id="save_results"]/div/div/div/div[' + str(stats_index) + ']/div[2]/div')
        for elm in element:
            cited_text = elm.text
        article_citations = 'na'
        case_citations = 'na'
        accessed = 'na'
        if not isinstance(cited_text, list):
            cited_text = cited_text.split('\n')
            cited_text
            for stat in cited_text:
                if 'Article' in stat:
                    article_citations = int(re.search(r'\d+', stat).group())
                if 'Case' in stat:
                    case_citations = int(re.search(r'\d+', stat).group())
                if 'Accessed' in stat:
                    accessed = int(re.search(r'\d+', stat).group())
    data_stream.append(article_citations)
    data_stream.append(case_citations)
    data_stream.append(accessed)
    try:
        data_stream.append(topic_array[topic_div_index].text.split(':')[1])
    except:
        data_stream.append('na')
    df = df.append(pd.DataFrame([data_stream], columns = ['Title', 'Journal', 'Authors', 'Cited (articles)', 'Cited (cases)', 'Accessed', 'Topics']))
    topic_index += topic_index_bound
    stats_index +=4
    title_index += 4
    topic_div_index +=1
    #Check that next paper exists:
    x_path_title = '//*[@id="save_results"]/div/div/div/div[' + str(title_index) + ']/div[2]/dt[1]/div'
    element = driver.find_elements_by_xpath(x_path_title)

# %%
df
# Out:
#                                                Title  \
# 0  A Small Matter of Regulation: An International...
# 0  Regulation by Means of Standardization: Key Le...
# 0  Defining Nanomaterials for the Purpose of Regu...
# 0  Looking Back to the Future of Regulating New T...
# 0  The Private Dimension in the Regulation of Nan...
# 0  Reflecting on REACH: Global Implications of th...
# 0  The Current State of Australia's Evolving Appr...
# 0  Governing Nanomedicine: Lessons from within, a...
# 0  Treating or Tracking - Regulatory Challenges o...
# 0  Netting Nano: Regulatory Challenges of the Int...
# 0  Mitigating Risks to Pregnant Teens from Zika V...
# 0  Symposium - Governance of Emerging Technologie...
# 0  Symposium - Governance of Emerging Technologie...
# 0  Nanotechnology Down Under: Getting on Top of R...
# 0  Making a Positive Impact: Striking a Balance b...
# 0  Mapping the Regulatory Environment for Nanomat...
# 0  Assessing the Impact of a For Government Revie...
# ...

# %%
element = driver.find_elements_by_xpath('//*[@id="save_results"]/div/div/div/div[24]/div[2]/div')
for elm in element:
    cited_text = elm.text

cited_text = cited_text.split('\n')
cited_text
article_citations = 'na'
case_citations = 'na'
accessed = 'na'
for stat in cited_text:
    if 'Article' in stat:
        article_citations = int(re.search(r'\d+', stat).group())
    if 'Case' in stat:
        case_citations = int(re.search(r'\d+', stat).group())
    if 'Accessed' in stat:
        accessed = int(re.search(r'\d+', stat).group())
print(accessed)
print(case_citations)
print(article_citations)

# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
len(str(soup.findAll('div', {'class': 'topics'})[4]).split(','))
# Out:
# 2
