# %%
import pandas as pd
import os
from pandas import ExcelFile
from fuzzywuzzy import fuzz
from selenium.common.exceptions import *


def create_path(*args):
    cur_path = os.getcwd()
    for value in args:
        cur_path  = os.path.join(cur_path, value)
    return cur_path

# %%
min_law_df = pd.read_csv('min_prof_aals.csv')
min_law_df.drop(columns = ['Unnamed: 0'], inplace=True)

# %%
main_df = pd.read_csv(create_path('school_data', 'full_data_new_with_gender.csv'))
main_df.drop(columns = ['Unnamed: 0'], inplace=True)

# %%
names = [x[0] + ' ' + x[1] for x in zip(main_df['First Name'], main_df['Last Name'])]
schools = main_df['School']

# %%
min_names = [x[0] + ' ' + x[1] for x in zip(min_law_df['First Name'], min_law_df['Last Name'])]
min_schools =  min_law_df['School']
min_aals_names = list(min_law_df['AALS Name'])
min_aals_schools = list(min_law_df['AALS School'])
fuzz = list(min_law_df['Fuzz List'])

# %%
def check_google(school):
    short_url_list = []
    if school == 'Southwestern  university':
        school == 'Southwestern Law School'
    elif school == 'Brooklyn  university':
        school = 'Brooklyn Law School'
    search_name(school)
    elems = g_driver.find_elements_by_xpath("//a[@href]")
    for elem in elems:
        try:
            url = elem.get_attribute("href")
        except StaleElementReferenceException:
            continue
        if '.edu' in url:
            if '.law.' in url:
                short_url = url.split('.law.')[1].split('.')[0]
            else:
                short_url = url.split('.')[1].split('.')[0]
            short_url_list.append(short_url)
#             print('.edu' + ' in: ' + short_url)
    return short_url_list

def search_name(name):
    g_driver.get("http://bing.com")
    search = g_driver.find_element_by_xpath('//*[@id="sb_form_q"]')
    search.send_keys(name)
    search.send_keys(Keys.RETURN)
    
def intersection(lst1, lst2): 
    return list(set(lst1) & set(lst2))

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

g_driver = webdriver.Chrome()

# %%
labels = [0]*len(main_df)
count = [1]*len(main_df)
min_name_list = ['NA']*len(main_df)
min_school_list = ['NA']*len(main_df)
fuzz_list = [0]*len(main_df)
for i in range(2292, len(names)):
    if names[i] in min_aals_names:
        print(names[i])
        name_index = min_aals_names.index(names[i])
        if fuzz[name_index] > 66:
            school_1 = min_aals_schools[name_index] + ' university'
            school_2 = schools[i]
            school_list_1 = check_google(school_1)
            school_list_2 = check_google(school_2)
            if min_names[name_index] in min_name_list:
                count[i] += 1
            min_name_list[i] = min_names[name_index]
            min_school_list[i] = min_aals_schools[name_index]
            fuzz_list[i] = fuzz[name_index]
            if intersection(school_list_1, school_list_2):
                labels[i] = 1
# Out:
# Deborah Pearlstein
# Emily Houh
# Sahar Aziz
# Elise Boddie
# Ronald Chen
# Jon Dubin
# Phoebe Haddon
# Suzanne Kim
# Dennis Kim-Prieto
# David Lopez
# Kimberly Mutcherson
# Twila Perry
# Rose Villazor
# Robert Williams
# David Brennen
# Roberta Harding
# Robert Chang
# Margaret Chon
# Annette Clark
# Carmen Gonzalez
# Gregory Silverman
# Christopher Cameron
# Danielle Hart
# Roman Hoyos
# Gowri Ramachandran
# Dennis Yokoyama
# Rick Su
# Alice Abreu
# JoAnne Epps
# Hosea Harvey
# Salil Mehra
# Jaya Ramji-Nogales
# Jan Ting
# Michael Green
# Vivian Hamilton
# Carol Brown
# Henry Chambers
# Connie de la Vega
# Rhonda Magee
# Maya Manian
# Mark Alexander
# Ruth Gordon
# Teressa Ravenell
# Tuan Samahon
# Michael Kelly
# Terry Maroney
# Karla McKanders
# Sean Seymore
# Ganesh Sitaraman
# Yesha Yadav
# Johnny Parker
# Regina Jefferson
# Emily Garcia Uhrig
# Rachael Salcido
# Jarrod Wong
# Lisa Nicholson
# Cedric Powell
# Enid Trucios-Haynes
# Pat Chew
# Jasmine Gonzales Rose
# Deepa Badrinarayana
# Lan Cao
# Susanna Ripken
# Rebecca Tsosie
# Robert Williams
# Michael Kelly
# Jasmine Abdel-Khalik
# Jamila Jefferson-Jones
# Mikah Thompson
# Alfredo Garcia
# Radha Pathak
# Seval Yildirim
# Jimmy Gurule
# Veronica Martinez
# Lloyd Mayer
# Mario Barnes
# Mary Fan
# Lea Vaughn
# Timothy Davis
# Michael Green
# Lauren Collins
# Browne Lewis
# Gwendolyn Majette
# Sergio Campos
# Charlton Copeland
# Osamudia James
# Francisco Valdes
# Tae-Ung Baik
# Maxine Burkett
# Diane Desierto
# Charles Lawrence
# Mari Matsuda
# Emily Garcia Uhrig
# Rachael Salcido
# Jarrod Wong
# Jeannine Bell
# Kevin Brown
# Christiana Ochoa
# Deborah Pearlstein
# Jorge Ramirez
# Wendy Ross
# Victoria Sutton
# Arturo Torres
# Teri Baxter
# Darren Hutchinson
# Kenneth Nunn
# Katheryn Russell-Brown
# Daniel Sokol
# Wentong Zheng
# Keith Harrison
# Carl Hernandez
# Michalyn Steele
# Rachel Anderson
# Ruben Garcia
# Ngai Pindell
# John White
# Jeannine Bell
# Kevin Brown
# Christiana Ochoa
# Andrea Dennis
# Usha Rodrigues
# Stephen Leacock
# Tomiko Brown-Nagin
# Einer Elhauge
# Jeannie Gersen
# Randall Kennedy
# Kenneth Mack
# Intisar Rabb
# Brietta Clark
# Sean Scott
# Theodore Seto
# Mario Barnes
# Mary Fan
# Lea Vaughn
# Joyce Hughes
# Michael Kang
# Jide Nzelibe
# Tomas Gomez-Arostegui
# Jennifer Johnson
# Jeffrey Jones
# Samir Parikh
# Ozan Varol
# Tomiko Brown-Nagin
# Einer Elhauge
# Jeannie Gersen
# Randall Kennedy
# Kenneth Mack
# Intisar Rabb
# Bret Asbury
# Karl Okamoto
# Hunter Clark
# Shontavia Johnson
# Miguel Schor
# Ellen Yee
# Anna Shavers
# Catherine Wilson
# Sahar Aziz
# Elise Boddie
# Ronald Chen
# Jon Dubin
# Phoebe Haddon
# Suzanne Kim
# Dennis Kim-Prieto
# David Lopez
# Kimberly Mutcherson
# Twila Perry
# Rose Villazor
# Robert Williams
# Kathy Northern
# Daniel Tokaji
# G. Lee
# Shaakirrah Sanders
# Michael Satz
# Aaron Taylor
# Ruqaiijah Yearby
# Craig Boise
# Keith Bybee
# Sanjay Chhablani
# Mark Latham
# Phoenix Cai
# Bernard Chao
# Alan Chen
# Roberto Corrada
# Patience Crowder
# Jose Juarez
# Nancy Leong
# Ved Nanda

# %%
main_df['Minority Status'] = labels
main_df['Count'] = count
main_df['Min List Name'] = min_name_list
main_df['Min School List'] = min_school_list
main_df
# Out:
#         First Name        Last Name  \
# 0          Michael         Ambrosio
# 1             Gaia        Bernstein
# 2          Kristen             Boon
# 3         Kathleen          Boozang
# 4           Angela         Carmella
# 5             Carl          Coleman
# 6     Jenny-Brooke           Condon
# 7             John         Cornwell
# 8             Mark         Denbeaux
# 9            Linda           Fisher
# 10           Paula         Franzese
# 11         Timothy            Glynn
# 12        Jonathan           Hafetz
# 13          Edward         Hartnett
# 14          Thomas            Healy
# 15            John           Jacobi
# 16           Tracy             Kaye
# 17          Marina              Lao
# 18        Margaret            Lewis
# 19            Erik        Lillquist
# 20         Stephen           Lubben
# 21        Solangel        Maldonado
# 22       Catherine        McCauliff
# 23          Andrea         McDowell
# 24           Denis       McLaughlin
# 25           Dinah          Minkoff
# 26            Lori           Nessel
# 27           David        Opderbeck
# 28          Dianne            Oster
# 29        Brittany          Persson
# ...            ...              ...
# 4352        Robert         Hardaway
# 4353          Jose           Juarez
# 4354           Sam            Kamin
# 4355        Martin             Katz
# 4356        Tamara          Kuennen
# 4357      Margaret            Kwoka
# 4358           Jan           Laitos
# 4359   Christopher            Lasch
# 4360         Nancy            Leong
# 4361         Kevin            Lynch
# 4362        Justin          Marceau
# 4363          Lucy            Marsh
# 4364   G. Kristian  McDaniel-Miccio
# 4365          Viva           Moffat
# 4366           Ved            Nanda
# 4367       Stephen           Pepper
# 4368        Justin            Pidot
# 4369        Edward            Roche
# 4370           Tom           Romero
# 4371         Laura           Rovner
# 4372        Thomas          Russell
# 4373       Michael        Siebecker
# 4374         Bruce            Smith
# 4375     Catherine            Smith
# 4376       Michael            Sousa
# 4377         Joyce         Sterling
# 4378         Robin         Sterling
# 4379         Celia           Taylor
# 4380           Eli             Wald
# 4381      Annecoos         Wiersema
#
#                                                   Title  \
# 0                                      Professor of Law
# 1     Michael J. Zimmer Professor of Law, Director o...
# 2     Associate Dean for Faculty Research and Develo...
# 3                  Law School Dean and Professor of law
# 4                                      Professor of Law
# 5     Professor of Law, and Academic Director of Div...
# 6                            Associate Professor of Law
# 7                                      Professor of Law
# 8                                      Professor of Law
# 9                                      Professor of Law
# 10                     Peter W. Rodino Professor of Law
# 11    Senior Associate Dean and Andrea J. Catania En...
# 12                                     Professor of Law
# 13                   Richard J. Hughes Professor of Law
# 14                                     Professor of Law
# 15    Faculty Director of the Center for Health & Ph...
# 16                                     Professor of Law
# 17                                     Professor of Law
# 18                                     Professor of Law
# 19    Associate Provost For Academic Projects and Pr...
# 20    Harvey Washington Wiley Chair in Corporate Gov...
# 21                     Joseph M. Lynch Professor of Law
# 22                            Emeritus Professor of Law
# 23                                     Professor of Law
# 24                                     Professor of Law
# 25    Assistant Professor and Reference/Research Lib...
# 26    Director and Professor of Law, Center for Soci...
# 27    Professor of Law and Co-Director of the Gibbon...
# 28    Associate Professor and Serials/Government Doc...
# 29      Associate Professor and Head of Public Services
# ...                                                 ...
# 4352                                   Professor of Law
# 4353                                   Professor of Law
# 4354                                   Professor of Law
# 4355  Chief Innovation Officer (for University); Pro...
# 4356                                   Professor of Law
# 4357                                Associate Professor
# 4358               John A. Carver, Jr. Professor of Law
# 4359                                          Professor
# 4360                                   Professor of Law
# 4361                                Associate Professor
# 4362                                   Professor of Law
# 4363                                   Professor of Law
# 4364                                   Professor of Law
# 4365     Professor & Associate Dean of Academic Affairs
# 4366                                   Professor of Law
# 4367                                   Professor of Law
# 4368                                Associate Professor
# 4369      Professor & Associate Dean, Budget & Planning
# 4370  Associate Professor, Assistant Provost of Camp...
# 4371  Ronald V. Yegge Clinical Director & Professor ...
# 4372                                   Professor of Law
# 4373                                   Professor of Law
# 4374                                               Dean
# 4375  Professor of Law & Associate Dean, Institution...
# 4376                                Associate Professor
# 4377                                   Professor of Law
# 4378                                Associate Professor
# 4379                                   Professor of Law
# 4380            Charles W. Delaney Jr. Professor of Law
# 4381                                   Professor of Law
#
#                                          School                       E-mail  \
# 0           Seton Hall University School of Law     michael.ambrosio@shu.edu
# 1           Seton Hall University School of Law       gaia.bernstein@shu.edu
# 2           Seton Hall University School of Law         kristen.boon@shu.edu
# 3           Seton Hall University School of Law     kathleen.boozang@shu.edu
# 4           Seton Hall University School of Law      angela.carmella@shu.edu
# 5           Seton Hall University School of Law         carl.coleman@shu.edu
# 6           Seton Hall University School of Law  jenny-brooke.condon@shu.edu
# 7           Seton Hall University School of Law         kip.cornwell@shu.edu
# 8           Seton Hall University School of Law        mark.denbeaux@shu.edu
# 9           Seton Hall University School of Law         linda.fisher@shu.edu
# 10          Seton Hall University School of Law       paula.franzese@shu.edu
# 11          Seton Hall University School of Law        timothy.glynn@shu.edu
# 12          Seton Hall University School of Law      jonathan.hafetz@shu.edu
# 13          Seton Hall University School of Law      edward.hartnett@shu.edu
# 14          Seton Hall University School of Law         thomas.healy@shu.edu
# 15          Seton Hall University School of Law          john.jacobi@shu.edu
# 16          Seton Hall University School of Law           tracy.kaye@shu.edu
# 17          Seton Hall University School of Law           Marina.Lao@shu.edu
# 18          Seton Hall University School of Law       Margaret.Lewis@shu.edu
# 19          Seton Hall University School of Law       erik.lillquist@shu.edu
# 20          Seton Hall University School of Law       stephen.lubben@shu.edu
# 21          Seton Hall University School of Law   solangel.maldonado@shu.edu
# 22          Seton Hall University School of Law  catherine.mccauliff@shu.edu
# 23          Seton Hall University School of Law      andrea.mcdowell@shu.edu
# 24          Seton Hall University School of Law     denis.mclaughlin@shu.edu
# 25          Seton Hall University School of Law        dinah.monkoff@shu.edu
# 26          Seton Hall University School of Law          lori.nessel@shu.edu
# 27          Seton Hall University School of Law      david.opderbeck@shu.edu
# 28          Seton Hall University School of Law         dianne.oster@shu.edu
# 29          Seton Hall University School of Law     brittany.persson@shu.edu
# ...                                         ...                          ...
# 4352  University of Denver Sturm College of Law         rhardaway@law.du.edu
# 4353  University of Denver Sturm College of Law           bjuarez@law.du.edu
# 4354  University of Denver Sturm College of Law            skamin@law.du.edu
# 4355  University of Denver Sturm College of Law             mkatz@law.du.edu
# 4356  University of Denver Sturm College of Law          tkuennen@law.du.edu
# 4357  University of Denver Sturm College of Law            mkwoka@law.du.edu
# 4358  University of Denver Sturm College of Law           jlaitos@law.du.edu
# 4359  University of Denver Sturm College of Law            clasch@law.du.edu
# 4360  University of Denver Sturm College of Law            nleong@law.du.edu
# 4361  University of Denver Sturm College of Law            klynch@law.du.edu
# 4362  University of Denver Sturm College of Law          jmarceau@law.du.edu
# 4363  University of Denver Sturm College of Law            lmarsh@law.du.edu
# 4364  University of Denver Sturm College of Law           kmiccio@law.du.edu
# 4365  University of Denver Sturm College of Law           vmoffat@law.du.edu
# 4366  University of Denver Sturm College of Law            vnanda@law.du.edu
# 4367  University of Denver Sturm College of Law           spepper@law.du.edu
# 4368  University of Denver Sturm College of Law            jpidot@law.du.edu
# 4369  University of Denver Sturm College of Law            eroche@law.du.edu
# 4370  University of Denver Sturm College of Law           tromero@law.du.edu
# 4371  University of Denver Sturm College of Law           lrovner@law.du.edu
# 4372  University of Denver Sturm College of Law          trussell@law.du.edu
# 4373  University of Denver Sturm College of Law        msiebecker@law.du.edu
# 4374  University of Denver Sturm College of Law            bsmith@law.du.edu
# 4375  University of Denver Sturm College of Law            csmith@law.du.edu
# 4376  University of Denver Sturm College of Law            msousa@law.du.edu
# 4377  University of Denver Sturm College of Law         jsterling@law.du.edu
# 4378  University of Denver Sturm College of Law         rsterling@law.du.edu
# 4379  University of Denver Sturm College of Law           ctaylor@law.du.edu
# 4380  University of Denver Sturm College of Law             ewald@law.du.edu
# 4381  University of Denver Sturm College of Law         awiersema@law.du.edu
#
#                Phone         Gender  Gender Label  Minority Status  Count  \
# 0     (973) 642-8807           male             1                0      1
# 1     (973) 642-8494         female             0                0      1
# 2     (973) 642-8958         female             0                0      1
# 3     (973) 642-8501         female             0                0      1
# 4     (973) 642-8843         female             0                0      1
# 5     (201) 204-9512           male             1                0      1
# 6     (973) 642-8307        unknown             2                0      1
# 7     (973) 642-8498           male             1                0      1
# 8     (973) 642-8822           male             1                0      1
# 9     (973) 642-8700         female             0                0      1
# 10    (973) 642-8817         female             0                0      1
# 11    (973) 642-8777           male             1                0      1
# 12    (973) 642-8492           male             1                0      1
# 13    (973) 642-8842           male             1                0      1
# 14    (973) 642-8561           male             1                0      1
# 15    (973) 642-8952           male             1                0      1
# 16    (973) 642-8455  mostly_female             0                0      1
# 17    (973) 642-8835         female             0                1      1
# 18    (973) 642-8821         female             0                0      1
# 19    (973) 642-8844           male             1                0      1
# 20    (973) 642-8857           male             1                0      1
# 21    (973) 642-8830        unknown             2                0      1
# 22    (973) 642-8849         female             0                0      1
# 23    (973) 642-8862         female             0                0      1
# 24    (973) 642-8824           male             1                0      1
# 25    (973) 642-8769         female             0                0      1
# 26    (973) 642-8700         female             0                0      1
# 27    (973) 642-8496           male             1                0      1
# 28    (973) 642-8195         female             0                0      1
# 29    (973) 642-8767         female             0                0      1
# ...              ...            ...           ...              ...    ...
# 4352  (303) 871-6310           male             1                0      1
# 4353  (303) 871-6908           male             1                1      1
# 4354  (303) 871-6125    mostly_male             1                0      1
# 4355  (303) 871-6301           male             1                0      1
# 4356  (303) 871-6246         female             0                0      1
# 4357  (303) 871-6275         female             0                0      1
# 4358  (303) 871-6263           male             1                0      1
# 4359  (303) 871-6368           male             1                0      1
# 4360  (303) 871-6092         female             0                1      1
# 4361  (303) 871-6039           male             1                0      1
# 4362  (303) 871-6449           male             1                0      1
# 4363  (303) 871-6285         female             0                0      1
# 4364  (303) 871-6361        unknown             2                0      1
# 4365  (303) 871-6105         female             0                0      1
# 4366  (303) 871-6276        unknown             2                0      1
# 4367  (303) 871-6259           male             1                0      1
# 4368  (303) 871-6168           male             1                0      1
# 4369  (303) 871-6244           male             1                0      1
# 4370  (651) 523-2539           male             1                0      1
# 4371  (303) 871-6441         female             0                0      1
# 4372  (303) 871-6224           male             1                0      1
# 4373  (303) 871-6057           male             1                0      1
# 4374  (303) 871-6103           male             1                0      1
# 4375  (303) 871-6180         female             0                0      1
# 4376  (303) 871-6292           male             1                0      1
# 4377  (303) 871-6309         female             0                0      1
# 4378  (303) 871-6160    mostly_male             1                0      1
# 4379  (303) 871-6931         female             0                0      1
# 4380  (303) 871-6530         female             0                0      1
# 4381  (303) 871-6525        unknown             2                0      1
#
#        Min List Name                            Min School List  Fuzz
# 0                 NA                                         NA   100
# 1                 NA                                         NA   100
# 2                 NA                                         NA   100
# 3                 NA                                         NA   100
# 4                 NA                                         NA   100
# 5                 NA                                         NA   100
# 6                 NA                                         NA   100
# 7                 NA                                         NA   100
# 8                 NA                                         NA   100
# 9                 NA                                         NA   100
# 10                NA                                         NA   100
# 11                NA                                         NA   100
# 12                NA                                         NA   100
# 13                NA                                         NA   100
# 14                NA                                         NA   100
# 15                NA                                         NA   100
# 16                NA                                         NA   100
# 17      Marina L Lao        Seton Hall University School of Law   100
# 18                NA                                         NA   100
# 19                NA                                         NA   100
# 20                NA                                         NA   100
# 21                NA                                         NA   100
# 22                NA                                         NA   100
# 23                NA                                         NA   100
# 24                NA                                         NA   100
# 25                NA                                         NA   100
# 26                NA                                         NA   100
# 27                NA                                         NA   100
# 28                NA                                         NA   100
# 29                NA                                         NA   100
# ...              ...                                        ...   ...
# 4352              NA                                         NA   100
# 4353  Jose R. Juarez  University of Denver Sturm College of Law   100
# 4354              NA                                         NA   100
# 4355              NA                                         NA   100
# 4356              NA                                         NA   100
# 4357              NA                                         NA   100
# 4358              NA                                         NA   100
# 4359              NA                                         NA   100
# 4360     Nancy Leong  University of Denver Sturm College of Law   100
# 4361              NA                                         NA   100
# 4362              NA                                         NA   100
# 4363              NA                                         NA   100
# 4364              NA                                         NA   100
# 4365              NA                                         NA   100
# 4366              NA                                         NA   100
# 4367              NA                                         NA   100
# 4368              NA                                         NA   100
# 4369              NA                                         NA   100
# 4370              NA                                         NA   100
# 4371              NA                                         NA   100
# 4372              NA                                         NA   100
# 4373              NA                                         NA   100
# 4374              NA                                         NA   100
# 4375              NA                                         NA   100
# 4376              NA                                         NA   100
# 4377              NA                                         NA   100
# 4378              NA                                         NA   100
# 4379              NA                                         NA   100
# 4380              NA                                         NA   100
# 4381              NA                                         NA   100
#
# [4382 rows x 13 columns]

# %%
main_df.to_csv('law_prof_data_gender_min.csv')

# %%
def closest_three(min_name, min_school, names_schools):
    max_fuzz = [0, 0, 0]
    name_list = ['', '', '']
    school_list = ['', '', '']
    for name, school in names_schools:
        fuzz_ratio = fuzz.ratio(min_name, name)
        if fuzz_ratio > max_fuzz[2]:
            name_list.pop(2)
            school_list.pop(2)
            max_fuzz.pop(2)
            name_list.insert(2, name)
            max_fuzz.insert(2, fuzz_ratio)
            school_list.insert(2, school)
            max_fuzz, name_list, school_list = (list(t) for t in zip(*sorted(zip(max_fuzz, name_list, school_list), reverse = True)))
    return list(zip(max_fuzz, name_list, school_list))

# %%
master_list = []
for min_name, min_school in min_names_schools:
    closest_list = closest_three(min_name, min_school, names_schools)
    master_list.append(closest_list)

# %%
fuzz_1 = [master_list[i][0][0] for i in range(len(master_list))]
fuzz_2 = [master_list[i][1][0] for i in range(len(master_list))]
fuzz_3 = [master_list[i][2][0] for i in range(len(master_list))]
name_1 = [master_list[i][0][1] for i in range(len(master_list))]
name_2 = [master_list[i][1][1] for i in range(len(master_list))]
name_3 = [master_list[i][2][1] for i in range(len(master_list))]
school_1 = [master_list[i][0][2] for i in range(len(master_list))]
school_2 = [master_list[i][1][2] for i in range(len(master_list))]
school_3 = [master_list[i][2][2] for i in range(len(master_list))]
near_df = pd.DataFrame({'Fuzz 1': fuzz_1, 'Fuzz 2': fuzz_2, 'Fuzz 3': fuzz_3, 
              'Name 1': name_1, 'Name 2': name_2, 'Name 3': name_3, 
             'School 1': school_1, 'School 2': school_2, 'School 3': school_3})
df = pd.concat([min_law_df, near_df], axis = 1,  sort = False)
df.to_csv('min_law_nearest_names.csv')

# %%
elems = g_driver.find_elements_by_xpath("//a[@href]")

# %%
for elem in elems:
#     print(elem.get_attribute("href"))
    if '.edu' in elem.get_attribute("href"):
        url = elem.get_attribute("href")
        print(elem.get_attribute("href"))
        short_url = url.split('.')[1].split('.')[0]
        print(short_url)
# Out:
# http://www.smu.edu/
# smu
# https://www.smu.edu/
# smu
# https://www.smu.edu/admission/
# smu
# http://www.smu.edu/
# smu

# %%
removed_values = [output[i] for i in index_list]

# %%
min_profs = [output[i] for i in range(len(output)) if i not in index_list]

# %%
def create_dataframe(prof_list):
    min_list_name = [x[0][0] for x in prof_list]
    min_list_school = [x[0][1] for x in prof_list]
    data_list_name = [x[1][0] for x in prof_list]
    data_list_school = [x[1][1] for x in prof_list]
    fuzz_ratio = [x[2] for x in prof_list]
    min_name_df = pd.DataFrame({'Min List Name': min_list_name, 'Data List Name': data_list_name,'Min List School': min_list_school, 'Data List School': data_list_school, 'Fuzz Ratio': fuzz_ratio})
    return min_name_df

# %%
incorrect_name_df = create_dataframe(removed_values)
correct_name_df = create_dataframe(min_profs)
incorrect_name_df.to_csv('incorrect_names.csv')
correct_name_df.to_csv('correct_names.csv')

# %%
min_index_list_df = [names.index(x) for x in list(correct_name_df['Data List Name'])]

# %%
min_var = [1 if i in min_index_list_df else 0 for i in range(len(main_df))]

# %%
main_df['Minority'] = min_var

# %%
main_df.to_csv('law_prof_data_gender_min.csv')
