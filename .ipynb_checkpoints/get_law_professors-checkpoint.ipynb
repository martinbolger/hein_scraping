# %%
from selenium import webdriver
import pandas as pd
import bs4 as bs
import urllib.request
import os

# %%
driver = webdriver.Firefox()
driver.get("http://dlt.aals.org")#put the adress of your page here

# %% [markdown]
# User: mlivermore@virginia.edu
# Pass: X33y22Z11

# %%
def search_school(school_name):
    driver.get('https://dlt.aals.org/dlts')
    elem = driver.find_element_by_xpath("/html/body/div/div/div/form/div[1]/div[1]/div/div/a/span")
    elem.click()
    driver.find_element_by_xpath("/html/body/div/div/div/form/div[1]/div[1]/div/div/div/div/input").send_keys(school_name)
    driver.find_element_by_xpath("/html/body/div/div/div/form/div[1]/div[1]/div/div/div/ul/li").click()
    example = driver.find_element_by_xpath('/html/body/div/div/div/form/div[1]/div[1]/div/div/div/ul/li')
    if example.text[:16] == 'No results match':
        school_exists = False
    else:
        school_exists = True
        driver.find_element_by_xpath('//*[@id="q_tenured_and_dean"]').click()
        driver.find_element_by_xpath("/html/body/div/div/div/form/div[2]/div/input").click()
    return school_exists

# %%
search_school('university of alabama')
# Out:
# False

# %%
def get_page_data(html, cur_data):
    dfs = pd.read_html(html)
    data = dfs[0].iloc[:,:-1]
    cur_data = pd.concat([cur_data, data])
    return cur_data
def create_path(*args):
    cur_path = os.getcwd()
    for value in args:
        cur_path  = os.path.join(cur_path, value)
    return cur_path

# %%
list_schools = open('list_schools.txt', 'r')
list_schools = list_schools.read().split('\n')[:-1]
type(list_schools)
# Out:
# list

# %%
for school in list_schools:
    school_exists = search_school(school)
    if school_exists:
        cur_data = pd.DataFrame()    
        html = driver.page_source
        cur_data = get_page_data(html, cur_data)
        soup = bs.BeautifulSoup(html, 'lxml')
        next_page_url = soup.find('a', {'rel': 'next'})

        while next_page_url:
            next_link = next_page_url.get('href')
            link = 'https://dlt.aals.org' + next_link
            driver.get(link)
            html = driver.page_source
            cur_data = get_page_data(html, cur_data)
            soup = bs.BeautifulSoup(html, 'lxml')
            next_page_url = soup.find('a', {'rel': 'next'})
        cur_data.reset_index(inplace = True, drop = True)
        cur_data.to_csv(create_path('school_data', '{}.csv'.format(school)))
    else:
        print('{} is not in the database'.format(school))
# Out:
# University of Texas School of Law is not in the database
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\webscraping\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-f445bc650044> in <module>
#      11             next_link = next_page_url.get('href')
#      12             link = 'https://dlt.aals.org' + next_link
# ---> 13             driver.get(link)
#      14             html = driver.page_source
#      15             cur_data = get_page_data(html, cur_data)
#
# ~\Anaconda3\envs\webscraping\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\Anaconda3\envs\webscraping\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\Anaconda3\envs\webscraping\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\Anaconda3\envs\webscraping\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\Anaconda3\envs\webscraping\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~\Anaconda3\envs\webscraping\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~\Anaconda3\envs\webscraping\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     321             response = conn.urlopen(method, url, **kw)
#     322         else:
# --> 323             response = conn.urlopen(method, u.request_uri, **kw)
#     324
#     325         redirect_location = redirect and response.get_redirect_location()
#
# ~\Anaconda3\envs\webscraping\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\envs\webscraping\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\envs\webscraping\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\Anaconda3\envs\webscraping\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3\envs\webscraping\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3\envs\webscraping\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
list_schools
# Out:
# <_io.TextIOWrapper name='list_schools.txt' mode='r' encoding='cp1252'>

# %% [markdown]
# After you have logged in, Selenium is able to navigate to any webpage. We will navigate to the pages on the list:

# %%
faculty_list = pd.read_csv('UVa_law_faculty.csv')
faculty_list
faculty_list.drop(columns = ['Unnamed: 0'], inplace=True)
faculty_list
# Out:
#                       Resident
# 0           Kenneth S. Abraham
# 1          Barbara E. Armacost
# 2                Aditya Bamzai
# 3               Charles Barzun
# 4               Michal Barzuza
# 5            Richard J. Bonnie
# 6                  Josh Bowers
# 7             Maureen E. Brady
# 8               Stephen  Braga
# 9              Darryl K. Brown
# 10                D. Ruth Buck
# 11          Jonathan Z. Cannon
# 12                 Albert Choi
# 13             George M. Cohen
# 14          Michael G. Collins
# 15                  Kevin Cope
# 16            Anne M. Coughlin
# 17                Quinn Curtis
# 18             Ashley S. Deeks
# 19               Michael Doran
# 20               John F. Duffy
# 21          Deirdre M. Enright
# 22     Kimberly Kessler Ferzan
# 23             Joshua Fischman
# 24            Kim Forde-Mazrui
# 25                    Joe Fore
# 26              George S. Geis
# 27          Michael D. Gilbert
# 28          Jennifer L. Givens
# 29            Risa L. Goluboff
# ..                         ...
# 59             Daniel R. Ortiz
# 60              Farah Peterson
# 61          Saikrishna Prakash
# 62       Margaret Foster Riley
# 63         Mildred W. Robinson
# 64           George Rutherglen
# 65               James E. Ryan
# 66         A. Sprightley  Ryan
# 67  Nelson Camilo Sánchez León
# 68           Frederick Schauer
# 69        Richard C. Schragger
# 70        Micah J. Schwartzman
# 71              John K. Setear
# 72         Molly Bishop Shadel
# 73                Crystal Shin
# 74                  Gil Siegal
# 75         Barbara A. Spellman
# 76         A. Benjamin Spencer
# 77             Paul B. Stephan
# 78               Gregg Strauss
# 79       Pierre-Hugues Verdier
# 80              J. H. Verkerke
# 81               Mila Versteeg
# 82           Andrew N. Vollmer
# 83              Steven D. Walt
# 84          Sarah Stewart Ware
# 85             G. Edward White
# 86             Ann Woolhandler
# 87                  Ethan Yale
# 88               George K. Yin
#
# [89 rows x 1 columns]

# %%
def to_float_or_int(input_list):
    new_list = []
    for x in input_list:
        x = x.replace(',','')
        try:
            value = int(x)
        except ValueError:
            try:
                value = float(x)
            except:
                value = ''
        new_list.append(value)
    return new_list
new_list = to_float_or_int(column_1)
print(column_1)
print(new_list)
# Out:
# ['82', '1,594', ' 732', ' 466', ' 74', '\xa0', '26.13', ' 58 ']
# [82, 1594, 732, 466, 74, '', 26.13, 58]

# %%
full_name = faculty_list.Resident[0]
first_name = full_name.split(' ')[0]
middle_name = full_name.split(' ')[1]
last_name = full_name.split(' ')[2]

link = 'https://heinonline-org.proxy01.its.virginia.edu/HOL/AuthorProfile?action=edit&search_name=' + last_name + '%2C%20' + first_name + '%20' + middle_name + '&collection=journals'
driver.get(link)

# %%
#Selenium hands the page source to Beautiful Soup
soup=bs.BeautifulSoup(driver.page_source, 'lxml')
# table = soup.table
table = soup.findAll('table', {'class': 'table noborder unpad'})
main_table = table[0]
table_rows = main_table.findAll('th')
print(table_rows)
# Out:
# [<th align="left">
# 	Full Name
# 	</th>, <th align="left">University/Affiliation
# 		</th>, <th style="text-align:right;padding-top:12px">
# #
# </th>, <th style="text-align:right;padding-top:12px">
# Rank
# </th>, <th align="left" style="white-space: nowrap;">
# <a class="glyphlink opacity" href="#" onclick="$('#a1_help').slideToggle();return false;"><span class="fa fa-info-circle"></span></a>
# 			Cited by Cases <br/>
# </th>, <th align="left" style="white-space: nowrap;">
# <a class="glyphlink opacity" href="#" onclick="$('#a2_help').slideToggle();return false;"><span class="fa fa-info-circle"></span></a>
# 			Cited by Articles <a class="glyphlink opacity" href="" id="year_link" name="year_link" onclick='$("#yearview").toggle();$(".yearview_tr").toggle();return false;' style="display:none;">(By Year)</a><br/>
# </th>, <th align="left" style="white-space: nowrap;">
# <a class="glyphlink opacity" href="#" onclick="$('#a3_help').slideToggle();return false;"><span class="fa fa-info-circle"></span></a>
# 			Accessed (Past 12 Months)<br/>
# </th>, <th align="left" style="white-space: nowrap;">
# <a class="glyphlink opacity" href="#" onclick="$('#a4_help').slideToggle();return false;"><span class="fa fa-info-circle"></span></a>
# 			Cited by Articles (Past 10 Years)<br/>
# </th>, <th align="left" style="white-space: nowrap;">
# <a class="glyphlink opacity" href="#" onclick="$('#a6_help').slideToggle();return false;"><span class="fa fa-info-circle"></span></a>
# 			Cited  by Articles (Past 1-2  years)<br/>
# </th>, <th align="left" style="white-space: nowrap;">
# <a class="glyphlink opacity" href="#" onclick="$('#a5_help').slideToggle();return false;"><span class="fa fa-info-circle"></span></a>
# 			ScholarCheck Rank<br/>
# </th>, <th align="left" style="white-space: nowrap;">
# <a class="glyphlink opacity" href="#" onclick="$('#a7_help').slideToggle();return false;"><span class="fa fa-info-circle"></span></a>
#
#
#
# 		Average Citations per Article  <br/>
# </th>, <th align="left" style="white-space: nowrap;">
# <a class="glyphlink opacity" href="#" onclick="$('#a2a_help').slideToggle();return false;"><span class="fa fa-info-circle"></span></a>
# 			Self-Citations
# 			</th>]

# %%
out = [row.findAll('td', {'style': 'text-align:right;'}) for row in table_rows if row.findAll('td', {'style': 'text-align:right;'}) != []]
#flatten
out = [item for sublist in out for item in sublist]
column_1 = [str(x).split('>')[1].split('<')[0] for i,x in enumerate(out) if i%2 == 0]
column_2 = [str(x).split('>')[1].split('<')[0] for i,x in enumerate(out) if i%2 != 0]
# print(list(map(lambda x: float(x), column_1)))
new_col_1 = to_float_or_int(column_1)
new_col_2 = to_float_or_int(column_2)                       
df = pd.DataFrame(columns = ['stat', 'number', 'rank'])
df['number'] = pd.Series(new_col_1)
df['rank'] = pd.Series(new_col_2)
df
# print(main_table_rows)
# data = main_table_rows.findAll('td', {'style': 'text-align:right;'})
# print(data)

# for tr in table_rows:
# 	td = tr.find_all('td')
# 	row = [i.text for i in td]
# 	print(row)
# Out:
# ['82', '1,594', ' 732', ' 466', ' 74', '\xa0', '26.13', ' 58 ']
# ['380', '448', '1,295', '758', '782', ' 260 ', ' ', '']
#   stat number  rank
# 0  NaN     82   380
# 1  NaN   1594   448
# 2  NaN    732  1295
# 3  NaN    466   758
# 4  NaN     74   782
# 5  NaN          260
# 6  NaN  26.13
# 7  NaN     58

# %%
browser.get_current_page()
browser.get_current_page().find_all('form')
# Out:
# [<form action="https://shibidp.its.virginia.edu/idp/profile/SAML2/POST/SSO" method="POST" name="EZproxyForm"><input name="RelayState" type="hidden" value="ezp.2aHR0cDovL2hlaW5vbmxpbmUub3JnL0hPTC9XZWxjb21l"/>
#  <input name="SAMLRequest" type="hidden" value="..."/>
#  If your browser does not continue automatically, click <input type="submit" value="here"/>
#  </form>,
#  <form name="EZproxyTrack"><input name="back" type="hidden" value="1"/><script language="JavaScript">
#  <!--
#  function EZproxyCheckBack() {  var goForward = (document.EZproxyTrack.back.value==1);  document.EZproxyTrack.back.value=2;  document.EZproxyTrack.back.defaultValue=2;  if (goForward) { document.EZproxyForm.submit(); }}
#  -->
#  </script></form>]

# %%
browser.select_form('form[action="/idp/profile/SAML2/POST/SSO?execution=e1s1"]')
browser["j_username"] = "meb2fv"
browser["j_password"] = "0ver In 2018!"
browser.submit_selected()
# Out:
# ---------------------------------------------------------------------------
# LinkNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-04d84542e31b> in <module>
# ----> 1 browser.select_form('form[action="/idp/profile/SAML2/POST/SSO?execution=e1s1"]')
#       2 browser["j_username"] = "meb2fv"
#       3 browser["j_password"] = "0ver In 2018!"
#       4 browser.submit_selected()
#
# ~\Anaconda3\envs\webscraping\lib\site-packages\mechanicalsoup\stateful_browser.py in select_form(self, selector, nr)
#     173                 print('select_form failed for', selector)
#     174                 self.launch_browser()
# --> 175             raise LinkNotFoundError()
#     176
#     177         self.__current_form = Form(found_forms[-1])
#
# LinkNotFoundError:
