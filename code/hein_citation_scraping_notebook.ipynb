# %%
import pandas as pd
import os
import numpy as np
import re
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
import random
import math
import pathlib 

import modules.hein_scraping_functions
from modules.create_path import create_path
from modules.hein_scraping_functions import create_browser, webpage_wait, get_paper_data, mod_names, check_bing, search_names

# %%
# Create the paths for the data directories
input_path, work_path, intr_path, out_path, selenium_driver_path = create_path()

# %%
# Create the paths for the Chrome binary and selenium driver
chrome_binary_path = pathlib.Path("C:\\Program Files (x86)\\BraveSoftware\\Brave-Browser\\Application\\brave.exe")
selenium_driver_full_path = selenium_driver_path / "chromedriver.exe"

# Initalize the browsers that we are going to use
driver = create_browser(chrome_binary_path, selenium_driver_full_path)

driver.get("http://proxy.its.virginia.edu/login?url=http://heinonline.org/HOL/Welcome")

# %%
# Load the datasets from the working directory
# The datasets in the working directory have already 
# been cleaned.
input_data = pd.read_excel(input_path / "search strings for cites before lateral move.xls")
data = input_data

# %%
# Check to see if the file for the alternate names data already exists.
# If it does, we only want to look for the missing observations
df_cur = intr_path / "_cites_before_lateral_year_update.xlsx"
if df_cur.exists():
    print("Data already exists. Papers that have already been scraped will be skipped")
    # Set the append flag to 1
    append = 1
    # Create the dataset of existing alt names.
    df_existing_data = pd.read_excel(df_cur)
    # df_existing_data['ID'] = df_existing_data['ID'].apply(lambda x: '{0:0>4}'.format(x))
    # Complete a left outer join of the existing alt names and the lateral/control data to get 
    # a list of the names that we still need to scrape alt names for.
    data = pd.merge(input_data, df_existing_data[["ID", "Title", "BBCite"]], how = "outer", left_on = ["ID", "Title", "BBCite"], right_on = ["ID", "Title", "BBCite"], indicator=True)
    data = data[data['_merge'] == 'left_only']
    data = data.drop(["_merge"], axis = 1)
    append_df = df_existing_data
else:
    # Set the append flag to zero because we won't have any data to append
    append = 0
    data = input_data
    append_df = pd.DataFrame().reindex(columns=list(data.columns) + ["google scholar cite count"])
data
# Out:
# Data already exists. Papers that have already been scraped will be skipped
#        ID                                              Title PaperType  \
# 158     8  Bankruptcy and Entrepreneurship: The Value of ...   article
# 162     8     Matching Bankruptcy Laws to Legal Environments   article
# 163     8       Optimal Trust Design in Mass Tort Bankruptcy   article
# 196    10  The Shareholder Wealth Effects of Delaware Lit...   article
# 247    14                        Harm - Benefit Interactions   article
# ...   ...                                                ...       ...
# 6161  264                                      In This Issue     notes
# 6162  264                                      In This Issue     notes
# 6163  264                                      In This Issue     notes
# 6164  264                                      In This Issue     notes
# 6212  266     A Dialogical Approach to Trade and Environment   article
#
#                                                 Authors  LateralYear  \
# 158                   Ayotte, Kenneth (Cited 280 times)         2013
# 162   Ayotte, Kenneth (Cited 280 times); Yun, Hayong...         2013
# 163   Ayotte, Kenneth (Cited 280 times); Listokin, Y...         2013
# 196   Badawi, Adam B. (Cited 81 times); Chen, Daniel...         2017
# 247   Bar-Gill, Oren (Cited 1378 times); Porat, Arie...         2014
# ...                                                 ...          ...
# 6161             Tomlins, Christopher (Cited 159 times)         2014
# 6162             Tomlins, Christopher (Cited 159 times)         2014
# 6163             Tomlins, Christopher (Cited 159 times)         2014
# 6164             Tomlins, Christopher (Cited 159 times)         2014
# 6212               Trujillo, Elizabeth (Cited 43 times)         2016
#
#       NumCoauthors                             BBCite  OrigArticleCites  \
# 158              1   23 J. L. Econ. & Org. 161 (2007)                17
# 162              2     25 J. L. Econ. & Org. 2 (2009)                 2
# 163              2   7 Am. L. & Econ. Rev. 403 (2005)                 2
# 196              2  19 Am. L. & Econ. Rev. 287 (2017)                 2
# 247              2   16 Am. L. & Econ. Rev. 86 (2014)                 6
# ...            ...                                ...               ...
# 6161             1     33 Law & Soc. Inquiry 1 (2008)                 2
# 6162             1   33 Law & Soc. Inquiry 291 (2008)                 1
# 6163             1   33 Law & Soc. Inquiry 575 (2008)                 1
# 6164             1   33 Law & Soc. Inquiry 849 (2008)                 1
# 6212             1    16 J. Int'l Econ. L. 535 (2013)                 6
#
#                                           Journal  Year  Lateral  \
# 158   Journal of Law, Economics, and Organization  2007        1
# 162   Journal of Law, Economics, and Organization  2009        1
# 163             American Law and Economics Review  2005        1
# 196             American Law and Economics Review  2017        1
# 247             American Law and Economics Review  2014        1
# ...                                           ...   ...      ...
# 6161                       Law and Social Inquiry  2008        1
# 6162                       Law and Social Inquiry  2008        1
# 6163                       Law and Social Inquiry  2008        1
# 6164                       Law and Social Inquiry  2008        1
# 6212        Journal of International Economic Law  2013        1
#
#       Year<=LatYear             BBCite w/o year  BeginYear  EndYear
# 158               1   23 J. L. Econ. & Org. 161       2005     2013
# 162               1     25 J. L. Econ. & Org. 2       2007     2013
# 163               1   7 Am. L. & Econ. Rev. 403       2003     2013
# 196               1  19 Am. L. & Econ. Rev. 287       2015     2017
# 247               1   16 Am. L. & Econ. Rev. 86       2012     2014
# ...             ...                         ...        ...      ...
# 6161              1     33 Law & Soc. Inquiry 1       2006     2014
# 6162              1   33 Law & Soc. Inquiry 291       2006     2014
# 6163              1   33 Law & Soc. Inquiry 575       2006     2014
# 6164              1   33 Law & Soc. Inquiry 849       2006     2014
# 6212              1    16 J. Int'l Econ. L. 535       2011     2016
#
# [63 rows x 15 columns]

# %%
#This function searches for a string of text using the advanced search function in Hein
# It is used to find the number of hits for different book/paper titles after a certain year.
def search_hein_for_cites_after_year(search_text, author_name_full, year, driver):

    if search_text == np.nan:
        return np.nan
    
    # Go to the main page
    link = 'https://heinonline-org.proxy01.its.virginia.edu/HOL/Welcome'
    driver.get(link)

    # Wait for the page logo to load
    webpage_wait('//*[@id="heinlogo"]/a/img', driver)

    # Enter the search text
    full_text = driver.find_element_by_xpath('//*[@id="full_text_terms"]') 
    full_text.clear()
    full_text.send_keys(search_text)

    # Click the search button
    search = driver.find_element_by_xpath('//*[@id="sendit_full_text"]').click()
    # Wait for the page logo to load
    webpage_wait('//*[@id="heinlogo"]/a/img', driver)

    # Find full paper information
    try:
        element = driver.find_element_by_xpath('//*[@id="save_results"]/div/div/div/div[3]/div[2]')
    except NoSuchElementException:
        print("Error: Paper information not found for {}".format(search_text))
        return np.nan
    # Make sure the author name is correct
    author_name = author_name_full.split(" (")[0]
    # 
    if author_name in element.text:
        # Find the citation field
        try:
            element = driver.find_element_by_xpath('//*[@id="save_results"]/div/div/div/div[4]/div[2]/div/a')
            if 'Cited by' in element.text and 'Case' not in element.text:
                cited_link = element.get_attribute('href')
                driver.get(cited_link)
            else:
                print("Error: Citation field not found for {}".format(search_text))
                return np.nan
        except NoSuchElementException:
            print("Note: The citation field was not found for {}".format(search_text))
            return np.nan
    else:
        print("Error: Author name not found in top result for {}".format(search_text))
        return np.nan
    # Click the year field
    year_box = driver.find_element_by_xpath('//*[@id="face_show_in"]/aside/a/h3').click()
    # Enter the ending year
    year_high = driver.find_element_by_xpath('//*[@id="yearhi"]')
    year_high.send_keys(str(year))

    year_go = driver.find_element_by_xpath('//*[@id="dateadd"]/input[12]').click()

    # Return the results
    try:
        result_element = driver.find_element_by_xpath('//*[@id="results_total"]')
        count_match = re.search(r"^(0|[1-9]\d{0,2},?\d*) results", result_element.text)
        citation_count = count_match.group(1)
    except NoSuchElementException:
        print("Note: No citations were found after the lateral move for {}".format(search_text))
        return 0
    return citation_count

# %%
for i in range(len(data)):
    # Read the current row of the df into a dictionary
    dict = data.to_dict('records')[i]
    # Update the cite count variable
    dict["Cites Before Lateral Year"] = search_hein_for_cites_after_year(data.iloc[i, 1], data.iloc[i, 3], data.iloc[i, 4], driver)   
    append_df = append_df.append(dict, ignore_index = True)
    append_df.to_excel(intr_path / "_cites_before_lateral_year.xlsx", index = False)
# Out:
# Note: The citation field was not found for Military Courts and the All Writs Act
# Note: The citation field was not found for Pendent Appellate Bootstrapping
# Note: The citation field was not found for Petty Offenses and Article III
# Note: No citations were found after the lateral move for Terrorism Prosecutions and the Problem of Constitutional Cross-Ruffing
# Note: No citations were found after the lateral move for The FISA Court and Article III
# Note: The citation field was not found for The Riddle of the One-Way Ratchet
# Note: The citation field was not found for The Torture Report and the Accountability Gap
# Note: The citation field was not found for Trying Terrorism Suspects in Article III Courts: The Lessons of United States v. Abu Ali
# Note: No citations were found after the lateral move for A New Paradigm of Leaking
# Error: Author name not found in top result for Foreword
# Note: No citations were found after the lateral move for Targeted Killing and Judicial Review
# Note: No citations were found after the lateral move for Targeted Killing and Judicial Review
# Note: No citations were found after the lateral move for The Supreme Court, Original Habeas, and the Paradoxical Virtue of Obscurity
# Error: Author name not found in top result for Introductory Note
# Note: The citation field was not found for Two Years after the Pennsylvania Supreme Court's Decision in Belden & Blake Corp. v. Commonwealth Department of Conservation & Natural Resources: The Commonwealth's Struggle to Protect State Lands
# Error: Author name not found in top result for Introduction
# Note: The citation field was not found for The American Approach
# Error: Author name not found in top result for Executive Summary
# Error: Author name not found in top result for Executive Summary
# Error: Author name not found in top result for Executive Summary
# Note: No citations were found after the lateral move for What Administrative Law Can Teach the Trademark System
# Note: The citation field was not found for ADR and Numbers: An Introduction
# Error: Author name not found in top result for All in the Family
# Note: The citation field was not found for Arbitration and beyond: Avoiding Pitfalls in Drafting Dispute Resolution Clauses in Employment Contracts
# Note: The citation field was not found for Becoming Investor-State Mediation
# Note: The citation field was not found for Court-Ordered ADR: What Are the Limits
# Note: The citation field was not found for Court-Ordered ADR: What Are the Limits
# Note: The citation field was not found for Enforcement of Foreign Arbitration Agreements and Awards: Application of the New York Convention in the United States
# Note: The citation field was not found for Eyes on the Prize
# Note: The citation field was not found for Finding Opportunities in Dispute Resolution: An Introduction
# Note: The citation field was not found for Grappling the Monster Case: The Net Frontier in ADR
# Note: The citation field was not found for Institutionalization: What Do Empirical Studies Tell Us about Court Mediation
# Note: The citation field was not found for Moving the Ball Forward in Consumer and Employment Dispute Resolution: What Can Planning, Talking, Listening and Breaking Bread Together Accomplish
# Note: The citation field was not found for Not Quite Protocols: Toward Collaborative Research in Dispute Resolution
# Note: The citation field was not found for Ross et al. v. American Express et al.
# Note: The citation field was not found for The Lawyers' Buffet: Options in Resolving Disputes
# Note: The citation field was not found for What's It All about: Finding the Appropriate Problem Definition in Mediation
# Error: Author name not found in top result for From the Chair
# Error: Author name not found in top result for From the Chair
# Error: Author name not found in top result for From the Chair
# Error: Author name not found in top result for From the Chair
# Error: Author name not found in top result for Introduction
# Note: The citation field was not found for Adaptations to the civil mediation model: Suggestions from research into the approaches to conflict resolution used in the Twin Cities' Cambodian community
# Note: The citation field was not found for Theory and Reality in Regulating Dispute Resolution
# Note: The citation field was not found for Introduction - A Sympathetic but Critical Assessment of Nanotechnology Initiatives
# Note: The citation field was not found for Private Partners and the Public Good
# Error: Author name not found in top result for Reviews in Medical Ethics
# Note: The citation field was not found for Senate Bill 386: Texas' New Manged Care Liability Law
# Note: No citations were found after the lateral move for The Overlooked Benefit of Minimalism: Perry v. Brown and the Future of Marriage Equality
# Note: The citation field was not found for Unauthorized Practice: Regulating the Use of Anesthetized, Recently Deceased, and Conscious Patients in Medical Teaching
# Note: The citation field was not found for Essay: The Limits of Conscience: Moral Clashes over Deeply Divisive Healthcare Procedures
# Error: Author name not found in top result for Introduction
# Note: The citation field was not found for A Behavioral Approach to Human Rights
# Note: The citation field was not found for A Behavioral Approach to Human Rights
# Note: The citation field was not found for Toward a Situational Model for Regulating International Crimes
# Note: The citation field was not found for Discounting Rights
# Note: No citations were found after the lateral move for Improperly Burdened: The Uncertain and Sometimes Unfair Application of Tax Penalties
# Note: No citations were found after the lateral move for Attempt, Risk-Creation, and Change of Mind: Reflections on Herzog
# Note: The citation field was not found for Harmfulness, Wrongfulness, Lesser Evils and Risk-Creation: A Comment on Douglas Husak's Overcriminalization
# Note: No citations were found after the lateral move for Intoxication, Recklessness, and Negligence
# Note: The citation field was not found for Prevention and Imminence, Pre-Punishment and Actuality
# Note: The citation field was not found for The Government Beguiled Me: The Entrapment Defense and the Problem of Private Entrapment
# Note: The citation field was not found for The Legal Importance of Trying: Reply to Enoch, Dahan-Katz, and Berman
# Note: No citations were found after the lateral move for Reply to Jan Broersen, Thomas Nadelhoffer and Steven Sverdlik
# Note: No citations were found after the lateral move for Duty of Outrage: The Defense Lawyer's Obligation to Speak Truth to Power to the Prosecutor and the Court When the Criminal Justice System Is Unjust
# Note: No citations were found after the lateral move for Duty of Outrage: The Defense Lawyer's Obligation to Speak Truth to Power to the Prosecutor and the Court When the Criminal Justice System is Unjust
# Error: Author name not found in top result for New Models for Prosecutorial Accountability
# Note: No citations were found after the lateral move for Prosecutorial Accountability 2.0
# Note: The citation field was not found for Starr Wars: Aberrational or Routine Exercixe of Prosecutorial Discretion
# Error: Author name not found in top result for Introduction
# Error: Author name not found in top result for Introduction
# Note: The citation field was not found for The Tucson Trial and Its Legal Consequences for Asylum Seekers
# Note: The citation field was not found for Missing the Target: Preventing the Unjust Inclusion of Vulnerable Children for Medical Research Studies
# Note: The citation field was not found for The Impact of Structural Racism in Employment and Wages on Minority Women's Health
# Note: The citation field was not found for From the Mayflower to Border Patrols: Who Deserves Access to Health Care in the United States
# Note: No citations were found after the lateral move for How Copyright Law May Affect Pop Music without Our Knowing It
# Note: The citation field was not found for The Trust and Distrust of Intellectual Property Rights
# Note: The citation field was not found for The US-China WTO Cases Explained
# Note: No citations were found after the lateral move for Trade Secret Hacking, Online Data Breaches, and China's Cyberthreats
# Error: Author name not found in top result for An Introduction
# Error: Author name not found in top result for Foreword
# Note: No citations were found after the lateral move for International and Comparative Aspects of Trademark Dilution
# Error: Author name not found in top result for Introduction
# Note: The citation field was not found for Conserving Ecosystems through the Secretarial Order on Tribal Rights (continued)
# Note: The citation field was not found for Floods, Famines, or Feasts: Too Much, Too Little, or Just Right
# Note: The citation field was not found for Improving Water Quality Antidegradation Policies
# Note: The citation field was not found for Is Water Property
# Note: No citations were found after the lateral move for Mudslinging on the Missouri: Can Endangered Species Survive the Clean Water Act
# Note: The citation field was not found for The Fallacy of Judicial Supermajority Clauses in State Constitutions
